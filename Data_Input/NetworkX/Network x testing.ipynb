# %% [markdown]
# An interaction network which could be used to visualise relevant kinase and substrate relationships based on the results from the user input file.

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
######################Test with kinase/substrate data############################
All_data=pd.read_csv('kinaseList_for_NX_test.csv') #Upload test file.
#Create different lists for kinases and substrates.
Kinase_list=All_data['Kinase'] 
Sub_list=All_data['Substrate']

#Subset for test as final output would include less interactions thenin test file.
Kinase_list=Kinase_list[0:50]
Sub_list=Sub_list[0:50]


###NODE LIST###
#Merge Kinases and substrates to make one big node list.
Nodelist=Test_K.append(Test_S)


###EDGE LIST###
#Zip Kinase and substrate list in tuples
E_list=tuple(zip(Test_K, Test_S))



###Input nodes and edges to make graph###
G3 = nx.Graph()


G3.add_nodes_from(Nodelist)
G3.add_edges_from(E_list)

nx.draw_circular(G3, with_labels=True, node_color='orange')
