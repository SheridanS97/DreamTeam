# %% [markdown]
# # Reading the new phosphosite data 29 Jan, 2020

# %%
import pandas as pd
new_df = pd.read_csv("Phosphosite_genomic_locations.csv")
new_df.head()
# Out:
#   KINASE KIN_ACC_ID SUB_ACC_ID SUB_GENE SUB_MOD_RSD     SITE_+/-7_AA  \
# 0    HRI     Q9BQI3     P05198   EIF2S1         S49  IEGMILLsELsRRRI
# 1    PKR     P19525     P05198   EIF2S1         S49  IEGMILLsELsRRRI
# 2   PERK     Q9NZJ5     P05198   EIF2S1         S49  IEGMILLsELsRRRI
# 3   PKCD     Q05655     P35611     ADD1        S726  KKKFRtPsFLKKsKK
# 4   Chk1     O14757     P35611     ADD1        S726  KKKFRtPsFLKKsKK
#
#   Chromosome/scaffold name Karyotype band  Strand  Start co    End co
# 0                       14          q23.3     1.0  67364912  67364914
# 1                       14          q23.3     1.0  67364912  67364914
# 2                       14          q23.3     1.0  67364912  67364914
# 3                        4          p16.3     1.0   2928485   2928487
# 4                        4          p16.3     1.0   2928485   2928487

# %%
new_df[new_df["SUB_GENE"]=="HDAC5"]
# Out:
#       KINASE KIN_ACC_ID SUB_ACC_ID SUB_GENE SUB_MOD_RSD     SITE_+/-7_AA  \
# 285   CAMK2A     Q9UQM7     Q9UQL6    HDAC5        S498  RPLSRtQsSPLPQsP
# 286   AMPKA1     Q13131     Q9UQL6    HDAC5        S498  RPLSRtQsSPLPQsP
# 287    CAMK4     Q16566     Q9UQL6    HDAC5        S498  RPLSRtQsSPLPQsP
# 288   AMPKA2     P54646     Q9UQL6    HDAC5        S498  RPLSRtQsSPLPQsP
# 289   CAMK1A     Q14012     Q9UQL6    HDAC5        S498  RPLSRtQsSPLPQsP
# 290    PRKD3     O94806     Q9UQL6    HDAC5        S498  RPLSRtQsSPLPQsP
# 291    PRKD1     Q15139     Q9UQL6    HDAC5        S498  RPLSRtQsSPLPQsP
# 292    PRKD2     Q9BZL6     Q9UQL6    HDAC5        S498  RPLSRtQsSPLPQsP
# 4393    PKN1     Q16512     Q9UQL6    HDAC5        T292  KDGtVIstFKKRAVE
#
#      Chromosome/scaffold name Karyotype band  Strand  Start co    End co
# 285                        17         q21.31    -1.0  44088494  44088492
# 286                        17         q21.31    -1.0  44088494  44088492
# ...
