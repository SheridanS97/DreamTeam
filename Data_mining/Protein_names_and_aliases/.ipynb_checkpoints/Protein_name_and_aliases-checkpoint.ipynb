# %% [markdown]
# # Getting protein name and other synonyms

# %% [markdown]
# ## Source: uniprot

# %%
#import library
import pandas as pd
import re

# %%
#install the library if you don't have it
# !pip install bioservices
from bioservices import UniProt

# %%
#read csv file into dataframe
kinase_df = pd.read_csv('clean_human_kinase.csv', index_col=0)
kinase_df.tail()
# Out:
#                                          gene_name uniprot_identifier  \
# family
# Atypical: PI3/PI4-kinase family              PRKDC        PRKDC_HUMAN
# Atypical: PI3/PI4-kinase family               SMG1         SMG1_HUMAN
# Atypical: RIO-type Ser/Thr kinase family     RIOK1        RIOK1_HUMAN
# Atypical: RIO-type Ser/Thr kinase family     RIOK2        RIOK2_HUMAN
# Atypical: RIO-type Ser/Thr kinase family     RIOK3        RIOK3_HUMAN
#
#                                          uniprot_number
# family
# Atypical: PI3/PI4-kinase family                  P78527
# Atypical: PI3/PI4-kinase family                  Q96Q15
# Atypical: RIO-type Ser/Thr kinase family         Q9BRS2
# Atypical: RIO-type Ser/Thr kinase family         Q9BVS4
# Atypical: RIO-type Ser/Thr kinase family         O14730

# %%
#unprocessed uniprot_number
unprocessed_list = kinase_df['uniprot_number'].tolist()
unprocessed_list[]
# Out:
# ['P31749',
#  'P31751',
#  'Q9Y243',
#  'Q5VT25',
#  'Q9Y5S2',
#  'Q6DT37',
#  'O14578',
#  'Q09013',
#  'Q15835',
#  'P25098',
#  'P35626',
#  'P32298',
#  'P34947',
#  'P43250',
#  'Q8WTQ7',
#  'O95835',
#  'Q9NRM7',
#  'Q9Y2H9',
#  'Q6P0Q8',
#  'O60307',
#  'O15021',
#  'Q96GX5',
#  'O15530',
#  'Q6A1A2',
#  'Q16512',
#  'Q16513',
#  'Q6P5Z2',
#  'P17612',
#  'P22694',
#  'P22612',
#  'P17252',
#  'P05771',
#  'Q05655',
#  'Q02156',
#  'P05129',
#  'P24723',
#  'P41743',
#  'Q04759',
#  'Q05513',
#  'Q13976',
#  'Q13237',
#  'P51817',
#  'O43930',
#  'Q13464',
#  'O75116',
#  'Q15418',
#  'Q15349',
#  'P51812',
#  'O75676',
#  'O75582',
#  'Q9UK32',
#  'P23443',
#  'Q9UBS0',
#  'O00141',
#  'Q9HBY8',
#  'Q96BR1',
#  'Q15208',
#  'Q9Y2H1',
#  'Q8TDC3',
#  'Q8IWQ3',
#  'Q14012',
#  'Q8IU85',
#  'Q96NX5',
#  'Q9UQM7',
#  'Q13554',
#  'Q13557',
#  'Q13555',
#  'Q16566',
#  'Q8NCB2',
#  'O14936',
#  'O14757',
#  'O96017',
#  'P53355',
#  'Q9UIK4',
#  'O43293',
#  'O15075',
#  'Q8N568',
#  'Q9C098',
#  'P57058',
#  'O60229',
#  'P49137',
#  'Q16644',
#  'Q8IW41',
#  'Q9P0L2',
#  'Q7KZI7',
#  'P27448',
#  'Q96L34',
#  'Q14680',
#  'Q9BUB5',
#  'Q9HBH9',
#  'Q15746',
#  'Q9H1R3',
#  'Q32MK0',
#  'Q86YV6',
#  'Q8IY84',
#  'O60285',
#  'Q9H093',
#  'Q5VST9',
#  'Q96RG2',
#  'Q16816',
#  'P15735',
#  'P11309',
#  'Q9P1W9',
#  'Q86V86',
#  'Q6P2M8',
#  'Q13131',
#  'P54646',
#  'Q15139',
#  'Q9BZL6',
#  'O94806',
#  'P11801',
#  'Q96QS6',
#  'P57059',
#  'A0A0B4J2F2',
#  'Q9H0K1',
#  'Q9Y2K2',
#  'Q9NRH2',
#  'Q15772',
#  'Q15831',
#  'Q9UEE5',
#  'O94768',
#  'Q9BYT3',
#  'Q8N2I9',
#  'Q96RU8',
#  'Q92519',
#  'Q96RU7',
#  'O75962',
#  'Q9BXA7',
#  'Q96PF2',
#  'Q96PN8',
#  'Q6SA08',
#  'Q9BXA6',
#  'Q8WZ42',
#  'P48729',
#  'Q8N752',
#  'P48730',
#  'P49674',
#  'Q9HCP0',
#  'P78368',
#  'Q9Y6M4',
#  'Q5TCY1',
#  'Q6IQ55',
#  'Q99986',
#  'Q86Y07',
#  'Q8IV63',
#  'P06493',
#  'Q15131',
#  'Q9UQ88',
#  'P21127',
#  'Q9NYV4',
#  'Q14004',
#  'O94921',
#  'Q96Q40',
#  'Q00536',
#  'Q00537',
#  'Q07002',
#  'Q9BWU1',
#  'P24941',
#  'Q8IZL9',
#  'Q00526',
#  'P11802',
#  'Q00535',
#  'Q00534',
#  'P50613',
#  'P49336',
#  'P50750',
#  'Q00532',
#  'Q92772',
#  'Q8IVW4',
#  'Q5MAI5',
#  'O76039',
#  'P49759',
#  'P49760',
#  'P49761',
#  'Q9HAZ1',
#  'Q13627',
#  'Q9Y463',
#  'Q92630',
#  'O43781',
#  'Q9NR20',
#  'P49840',
#  'P49841',
#  'Q86Z02',
#  'Q9H2X6',
#  'Q9H422',
#  'Q8NE63',
#  'Q9UPZ9',
#  'P20794',
#  'P28482',
#  'P53779',
#  'Q15759',
#  'P53778',
#  'O15264',
#  'Q16539',
#  'Q8TD08',
#  'P27361',
#  'P31152',
#  'Q16659',
#  'Q13164',
#  'P45983',
#  'P45984',
#  'Q9UQ07',
#  'Q9UBE8',
#  'Q13523',
#  'Q96SB4',
#  'P78362',
#  'Q9UPE1',
#  'Q96PY6',
#  'Q6ZWH5',
#  'Q8NG66',
#  'P51955',
#  'P51956',
#  'P51957',
#  'Q6P3R8',
#  'Q9HC98',
#  'Q8TDX7',
#  'Q86SG6',
#  'Q8TD19',
#  'P25092',
#  'Q02846',
#  'P51841',
#  'P16066',
#  'P20594',
#  'Q02750',
#  'P36507',
#  'P46734',
#  'P45985',
#  'Q13163',
#  'P52564',
#  'O14733',
#  'Q13233',
#  'Q02779',
#  'Q16584',
#  'Q12852',
#  'O43283',
#  'Q99558',
#  'Q6ZN16',
#  'Q56UN5',
#  'Q9Y2U5',
#  'Q9NYL2',
#  'Q5TCX8',
#  'Q99759',
#  'Q9Y6R4',
#  'Q99683',
#  'O95382',
#  'O43318',
#  'P41279',
#  'P80192',
#  'Q92918',
#  'Q12851',
#  'Q8IVH8',
#  'O95819',
#  'Q9Y4K4',
#  'Q8N4C8',
#  'Q8NEV4',
#  'Q8WXR4',
#  'Q7Z2Y5',
#  'O95747',
#  'Q13153',
#  'Q13177',
#  'O75914',
#  'O96013',
#  'Q9P286',
#  'Q9NQU5',
#  'Q96KB5',
#  'Q9H2G2',
#  'O94804',
#  'Q9Y6E0',
#  'O00506',
#  'Q9P289',
#  'Q13188',
#  'Q9UEW8',
#  'Q13043',
#  'Q7RTN6',
#  'Q9C0K7',
#  'Q7L7X3',
#  'Q9UL54',
#  'Q9H2K8',
#  'Q9UKE5',
#  'Q04771',
#  'P36896',
#  'Q8NER5',
#  'P27037',
#  'Q13705',
#  'P37023',
#  'Q16671',
#  'Q8NFD2',
#  'P10398',
#  'P36894',
#  'O00238',
#  'Q13873',
#  'P15056',
#  'Q13418',
#  'P51617',
#  'O43187',
#  'Q9Y616',
#  'Q9NWZ3',
#  'Q8IVT5',
#  'Q6VAB6',
#  'P53667',
#  'P53671',
#  'Q38SD2',
#  'Q5S007',
#  'P04049',
#  'Q13546',
#  'O43353',
#  'Q9Y572',
#  'P57078',
#  'Q15569',
#  'Q96S53',
#  'P36897',
#  'P37173',
#  'Q59H18',
#  'Q6ZMQ8',
#  'P00519',
#  'P42684',
#  'Q9UM73',
#  'P30530',
#  'P51451',
#  'P51813',
#  'Q06187',
#  'P07333',
#  'P41240',
#  'Q08345',
#  'Q16832',
#  'P00533',
#  'P21709',
#  'Q5JZY3',
#  'P29317',
#  'P29320',
#  'P54764',
#  'P54756',
#  'Q9UF33',
#  'Q15375',
#  'P29322',
#  'P54762',
#  'P29323',
#  'P54753',
#  'P54760',
#  'O15197',
#  'P04626',
#  'P21860',
#  'Q15303',
#  'P16591',
#  'P07332',
#  'P11362',
#  'P21802',
#  'P22607',
#  'P22455',
#  'P09769',
#  'P17948',
#  'P36888',
#  'P35916',
#  'P42685',
#  'P06241',
#  'P08631',
#  'P08069',
#  'P06213',
#  'P14616',
#  'Q08881',
#  'P23458',
#  'O60674',
#  'P52333',
#  'P35968',
#  'P10721',
#  'P06239',
#  'Q8IWU2',
#  'Q96Q04',
#  'P29376',
#  'P07948',
#  'P42679',
#  'Q12866',
#  'P08581',
#  'Q04912',
#  'O15146',
#  'P04629',
#  'Q16620',
#  'Q16288',
#  'P16234',
#  'P09619',
#  'Q05397',
#  'Q14289',
#  'Q13882',
#  'Q13308',
#  'P07949',
#  'Q01973',
#  'Q01974',
#  'P08922',
#  'P34925',
#  'P12931',
#  'Q9H3Y6',
#  'Q6J9G0',
#  'P43405',
#  'P42680',
#  'Q02763',
#  'P35590',
#  'Q13470',
#  'Q07912',
#  'P42681',
#  'P29597',
#  'Q06418',
#  'P07947',
#  'P43403',
#  'Q2M2I8',
#  'O14965',
#  'Q96GD4',
#  'Q9UQB9',
#  'Q9NSY1',
#  'O43683',
#  'O60566',
#  'Q8N5S9',
#  'Q96RR4',
#  'O00311',
#  'O15111',
#  'P68400',
#  'P19784',
#  'Q8NEV1',
#  'Q6XUX3',
#  'Q9BQI3',
#  'P19525',
#  'Q9NZJ5',
#  'Q9P2K8',
#  'O75460',
#  'Q76MJ5',
#  'O14976',
#  'Q8TF76',
#  'O14920',
#  'Q14164',
#  'Q8NB16',
#  'P00540',
#  'Q9UHY1',
#  'Q9NSY0',
#  'Q58A45',
#  'Q8N165',
#  'Q9H792',
#  'Q99570',
#  'Q9BXM7',
#  'Q504Y2',
#  'Q99640',
#  'P53350',
#  'Q9NYY3',
#  'Q9H4B4',
#  'O00444',
#  'Q496M5',
#  'Q9H5K3',
#  'Q86YV5',
#  'Q7Z7A4',
#  'Q05823',
#  'Q96S38',
#  'Q9Y6S9',
#  'Q96LW2',
#  'Q52WX2',
#  'P0C263',
#  'P0C264',
#  'Q96KG9',
#  'Q6P3W7',
#  'Q8IZE3',
#  'O75716',
#  'Q9BXU1',
#  'Q8WU08',
#  'Q9NY57',
#  'Q86UX6',
#  'Q8TDR2',
#  'Q9NRP7',
#  'Q8NE28',
#  'Q8TEA7',
#  'Q9UHD2',
#  'Q8IWB6',
#  'Q9UKI8',
#  'Q86UE8',
#  'Q96S44',
#  'P33981',
#  'Q8TAS1',
#  'O75385',
#  'Q8IYT8',
#  'Q6PHR2',
#  'Q96C45',
#  'P30291',
#  'P0C1S8',
#  'Q9H4A3',
#  'Q9Y3S1',
#  'Q9BYP7',
#  'Q96J92',
#  'Q86TW2',
#  'Q7Z695',
#  'Q3MIX3',
#  'Q8NI60',
#  'Q96D53',
#  'Q96QP1',
#  'Q86TB3',
#  'Q96L96',
#  'O00418',
#  'Q9BX84',
#  'Q96QT4',
#  'Q14296',
#  'O14874',
#  'Q15118',
#  'Q15119',
#  'Q15120',
#  'Q16654',
#  'Q13315',
#  'Q13535',
#  'P42345',
#  'P42336',
#  'P42338',
#  'O00329',
#  'P48736',
#  'P78527',
#  'Q96Q15',
#  'Q9BRS2',
#  'Q9BVS4',
#  'O14730']

# %%
#turn gene name into a list
up_num_list = kinase_df['Uniprot_number'].str.rstrip().tolist() #rstrip to remove the white spaces
up_num_list
# Out:
# ['P31749',
#  'P31751',
#  'Q9Y243',
#  'Q5VT25',
#  'Q9Y5S2',
#  'Q6DT37',
#  'O14578',
#  'Q09013',
#  'Q15835',
#  'P25098',
#  'P35626',
#  'P32298',
#  'P34947',
#  'P43250',
#  'Q8WTQ7',
#  'O95835',
#  'Q9NRM7',
#  'Q9Y2H9',
#  'Q6P0Q8',
#  'O60307',
#  'O15021',
#  'Q96GX5',
#  'O15530',
#  'Q6A1A2',
#  'Q16512',
#  'Q16513',
#  'Q6P5Z2',
#  'P17612',
#  'P22694',
#  'P22612',
#  'P17252',
#  'P05771',
#  'Q05655',
#  'Q02156',
#  'P05129',
#  'P24723',
#  'P41743',
#  'Q04759',
#  'Q05513',
#  'Q13976',
#  'Q13237',
#  'P51817',
#  'O43930',
#  'Q13464',
#  'O75116',
#  'Q15418',
#  'Q15349',
#  'P51812',
#  'O75676',
#  'O75582',
#  'Q9UK32',
#  'P23443',
#  'Q9UBS0',
#  'O00141',
#  'Q9HBY8',
#  'Q96BR1',
#  'Q15208',
#  'Q9Y2H1',
#  'Q8TDC3',
#  'Q8IWQ3',
#  'Q14012',
#  'Q8IU85',
#  'Q96NX5',
#  'Q9UQM7',
#  'Q13554',
#  'Q13557',
#  'Q13555',
#  'Q16566',
#  'Q8NCB2',
#  'O14936',
#  'O14757',
#  'O96017',
#  'P53355',
#  'Q9UIK4',
#  'O43293',
#  'O15075',
#  'Q8N568',
#  'Q9C098',
#  'P57058',
#  'O60229',
#  'P49137',
#  'Q16644',
#  'Q8IW41',
#  'Q9P0L2',
#  'Q7KZI7',
#  'P27448',
#  'Q96L34',
#  'Q14680',
#  'Q9BUB5',
#  'Q9HBH9',
#  'Q15746',
#  'Q9H1R3',
#  'Q32MK0',
#  'Q86YV6',
#  'Q8IY84',
#  'O60285',
#  'Q9H093',
#  'Q5VST9',
#  'Q96RG2',
#  'Q16816',
#  'P15735',
#  'P11309',
#  'Q9P1W9',
#  'Q86V86',
#  'Q6P2M8',
#  'Q13131',
#  'P54646',
#  'Q15139',
#  'Q9BZL6',
#  'O94806',
#  'P11801',
#  'Q96QS6',
#  'P57059',
#  'A0A0B4J2F2',
#  'Q9H0K1',
#  'Q9Y2K2',
#  'Q9NRH2',
#  'Q15772',
#  'Q15831',
#  'Q9UEE5',
#  'O94768',
#  'Q9BYT3',
#  'Q8N2I9',
#  'Q96RU8',
#  'Q92519',
#  'Q96RU7',
#  'O75962',
#  'Q9BXA7',
#  'Q96PF2',
#  'Q96PN8',
#  'Q6SA08',
#  'Q9BXA6',
#  'Q8WZ42',
#  'P48729',
#  'Q8N752',
#  'P48730',
#  'P49674',
#  'Q9HCP0',
#  'P78368',
#  'Q9Y6M4',
#  'Q5TCY1',
#  'Q6IQ55',
#  'Q99986',
#  'Q86Y07',
#  'Q8IV63',
#  'P06493',
#  'Q15131',
#  'Q9UQ88',
#  'P21127',
#  'Q9NYV4',
#  'Q14004',
#  'O94921',
#  'Q96Q40',
#  'Q00536',
#  'Q00537',
#  'Q07002',
#  'Q9BWU1',
#  'P24941',
#  'Q8IZL9',
#  'Q00526',
#  'P11802',
#  'Q00535',
#  'Q00534',
#  'P50613',
#  'P49336',
#  'P50750',
#  'Q00532',
#  'Q92772',
#  'Q8IVW4',
#  'Q5MAI5',
#  'O76039',
#  'P49759',
#  'P49760',
#  'P49761',
#  'Q9HAZ1',
#  'Q13627',
#  'Q9Y463',
#  'Q92630',
#  'O43781',
#  'Q9NR20',
#  'P49840',
#  'P49841',
#  'Q86Z02',
#  'Q9H2X6',
#  'Q9H422',
#  'Q8NE63',
#  'Q9UPZ9',
#  'P20794',
#  'P28482',
#  'P53779',
#  'Q15759',
#  'P53778',
#  'O15264',
#  'Q16539',
#  'Q8TD08',
#  'P27361',
#  'P31152',
#  'Q16659',
#  'Q13164',
#  'P45983',
#  'P45984',
#  'Q9UQ07',
#  'Q9UBE8',
#  'Q13523',
#  'Q96SB4',
#  'P78362',
#  'Q9UPE1',
#  'Q96PY6',
#  'Q6ZWH5',
#  'Q8NG66',
#  'P51955',
#  'P51956',
#  'P51957',
#  'Q6P3R8',
#  'Q9HC98',
#  'Q8TDX7',
#  'Q86SG6',
#  'Q8TD19',
#  'P25092',
#  'Q02846',
#  'P51841',
#  'P16066',
#  'P20594',
#  'Q02750',
#  'P36507',
#  'P46734',
#  'P45985',
#  'Q13163',
#  'P52564',
#  'O14733',
#  'Q13233',
#  'Q02779',
#  'Q16584',
#  'Q12852',
#  'O43283',
#  'Q99558',
#  'Q6ZN16',
#  'Q56UN5',
#  'Q9Y2U5',
#  'Q9NYL2',
#  'Q5TCX8',
#  'Q99759',
#  'Q9Y6R4',
#  'Q99683',
#  'O95382',
#  'O43318',
#  'P41279',
#  'P80192',
#  'Q92918',
#  'Q12851',
#  'Q8IVH8',
#  'O95819',
#  'Q9Y4K4',
#  'Q8N4C8',
#  'Q8NEV4',
#  'Q8WXR4',
#  'Q7Z2Y5',
#  'O95747',
#  'Q13153',
#  'Q13177',
#  'O75914',
#  'O96013',
#  'Q9P286',
#  'Q9NQU5',
#  'Q96KB5',
#  'Q9H2G2',
#  'O94804',
#  'Q9Y6E0',
#  'O00506',
#  'Q9P289',
#  'Q13188',
#  'Q9UEW8',
#  'Q13043',
#  'Q7RTN6',
#  'Q9C0K7',
#  'Q7L7X3',
#  'Q9UL54',
#  'Q9H2K8',
#  'Q9UKE5',
#  'Q04771',
#  'P36896',
#  'Q8NER5',
#  'P27037',
#  'Q13705',
#  'P37023',
#  'Q16671',
#  'Q8NFD2',
#  'P10398',
#  'P36894',
#  'O00238',
#  'Q13873',
#  'P15056',
#  'Q13418',
#  'P51617',
#  'O43187',
#  'Q9Y616',
#  'Q9NWZ3',
#  'Q8IVT5',
#  'Q6VAB6',
#  'P53667',
#  'P53671',
#  'Q38SD2',
#  'Q5S007',
#  'P04049',
#  'Q13546',
#  'O43353',
#  'Q9Y572',
#  'P57078',
#  'Q15569',
#  'Q96S53',
#  'P36897',
#  'P37173',
#  'Q59H18',
#  'Q6ZMQ8',
#  'P00519',
#  'P42684',
#  'Q9UM73',
#  'P30530',
#  'P51451',
#  'P51813',
#  'Q06187',
#  'P07333',
#  'P41240',
#  'Q08345',
#  'Q16832',
#  'P00533',
#  'P21709',
#  'Q5JZY3',
#  'P29317',
#  'P29320',
#  'P54764',
#  'P54756',
#  'Q9UF33',
#  'Q15375',
#  'P29322',
#  'P54762',
#  'P29323',
#  'P54753',
#  'P54760',
#  'O15197',
#  'P04626',
#  'P21860',
#  'Q15303',
#  'P16591',
#  'P07332',
#  'P11362',
#  'P21802',
#  'P22607',
#  'P22455',
#  'P09769',
#  'P17948',
#  'P36888',
#  'P35916',
#  'P42685',
#  'P06241',
#  'P08631',
#  'P08069',
#  'P06213',
#  'P14616',
#  'Q08881',
#  'P23458',
#  'O60674',
#  'P52333',
#  'P35968',
#  'P10721',
#  'P06239',
#  'Q8IWU2',
#  'Q96Q04',
#  'P29376',
#  'P07948',
#  'P42679',
#  'Q12866',
#  'P08581',
#  'Q04912',
#  'O15146',
#  'P04629',
#  'Q16620',
#  'Q16288',
#  'P16234',
#  'P09619',
#  'Q05397',
#  'Q14289',
#  'Q13882',
#  'Q13308',
#  'P07949',
#  'Q01973',
#  'Q01974',
#  'P08922',
#  'P34925',
#  'P12931',
#  'Q9H3Y6',
#  'Q6J9G0',
#  'P43405',
#  'P42680',
#  'Q02763',
#  'P35590',
#  'Q13470',
#  'Q07912',
#  'P42681',
#  'P29597',
#  'Q06418',
#  'P07947',
#  'P43403',
#  'Q2M2I8',
#  'O14965',
#  'Q96GD4',
#  'Q9UQB9',
#  'Q9NSY1',
#  'O43683',
#  'O60566',
#  'Q8N5S9',
#  'Q96RR4',
#  'O00311',
#  'O15111',
#  'P68400',
#  'P19784',
#  'Q8NEV1',
#  'Q6XUX3',
#  'Q9BQI3',
#  'P19525',
#  'Q9NZJ5',
#  'Q9P2K8',
#  'O75460',
#  'Q76MJ5',
#  'O14976',
#  'Q8TF76',
#  'O14920',
#  'Q14164',
#  'Q8NB16',
#  'P00540',
#  'Q9UHY1',
#  'Q9NSY0',
#  'Q58A45',
#  'Q8N165',
#  'Q9H792',
#  'Q99570',
#  'Q9BXM7',
#  'Q504Y2',
#  'Q99640',
#  'P53350',
#  'Q9NYY3',
#  'Q9H4B4',
#  'O00444',
#  'Q496M5',
#  'Q9H5K3',
#  'Q86YV5',
#  'Q7Z7A4',
#  'Q05823',
#  'Q96S38',
#  'Q9Y6S9',
#  'Q96LW2',
#  'Q52WX2',
#  'P0C263',
#  'P0C264',
#  'Q96KG9',
#  'Q6P3W7',
#  'Q8IZE3',
#  'O75716',
#  'Q9BXU1',
#  'Q8WU08',
#  'Q9NY57',
#  'Q86UX6',
#  'Q8TDR2',
#  'Q9NRP7',
#  'Q8NE28',
#  'Q8TEA7',
#  'Q9UHD2',
#  'Q8IWB6',
#  'Q9UKI8',
#  'Q86UE8',
#  'Q96S44',
#  'P33981',
#  'Q8TAS1',
#  'O75385',
#  'Q8IYT8',
#  'Q6PHR2',
#  'Q96C45',
#  'P30291',
#  'P0C1S8',
#  'Q9H4A3',
#  'Q9Y3S1',
#  'Q9BYP7',
#  'Q96J92',
#  'Q86TW2',
#  'Q7Z695',
#  'Q3MIX3',
#  'Q8NI60',
#  'Q96D53',
#  'Q96QP1',
#  'Q86TB3',
#  'Q96L96',
#  'O00418',
#  'Q9BX84',
#  'Q96QT4',
#  'Q14296',
#  'Q14874',
#  'Q15118',
#  'Q15119',
#  'Q15120',
#  'Q16654',
#  'Q13315',
#  'Q13535',
#  'P42345',
#  'P42336',
#  'P42338',
#  'O00329',
#  'P48736',
#  'P78527',
#  'Q96Q15',
#  'Q9BRS2',
#  'Q9BVS4',
#  'O14730']

# %%
#using bioservices
u = UniProt(verbose=False)
u.search("id:P31751", limit=1, columns="id,protein names")
# Out:
# Creating directory /home/jovyan/.cache/bioservices
# Welcome to Bioservices
# ======================
# It looks like you do not have a configuration file.
# We are creating one with default values in /home/jovyan/.config/bioservices/bioservices.cfg .
# Done
# 'Entry\tProtein names\nP31751\tRAC-beta serine/threonine-protein kinase (EC 2.7.11.1) (Protein kinase Akt-2) (Protein kinase B beta) (PKB beta) (RAC-PK-beta)\n'

# %%
#split the output by multiple seps
example = u.search("id:P31751", limit=1, columns="id,protein names")
re.split('\t|\n', example)
# Out:
# ['Entry',
#  'Protein names',
#  'P31751',
#  'RAC-beta serine/threonine-protein kinase (EC 2.7.11.1) (Protein kinase Akt-2) (Protein kinase B beta) (PKB beta) (RAC-PK-beta)',
#  '']

# %%
#retrieve the protein names
ex_str = re.split('\t|\n', example)
ex_str[3].split('(')[0].rstrip()
# Out:
# 'RAC-beta serine/threonine-protein kinase'

# %%
#create a function to get the uniprot_number, gene_name, protein_name, gene_aliases
def get_meta(uniprot_num):
    """
    Takes in a uniprot number.
    Returns the uniprot_number, gene_name, protein_name, gene_aliases as a tuple.
    """
    query = "id:{}".format(uniprot_num)
    output = u.search(query, limit=1, columns="id,protein names, genes(PREFERRED), genes")
    tmp = re.split('\t|\n', output)
    protein_name = tmp[5].split('(')[0].rstrip()
    gene_name = tmp[6]
    gene_aliases = tmp[7].split()
    return(uniprot_num, gene_name, protein_name, gene_aliases)
get_meta('Q5VT25')
# Out:
# ('Q5VT25',
#  'CDC42BPA',
#  'Serine/threonine-protein kinase MRCK alpha',
#  ['CDC42BPA', 'KIAA0451'])

# %%
#get all the protein names
total = []
for num in up_num_list:
    tmp = get_meta(num)
    if len(tmp) < 4:
        print(tmp)
    else:
        total.append(tmp)
total
# Out:
# [('P31749',
#   'AKT1',
#   'RAC-alpha serine/threonine-protein kinase',
#   ['AKT1', 'PKB', 'RAC']),
#  ('P31751', 'AKT2', 'RAC-beta serine/threonine-protein kinase', ['AKT2']),
#  ('Q9Y243',
#   'AKT3',
#   'RAC-gamma serine/threonine-protein kinase',
#   ['AKT3', 'PKBG']),
#  ('Q5VT25',
#   'CDC42BPA',
#   'Serine/threonine-protein kinase MRCK alpha',
#   ['CDC42BPA', 'KIAA0451']),
#  ('Q9Y5S2',
#   'CDC42BPB',
#   'Serine/threonine-protein kinase MRCK beta',
#   ['CDC42BPB', 'KIAA1124']),
#  ('Q6DT37',
#   'CDC42BPG',
#   'Serine/threonine-protein kinase MRCK gamma',
#   ['CDC42BPG', 'DMPK2']),
#  ('O14578',
#   'CIT',
#   'Citron Rho-interacting kinase',
#   ['CIT', 'CRIK', 'KIAA0949', 'STK21']),
#  ('Q09013', 'DMPK', 'Myotonin-protein kinase', ['DMPK', 'DM1PK', 'MDPK']),
#  ('Q15835', 'GRK1', 'Rhodopsin kinase GRK1', ['GRK1', 'RHOK']),
#  ('P25098',
#   'GRK2',
#   'Beta-adrenergic receptor kinase 1',
#   ['GRK2', 'ADRBK1', 'BARK', 'BARK1']),
#  ('P35626',
#   'GRK3',
#   'Beta-adrenergic receptor kinase 2',
#   ['GRK3', 'ADRBK2', 'BARK2']),
#  ('P32298',
#   'GRK4',
#   'G protein-coupled receptor kinase 4',
#   ['GRK4', 'GPRK2L', 'GPRK4']),
#  ('P34947', 'GRK5', 'G protein-coupled receptor kinase 5', ['GRK5', 'GPRK5']),
#  ('P43250', 'GRK6', 'G protein-coupled receptor kinase 6', ['GRK6', 'GPRK6']),
#  ('Q8WTQ7', 'GRK7', 'Rhodopsin kinase GRK7', ['GRK7', 'GPRK7']),
#  ('O95835',
#   'LATS1',
#   'Serine/threonine-protein kinase LATS1',
#   ['LATS1', 'WARTS']),
#  ('Q9NRM7',
#   'LATS2',
#   'Serine/threonine-protein kinase LATS2',
#   ['LATS2', 'KPM']),
#  ('Q9Y2H9',
#   'MAST1',
#   'Microtubule-associated serine/threonine-protein kinase 1',
#   ['MAST1', 'KIAA0973', 'SAST']),
#  ('Q6P0Q8',
#   'MAST2',
#   'Microtubule-associated serine/threonine-protein kinase 2',
#   ['MAST2', 'KIAA0807', 'MAST205']),
#  ('O60307',
#   'MAST3',
#   'Microtubule-associated serine/threonine-protein kinase 3',
#   ['MAST3', 'KIAA0561']),
#  ('O15021',
#   'MAST4',
#   'Microtubule-associated serine/threonine-protein kinase 4',
#   ['MAST4', 'KIAA0303']),
#  ('Q96GX5',
#   'MASTL',
#   'Serine/threonine-protein kinase greatwall',
#   ['MASTL', 'GW', 'GWL', 'THC2']),
#  ('O15530',
#   'PDPK1',
#   '3-phosphoinositide-dependent protein kinase 1',
#   ['PDPK1', 'PDK1']),
#  ('Q6A1A2',
#   'PDPK2P',
#   'Putative 3-phosphoinositide-dependent protein kinase 2',
#   ['PDPK2P', 'PDPK2']),
#  ('Q16512',
#   'PKN1',
#   'Serine/threonine-protein kinase N1',
#   ['PKN1', 'PAK1', 'PKN', 'PRK1', 'PRKCL1']),
#  ('Q16513',
#   'PKN2',
#   'Serine/threonine-protein kinase N2',
#   ['PKN2', 'PRK2', 'PRKCL2']),
#  ('Q6P5Z2', 'PKN3', 'Serine/threonine-protein kinase N3', ['PKN3', 'PKNBETA']),
#  ('P17612',
#   'PRKACA',
#   'cAMP-dependent protein kinase catalytic subunit alpha',
#   ['PRKACA', 'PKACA']),
#  ('P22694',
#   'PRKACB',
#   'cAMP-dependent protein kinase catalytic subunit beta',
#   ['PRKACB']),
#  ('P22612',
#   'PRKACG',
#   'cAMP-dependent protein kinase catalytic subunit gamma',
#   ['PRKACG']),
#  ('P17252',
#   'PRKCA',
#   'Protein kinase C alpha type',
#   ['PRKCA', 'PKCA', 'PRKACA']),
#  ('P05771',
#   'PRKCB',
#   'Protein kinase C beta type',
#   ['PRKCB', 'PKCB', 'PRKCB1']),
#  ('Q05655', 'PRKCD', 'Protein kinase C delta type', ['PRKCD']),
#  ('Q02156', 'PRKCE', 'Protein kinase C epsilon type', ['PRKCE', 'PKCE']),
#  ('P05129', 'PRKCG', 'Protein kinase C gamma type', ['PRKCG', 'PKCG']),
#  ('P24723', 'PRKCH', 'Protein kinase C eta type', ['PRKCH', 'PKCL', 'PRKCL']),
#  ('P41743', 'PRKCI', 'Protein kinase C iota type', ['PRKCI', 'DXS1179E']),
#  ('Q04759', 'PRKCQ', 'Protein kinase C theta type', ['PRKCQ', 'PRKCT']),
#  ('Q05513', 'PRKCZ', 'Protein kinase C zeta type', ['PRKCZ', 'PKC2']),
#  ('Q13976',
#   'PRKG1',
#   'cGMP-dependent protein kinase 1',
#   ['PRKG1', 'PRKG1B', 'PRKGR1A', 'PRKGR1B']),
#  ('Q13237', 'PRKG2', 'cGMP-dependent protein kinase 2', ['PRKG2', 'PRKGR2']),
#  ('P51817',
#   'PRKX',
#   'cAMP-dependent protein kinase catalytic subunit PRKX',
#   ['PRKX', 'PKX1']),
#  ('O43930', 'PRKY', 'Putative serine/threonine-protein kinase PRKY', ['PRKY']),
#  ('Q13464', 'ROCK1', 'Rho-associated protein kinase 1', ['ROCK1']),
#  ('O75116', 'ROCK2', 'Rho-associated protein kinase 2', ['ROCK2', 'KIAA0619']),
#  ('Q15418',
#   'RPS6KA1',
#   'Ribosomal protein S6 kinase alpha-1',
#   ['RPS6KA1', 'MAPKAPK1A', 'RSK1']),
#  ('Q15349',
#   'RPS6KA2',
#   'Ribosomal protein S6 kinase alpha-2',
#   ['RPS6KA2', 'MAPKAPK1C', 'RSK3']),
#  ('P51812',
#   'RPS6KA3',
#   'Ribosomal protein S6 kinase alpha-3',
#   ['RPS6KA3', 'ISPK1', 'MAPKAPK1B', 'RSK2']),
#  ('O75676',
#   'RPS6KA4',
#   'Ribosomal protein S6 kinase alpha-4',
#   ['RPS6KA4', 'MSK2']),
#  ('O75582',
#   'RPS6KA5',
#   'Ribosomal protein S6 kinase alpha-5',
#   ['RPS6KA5', 'MSK1']),
#  ('Q9UK32',
#   'RPS6KA6',
#   'Ribosomal protein S6 kinase alpha-6',
#   ['RPS6KA6', 'RSK4']),
#  ('P23443',
#   'RPS6KB1',
#   'Ribosomal protein S6 kinase beta-1',
#   ['RPS6KB1', 'STK14A']),
#  ('Q9UBS0',
#   'RPS6KB2',
#   'Ribosomal protein S6 kinase beta-2',
#   ['RPS6KB2', 'STK14B']),
#  ('O00141', 'SGK1', 'Serine/threonine-protein kinase Sgk1', ['SGK1', 'SGK']),
#  ('Q9HBY8', 'SGK2', 'Serine/threonine-protein kinase Sgk2', ['SGK2']),
#  ('Q96BR1',
#   'SGK3',
#   'Serine/threonine-protein kinase Sgk3',
#   ['SGK3', 'CISK', 'SGKL']),
#  ('Q15208', 'STK38', 'Serine/threonine-protein kinase 38', ['STK38', 'NDR1']),
#  ('Q9Y2H1',
#   'STK38L',
#   'Serine/threonine-protein kinase 38-like',
#   ['STK38L', 'KIAA0965', 'NDR2']),
#  ('Q8TDC3',
#   'BRSK1',
#   'Serine/threonine-protein kinase BRSK1',
#   ['BRSK1', 'KIAA1811', 'SAD1', 'SADB']),
#  ('Q8IWQ3',
#   'BRSK2',
#   'Serine/threonine-protein kinase BRSK2',
#   ['BRSK2', 'C11orf7', 'PEN11B', 'SADA', 'STK29', 'HUSSY-12']),
#  ('Q14012',
#   'CAMK1',
#   'Calcium/calmodulin-dependent protein kinase type 1',
#   ['CAMK1']),
#  ('Q8IU85',
#   'CAMK1D',
#   'Calcium/calmodulin-dependent protein kinase type 1D',
#   ['CAMK1D', 'CAMKID']),
#  ('Q96NX5',
#   'CAMK1G',
#   'Calcium/calmodulin-dependent protein kinase type 1G',
#   ['CAMK1G', 'CLICK3', 'VWS1']),
#  ('Q9UQM7',
#   'CAMK2A',
#   'Calcium/calmodulin-dependent protein kinase type II subunit alpha',
#   ['CAMK2A', 'CAMKA', 'KIAA0968']),
#  ('Q13554',
#   'CAMK2B',
#   'Calcium/calmodulin-dependent protein kinase type II subunit beta',
#   ['CAMK2B', 'CAM2', 'CAMK2', 'CAMKB']),
#  ('Q13557',
#   'CAMK2D',
#   'Calcium/calmodulin-dependent protein kinase type II subunit delta',
#   ['CAMK2D', 'CAMKD']),
#  ('Q13555',
#   'CAMK2G',
#   'Calcium/calmodulin-dependent protein kinase type II subunit gamma',
#   ['CAMK2G', 'CAMK', 'CAMK-II', 'CAMKG']),
#  ('Q16566',
#   'CAMK4',
#   'Calcium/calmodulin-dependent protein kinase type IV',
#   ['CAMK4', 'CAMK', 'CAMK-GR', 'CAMKIV']),
#  ('Q8NCB2', 'CAMKV', 'CaM kinase-like vesicle-associated protein', ['CAMKV']),
#  ('O14936',
#   'CASK',
#   'Peripheral plasma membrane protein CASK',
#   ['CASK', 'LIN2']),
#  ('O14757',
#   'CHEK1',
#   'Serine/threonine-protein kinase Chk1',
#   ['CHEK1', 'CHK1']),
#  ('O96017',
#   'CHEK2',
#   'Serine/threonine-protein kinase Chk2',
#   ['CHEK2', 'CDS1', 'CHK2', 'RAD53']),
#  ('P53355', 'DAPK1', 'Death-associated protein kinase 1', ['DAPK1', 'DAPK']),
#  ('Q9UIK4', 'DAPK2', 'Death-associated protein kinase 2', ['DAPK2']),
#  ('O43293', 'DAPK3', 'Death-associated protein kinase 3', ['DAPK3', 'ZIPK']),
#  ('O15075',
#   'DCLK1',
#   'Serine/threonine-protein kinase DCLK1',
#   ['DCLK1', 'DCAMKL1', 'DCDC3A', 'KIAA0369']),
#  ('Q8N568',
#   'DCLK2',
#   'Serine/threonine-protein kinase DCLK2',
#   ['DCLK2', 'DCAMKL2', 'DCDC3B', 'DCK2']),
#  ('Q9C098',
#   'DCLK3',
#   'Serine/threonine-protein kinase DCLK3',
#   ['DCLK3', 'DCAMKL3', 'DCDC3C', 'KIAA1765']),
#  ('P57058',
#   'HUNK',
#   'Hormonally up-regulated neu tumor-associated kinase',
#   ['HUNK', 'MAKV']),
#  ('O60229', 'KALRN', 'Kalirin', ['KALRN', 'DUET', 'DUO', 'HAPIP', 'TRAD']),
#  ('P49137', 'MAPKAPK2', 'MAP kinase-activated protein kinase 2', ['MAPKAPK2']),
#  ('Q16644', 'MAPKAPK3', 'MAP kinase-activated protein kinase 3', ['MAPKAPK3']),
#  ('Q8IW41',
#   'MAPKAPK5',
#   'MAP kinase-activated protein kinase 5',
#   ['MAPKAPK5', 'PRAK']),
#  ('Q9P0L2',
#   'MARK1',
#   'Serine/threonine-protein kinase MARK1',
#   ['MARK1', 'KIAA1477', 'MARK']),
#  ('Q7KZI7',
#   'MARK2',
#   'Serine/threonine-protein kinase MARK2',
#   ['MARK2', 'EMK1']),
#  ('P27448',
#   'MARK3',
#   'MAP/microtubule affinity-regulating kinase 3',
#   ['MARK3', 'CTAK1', 'EMK2']),
#  ('Q96L34',
#   'MARK4',
#   'MAP/microtubule affinity-regulating kinase 4',
#   ['MARK4', 'KIAA1860', 'MARKL1']),
#  ('Q14680',
#   'MELK',
#   'Maternal embryonic leucine zipper kinase',
#   ['MELK', 'KIAA0175']),
#  ('Q9BUB5',
#   'MKNK1',
#   'MAP kinase-interacting serine/threonine-protein kinase 1',
#   ['MKNK1', 'MNK1']),
#  ('Q9HBH9',
#   'MKNK2',
#   'MAP kinase-interacting serine/threonine-protein kinase 2',
#   ['MKNK2', 'GPRK7', 'MNK2']),
#  ('Q15746',
#   'MYLK',
#   'Myosin light chain kinase, smooth muscle',
#   ['MYLK', 'MLCK', 'MLCK1', 'MYLK1']),
#  ('Q9H1R3',
#   'MYLK2',
#   'Myosin light chain kinase 2, skeletal/cardiac muscle',
#   ['MYLK2']),
#  ('Q32MK0', 'MYLK3', 'Myosin light chain kinase 3', ['MYLK3', 'MLCK']),
#  ('Q86YV6',
#   'MYLK4',
#   'Myosin light chain kinase family member 4',
#   ['MYLK4', 'SGK085']),
#  ('Q8IY84',
#   'NIM1K',
#   'Serine/threonine-protein kinase NIM1',
#   ['NIM1K', 'NIM1']),
#  ('O60285',
#   'NUAK1',
#   'NUAK family SNF1-like kinase 1',
#   ['NUAK1', 'ARK5', 'KIAA0537', 'OMPHK1']),
#  ('Q9H093',
#   'NUAK2',
#   'NUAK family SNF1-like kinase 2',
#   ['NUAK2', 'OMPHK2', 'SNARK']),
#  ('Q5VST9', 'OBSCN', 'Obscurin', ['OBSCN', 'KIAA1556', 'KIAA1639']),
#  ('Q96RG2',
#   'PASK',
#   'PAS domain-containing serine/threonine-protein kinase',
#   ['PASK', 'KIAA0135']),
#  ('Q16816',
#   'PHKG1',
#   'Phosphorylase b kinase gamma catalytic chain, skeletal muscle/heart isoform',
#   ['PHKG1', 'PHKG']),
#  ('P15735',
#   'PHKG2',
#   'Phosphorylase b kinase gamma catalytic chain, liver/testis isoform',
#   ['PHKG2']),
#  ('P11309', 'PIM1', 'Serine/threonine-protein kinase pim-1', ['PIM1']),
#  ('Q9P1W9', 'PIM2', 'Serine/threonine-protein kinase pim-2', ['PIM2']),
#  ('Q86V86', 'PIM3', 'Serine/threonine-protein kinase pim-3', ['PIM3']),
#  ('Q6P2M8',
#   'PNCK',
#   'Calcium/calmodulin-dependent protein kinase type 1B',
#   ['PNCK']),
#  ('Q13131',
#   'PRKAA1',
#   "5'-AMP-activated protein kinase catalytic subunit alpha-1",
#   ['PRKAA1', 'AMPK1']),
#  ('P54646',
#   'PRKAA2',
#   "5'-AMP-activated protein kinase catalytic subunit alpha-2",
#   ['PRKAA2', 'AMPK', 'AMPK2']),
#  ('Q15139',
#   'PRKD1',
#   'Serine/threonine-protein kinase D1',
#   ['PRKD1', 'PKD', 'PKD1', 'PRKCM']),
#  ('Q9BZL6',
#   'PRKD2',
#   'Serine/threonine-protein kinase D2',
#   ['PRKD2', 'PKD2', 'HSPC187']),
#  ('O94806',
#   'PRKD3',
#   'Serine/threonine-protein kinase D3',
#   ['PRKD3', 'EPK2', 'PRKCN']),
#  ('P11801', 'PSKH1', 'Serine/threonine-protein kinase H1', ['PSKH1']),
#  ('Q96QS6', 'PSKH2', 'Serine/threonine-protein kinase H2', ['PSKH2']),
#  ('P57059',
#   'SIK1',
#   'Serine/threonine-protein kinase SIK1',
#   ['SIK1', 'SIK', 'SNF1LK']),
#  ('A0A0B4J2F2',
#   'SIK1B',
#   'Probable serine/threonine-protein kinase SIK1B',
#   ['SIK1B']),
#  ('Q9H0K1',
#   'SIK2',
#   'Serine/threonine-protein kinase SIK2',
#   ['SIK2', 'KIAA0781', 'QIK', 'SNF1LK2']),
#  ('Q9Y2K2',
#   'SIK3',
#   'Serine/threonine-protein kinase SIK3',
#   ['SIK3', 'KIAA0999', 'QSK', 'L19']),
#  ('Q9NRH2',
#   'SNRK',
#   'SNF-related serine/threonine-protein kinase',
#   ['SNRK', 'KIAA0096', 'SNFRK']),
#  ('Q15772',
#   'SPEG',
#   'Striated muscle preferentially expressed protein kinase',
#   ['SPEG', 'APEG1', 'KIAA1297']),
#  ('Q15831',
#   'STK11',
#   'Serine/threonine-protein kinase STK11',
#   ['STK11', 'LKB1', 'PJS']),
#  ('Q9UEE5',
#   'STK17A',
#   'Serine/threonine-protein kinase 17A',
#   ['STK17A', 'DRAK1']),
#  ('O94768',
#   'STK17B',
#   'Serine/threonine-protein kinase 17B',
#   ['STK17B', 'DRAK2']),
#  ('Q9BYT3', 'STK33', 'Serine/threonine-protein kinase 33', ['STK33']),
#  ('Q8N2I9',
#   'STK40',
#   'Serine/threonine-protein kinase 40',
#   ['STK40', 'SGK495', 'SHIK']),
#  ('Q96RU8', 'TRIB1', 'Tribbles homolog 1', ['TRIB1', 'C8FW', 'GIG2', 'TRB1']),
#  ('Q92519', 'TRIB2', 'Tribbles homolog 2', ['TRIB2', 'TRB2']),
#  ('Q96RU7',
#   'TRIB3',
#   'Tribbles homolog 3',
#   ['TRIB3', 'C20orf97', 'NIPK', 'SKIP3', 'TRB3']),
#  ('O75962', 'TRIO', 'Triple functional domain protein', ['TRIO']),
#  ('Q9BXA7',
#   'TSSK1B',
#   'Testis-specific serine/threonine-protein kinase 1',
#   ['TSSK1B', 'SPOGA1', 'SPOGA4', 'STK22A', 'STK22D', 'TSSK1', 'FKSG81']),
#  ('Q96PF2',
#   'TSSK2',
#   'Testis-specific serine/threonine-protein kinase 2',
#   ['TSSK2', 'DGSG', 'SPOGA2', 'STK22B']),
#  ('Q96PN8',
#   'TSSK3',
#   'Testis-specific serine/threonine-protein kinase 3',
#   ['TSSK3', 'SPOGA3', 'STK22C']),
#  ('Q6SA08',
#   'TSSK4',
#   'Testis-specific serine/threonine-protein kinase 4',
#   ['TSSK4', 'C14orf20', 'STK22E', 'TSSK5']),
#  ('Q9BXA6',
#   'TSSK6',
#   'Testis-specific serine/threonine-protein kinase 6',
#   ['TSSK6', 'SSTK', 'FKSG82']),
#  ('Q8WZ42', 'TTN', 'Titin', ['TTN']),
#  ('P48729', 'CSNK1A1', 'Casein kinase I isoform alpha', ['CSNK1A1']),
#  ('Q8N752', 'CSNK1A1L', 'Casein kinase I isoform alpha-like', ['CSNK1A1L']),
#  ('P48730', 'CSNK1D', 'Casein kinase I isoform delta', ['CSNK1D', 'HCKID']),
#  ('P49674', 'CSNK1E', 'Casein kinase I isoform epsilon', ['CSNK1E']),
#  ('Q9HCP0', 'CSNK1G1', 'Casein kinase I isoform gamma-1', ['CSNK1G1']),
#  ('P78368',
#   'CSNK1G2',
#   'Casein kinase I isoform gamma-2',
#   ['CSNK1G2', 'CK1G2']),
#  ('Q9Y6M4', 'CSNK1G3', 'Casein kinase I isoform gamma-3', ['CSNK1G3']),
#  ('Q5TCY1', 'TTBK1', 'Tau-tubulin kinase 1', ['TTBK1', 'BDTK', 'KIAA1855']),
#  ('Q6IQ55', 'TTBK2', 'Tau-tubulin kinase 2', ['TTBK2', 'KIAA0847']),
#  ('Q99986', 'VRK1', 'Serine/threonine-protein kinase VRK1', ['VRK1']),
#  ('Q86Y07', 'VRK2', 'Serine/threonine-protein kinase VRK2', ['VRK2']),
#  ('Q8IV63', 'VRK3', 'Inactive serine/threonine-protein kinase VRK3', ['VRK3']),
#  ('P06493',
#   'CDK1',
#   'Cyclin-dependent kinase 1',
#   ['CDK1', 'CDC2', 'CDC28A', 'CDKN1', 'P34CDC2']),
#  ('Q15131', 'CDK10', 'Cyclin-dependent kinase 10', ['CDK10']),
#  ('Q9UQ88',
#   'CDK11A',
#   'Cyclin-dependent kinase 11A',
#   ['CDK11A', 'CDC2L2', 'CDC2L3', 'PITSLREB']),
#  ('P21127',
#   'CDK11B',
#   'Cyclin-dependent kinase 11B',
#   ['CDK11B', 'CDC2L1', 'CDK11', 'PITSLREA', 'PK58']),
#  ('Q9NYV4',
#   'CDK12',
#   'Cyclin-dependent kinase 12',
#   ['CDK12', 'CRK7', 'CRKRS', 'KIAA0904']),
#  ('Q14004',
#   'CDK13',
#   'Cyclin-dependent kinase 13',
#   ['CDK13', 'CDC2L', 'CDC2L5', 'CHED', 'KIAA1791']),
#  ('O94921',
#   'CDK14',
#   'Cyclin-dependent kinase 14',
#   ['CDK14', 'KIAA0834', 'PFTK1']),
#  ('Q96Q40',
#   'CDK15',
#   'Cyclin-dependent kinase 15',
#   ['CDK15', 'ALS2CR7', 'PFTK2']),
#  ('Q00536',
#   'CDK16',
#   'Cyclin-dependent kinase 16',
#   ['CDK16', 'PCTAIRE1', 'PCTK1']),
#  ('Q00537',
#   'CDK17',
#   'Cyclin-dependent kinase 17',
#   ['CDK17', 'PCTAIRE2', 'PCTK2']),
#  ('Q07002',
#   'CDK18',
#   'Cyclin-dependent kinase 18',
#   ['CDK18', 'PCTAIRE3', 'PCTK3']),
#  ('Q9BWU1',
#   'CDK19',
#   'Cyclin-dependent kinase 19',
#   ['CDK19', 'CDC2L6', 'CDK11', 'KIAA1028']),
#  ('P24941', 'CDK2', 'Cyclin-dependent kinase 2', ['CDK2', 'CDKN2']),
#  ('Q8IZL9', 'CDK20', 'Cyclin-dependent kinase 20', ['CDK20', 'CCRK', 'CDCH']),
#  ('Q00526', 'CDK3', 'Cyclin-dependent kinase 3', ['CDK3', 'CDKN3']),
#  ('P11802', 'CDK4', 'Cyclin-dependent kinase 4', ['CDK4']),
#  ('Q00535', 'CDK5', 'Cyclin-dependent-like kinase 5', ['CDK5', 'CDKN5']),
#  ('Q00534', 'CDK6', 'Cyclin-dependent kinase 6', ['CDK6', 'CDKN6']),
#  ('P50613',
#   'CDK7',
#   'Cyclin-dependent kinase 7',
#   ['CDK7', 'CAK', 'CAK1', 'CDKN7', 'MO15', 'STK1']),
#  ('P49336', 'CDK8', 'Cyclin-dependent kinase 8', ['CDK8']),
#  ('P50750', 'CDK9', 'Cyclin-dependent kinase 9', ['CDK9', 'CDC2L4', 'TAK']),
#  ('Q00532', 'CDKL1', 'Cyclin-dependent kinase-like 1', ['CDKL1']),
#  ('Q92772', 'CDKL2', 'Cyclin-dependent kinase-like 2', ['CDKL2']),
#  ('Q8IVW4', 'CDKL3', 'Cyclin-dependent kinase-like 3', ['CDKL3', 'NKIAMRE']),
#  ('Q5MAI5', 'CDKL4', 'Cyclin-dependent kinase-like 4', ['CDKL4']),
#  ('O76039', 'CDKL5', 'Cyclin-dependent kinase-like 5', ['CDKL5', 'STK9']),
#  ('P49759', 'CLK1', 'Dual specificity protein kinase CLK1', ['CLK1', 'CLK']),
#  ('P49760', 'CLK2', 'Dual specificity protein kinase CLK2', ['CLK2']),
#  ('P49761', 'CLK3', 'Dual specificity protein kinase CLK3', ['CLK3']),
#  ('Q9HAZ1', 'CLK4', 'Dual specificity protein kinase CLK4', ['CLK4']),
#  ('Q13627',
#   'DYRK1A',
#   'Dual specificity tyrosine-phosphorylation-regulated kinase 1A',
#   ['DYRK1A', 'DYRK', 'MNB', 'MNBH']),
#  ('Q9Y463',
#   'DYRK1B',
#   'Dual specificity tyrosine-phosphorylation-regulated kinase 1B',
#   ['DYRK1B', 'MIRK']),
#  ('Q92630',
#   'DYRK2',
#   'Dual specificity tyrosine-phosphorylation-regulated kinase 2',
#   ['DYRK2']),
#  ('O43781',
#   'DYRK3',
#   'Dual specificity tyrosine-phosphorylation-regulated kinase 3',
#   ['DYRK3']),
#  ('Q9NR20',
#   'DYRK4',
#   'Dual specificity tyrosine-phosphorylation-regulated kinase 4',
#   ['DYRK4']),
#  ('P49840', 'GSK3A', 'Glycogen synthase kinase-3 alpha', ['GSK3A']),
#  ('P49841', 'GSK3B', 'Glycogen synthase kinase-3 beta', ['GSK3B']),
#  ('Q86Z02',
#   'HIPK1',
#   'Homeodomain-interacting protein kinase 1',
#   ['HIPK1', 'KIAA0630', 'MYAK', 'NBAK2']),
#  ('Q9H2X6', 'HIPK2', 'Homeodomain-interacting protein kinase 2', ['HIPK2']),
#  ('Q9H422',
#   'HIPK3',
#   'Homeodomain-interacting protein kinase 3',
#   ['HIPK3', 'DYRK6', 'FIST3', 'PKY']),
#  ('Q8NE63', 'HIPK4', 'Homeodomain-interacting protein kinase 4', ['HIPK4']),
#  ('Q9UPZ9', 'ICK', 'Serine/threonine-protein kinase ICK', ['ICK', 'KIAA0936']),
#  ('P20794', 'MAK', 'Serine/threonine-protein kinase MAK', ['MAK']),
#  ('P28482',
#   'MAPK1',
#   'Mitogen-activated protein kinase 1',
#   ['MAPK1', 'ERK2', 'PRKM1', 'PRKM2']),
#  ('P53779',
#   'MAPK10',
#   'Mitogen-activated protein kinase 10',
#   ['MAPK10', 'JNK3', 'JNK3A', 'PRKM10', 'SAPK1B']),
#  ('Q15759',
#   'MAPK11',
#   'Mitogen-activated protein kinase 11',
#   ['MAPK11', 'PRKM11', 'SAPK2', 'SAPK2B']),
#  ('P53778',
#   'MAPK12',
#   'Mitogen-activated protein kinase 12',
#   ['MAPK12', 'ERK6', 'SAPK3']),
#  ('O15264',
#   'MAPK13',
#   'Mitogen-activated protein kinase 13',
#   ['MAPK13', 'PRKM13', 'SAPK4']),
#  ('Q16539',
#   'MAPK14',
#   'Mitogen-activated protein kinase 14',
#   ['MAPK14', 'CSBP', 'CSBP1', 'CSBP2', 'CSPB1', 'MXI2', 'SAPK2A']),
#  ('Q8TD08',
#   'MAPK15',
#   'Mitogen-activated protein kinase 15',
#   ['MAPK15', 'ERK7', 'ERK8']),
#  ('P27361',
#   'MAPK3',
#   'Mitogen-activated protein kinase 3',
#   ['MAPK3', 'ERK1', 'PRKM3']),
#  ('P31152',
#   'MAPK4',
#   'Mitogen-activated protein kinase 4',
#   ['MAPK4', 'ERK4', 'PRKM4']),
#  ('Q16659',
#   'MAPK6',
#   'Mitogen-activated protein kinase 6',
#   ['MAPK6', 'ERK3', 'PRKM6']),
#  ('Q13164',
#   'MAPK7',
#   'Mitogen-activated protein kinase 7',
#   ['MAPK7', 'BMK1', 'ERK5', 'PRKM7']),
#  ('P45983',
#   'MAPK8',
#   'Mitogen-activated protein kinase 8',
#   ['MAPK8', 'JNK1', 'PRKM8', 'SAPK1', 'SAPK1C']),
#  ('P45984',
#   'MAPK9',
#   'Mitogen-activated protein kinase 9',
#   ['MAPK9', 'JNK2', 'PRKM9', 'SAPK1A']),
#  ('Q9UQ07',
#   'MOK',
#   'MAPK/MAK/MRK overlapping kinase',
#   ['MOK', 'RAGE', 'RAGE1']),
#  ('Q9UBE8', 'NLK', 'Serine/threonine-protein kinase NLK', ['NLK', 'LAK1']),
#  ('Q13523',
#   'PRPF4B',
#   'Serine/threonine-protein kinase PRP4 homolog',
#   ['PRPF4B', 'KIAA0536', 'PRP4', 'PRP4H', 'PRP4K']),
#  ('Q96SB4', 'SRPK1', 'SRSF protein kinase 1', ['SRPK1']),
#  ('P78362', 'SRPK2', 'SRSF protein kinase 2', ['SRPK2']),
#  ('Q9UPE1', 'SRPK3', 'SRSF protein kinase 3', ['SRPK3', 'MSSK1', 'STK23']),
#  ('Q96PY6',
#   'NEK1',
#   'Serine/threonine-protein kinase Nek1',
#   ['NEK1', 'KIAA1901']),
#  ('Q6ZWH5', 'NEK10', 'Serine/threonine-protein kinase Nek10', ['NEK10']),
#  ('Q8NG66', 'NEK11', 'Serine/threonine-protein kinase Nek11', ['NEK11']),
#  ('P51955',
#   'NEK2',
#   'Serine/threonine-protein kinase Nek2',
#   ['NEK2', 'NEK2A', 'NLK1']),
#  ('P51956', 'NEK3', 'Serine/threonine-protein kinase Nek3', ['NEK3']),
#  ('P51957', 'NEK4', 'Serine/threonine-protein kinase Nek4', ['NEK4', 'STK2']),
#  ('Q6P3R8', 'NEK5', 'Serine/threonine-protein kinase Nek5', ['NEK5']),
#  ('Q9HC98', 'NEK6', 'Serine/threonine-protein kinase Nek6', ['NEK6']),
#  ('Q8TDX7', 'NEK7', 'Serine/threonine-protein kinase Nek7', ['NEK7']),
#  ('Q86SG6',
#   'NEK8',
#   'Serine/threonine-protein kinase Nek8',
#   ['NEK8', 'JCK', 'NEK12A']),
#  ('Q8TD19',
#   'NEK9',
#   'Serine/threonine-protein kinase Nek9',
#   ['NEK9', 'KIAA1995', 'NEK8', 'NERCC']),
#  ('P25092',
#   'GUCY2C',
#   'Heat-stable enterotoxin receptor',
#   ['GUCY2C', 'GUC2C', 'STAR']),
#  ('Q02846',
#   'GUCY2D',
#   'Retinal guanylyl cyclase 1',
#   ['GUCY2D', 'CORD6', 'GUC1A4', 'GUC2D', 'RETGC', 'RETGC1']),
#  ('P51841',
#   'GUCY2F',
#   'Retinal guanylyl cyclase 2',
#   ['GUCY2F', 'GUC2F', 'RETGC2']),
#  ('P16066',
#   'NPR1',
#   'Atrial natriuretic peptide receptor 1',
#   ['NPR1', 'ANPRA']),
#  ('P20594',
#   'NPR2',
#   'Atrial natriuretic peptide receptor 2',
#   ['NPR2', 'ANPRB']),
#  ('Q02750',
#   'MAP2K1',
#   'Dual specificity mitogen-activated protein kinase kinase 1',
#   ['MAP2K1', 'MEK1', 'PRKMK1']),
#  ('P36507',
#   'MAP2K2',
#   'Dual specificity mitogen-activated protein kinase kinase 2',
#   ['MAP2K2', 'MEK2', 'MKK2', 'PRKMK2']),
#  ('P46734',
#   'MAP2K3',
#   'Dual specificity mitogen-activated protein kinase kinase 3',
#   ['MAP2K3', 'MEK3', 'MKK3', 'PRKMK3', 'SKK2']),
#  ('P45985',
#   'MAP2K4',
#   'Dual specificity mitogen-activated protein kinase kinase 4',
#   ['MAP2K4', 'JNKK1', 'MEK4', 'MKK4', 'PRKMK4', 'SEK1', 'SERK1', 'SKK1']),
#  ('Q13163',
#   'MAP2K5',
#   'Dual specificity mitogen-activated protein kinase kinase 5',
#   ['MAP2K5', 'MEK5', 'MKK5', 'PRKMK5']),
#  ('P52564',
#   'MAP2K6',
#   'Dual specificity mitogen-activated protein kinase kinase 6',
#   ['MAP2K6', 'MEK6', 'MKK6', 'PRKMK6', 'SKK3']),
#  ('O14733',
#   'MAP2K7',
#   'Dual specificity mitogen-activated protein kinase kinase 7',
#   ['MAP2K7', 'JNKK2', 'MEK7', 'MKK7', 'PRKMK7', 'SKK4']),
#  ('Q13233',
#   'MAP3K1',
#   'Mitogen-activated protein kinase kinase kinase 1',
#   ['MAP3K1', 'MAPKKK1', 'MEKK', 'MEKK1']),
#  ('Q02779',
#   'MAP3K10',
#   'Mitogen-activated protein kinase kinase kinase 10',
#   ['MAP3K10', 'MLK2', 'MST']),
#  ('Q16584',
#   'MAP3K11',
#   'Mitogen-activated protein kinase kinase kinase 11',
#   ['MAP3K11', 'MLK3', 'PTK1', 'SPRK']),
#  ('Q12852',
#   'MAP3K12',
#   'Mitogen-activated protein kinase kinase kinase 12',
#   ['MAP3K12', 'ZPK']),
#  ('O43283',
#   'MAP3K13',
#   'Mitogen-activated protein kinase kinase kinase 13',
#   ['MAP3K13', 'LZK']),
#  ('Q99558',
#   'MAP3K14',
#   'Mitogen-activated protein kinase kinase kinase 14',
#   ['MAP3K14', 'NIK']),
#  ('Q6ZN16',
#   'MAP3K15',
#   'Mitogen-activated protein kinase kinase kinase 15',
#   ['MAP3K15', 'ASK3']),
#  ('Q56UN5',
#   'MAP3K19',
#   'Mitogen-activated protein kinase kinase kinase 19',
#   ['MAP3K19', 'RCK', 'YSK4']),
#  ('Q9Y2U5',
#   'MAP3K2',
#   'Mitogen-activated protein kinase kinase kinase 2',
#   ['MAP3K2', 'MAPKKK2', 'MEKK2']),
#  ('Q9NYL2',
#   'MAP3K20',
#   'Mitogen-activated protein kinase kinase kinase 20',
#   ['MAP3K20', 'MLTK', 'ZAK', 'HCCS4']),
#  ('Q5TCX8',
#   'MAP3K21',
#   'Mitogen-activated protein kinase kinase kinase 21',
#   ['MAP3K21', 'KIAA1804', 'MLK4']),
#  ('Q99759',
#   'MAP3K3',
#   'Mitogen-activated protein kinase kinase kinase 3',
#   ['MAP3K3', 'MAPKKK3', 'MEKK3']),
#  ('Q9Y6R4',
#   'MAP3K4',
#   'Mitogen-activated protein kinase kinase kinase 4',
#   ['MAP3K4', 'KIAA0213', 'MAPKKK4', 'MEKK4', 'MTK1']),
#  ('Q99683',
#   'MAP3K5',
#   'Mitogen-activated protein kinase kinase kinase 5',
#   ['MAP3K5', 'ASK1', 'MAPKKK5', 'MEKK5']),
#  ('O95382',
#   'MAP3K6',
#   'Mitogen-activated protein kinase kinase kinase 6',
#   ['MAP3K6', 'ASK2', 'MAPKKK6', 'MEKK6']),
#  ('O43318',
#   'MAP3K7',
#   'Mitogen-activated protein kinase kinase kinase 7',
#   ['MAP3K7', 'TAK1']),
#  ('P41279',
#   'MAP3K8',
#   'Mitogen-activated protein kinase kinase kinase 8',
#   ['MAP3K8', 'COT', 'ESTF']),
#  ('P80192',
#   'MAP3K9',
#   'Mitogen-activated protein kinase kinase kinase 9',
#   ['MAP3K9', 'MLK1', 'PRKE1']),
#  ('Q92918',
#   'MAP4K1',
#   'Mitogen-activated protein kinase kinase kinase kinase 1',
#   ['MAP4K1', 'HPK1']),
#  ('Q12851',
#   'MAP4K2',
#   'Mitogen-activated protein kinase kinase kinase kinase 2',
#   ['MAP4K2', 'GCK', 'RAB8IP']),
#  ('Q8IVH8',
#   'MAP4K3',
#   'Mitogen-activated protein kinase kinase kinase kinase 3',
#   ['MAP4K3', 'RAB8IPL1']),
#  ('O95819',
#   'MAP4K4',
#   'Mitogen-activated protein kinase kinase kinase kinase 4',
#   ['MAP4K4', 'HGK', 'KIAA0687', 'NIK']),
#  ('Q9Y4K4',
#   'MAP4K5',
#   'Mitogen-activated protein kinase kinase kinase kinase 5',
#   ['MAP4K5']),
#  ('Q8N4C8',
#   'MINK1',
#   'Misshapen-like kinase 1',
#   ['MINK1', 'B55', 'MAP4K6', 'MINK', 'YSK2', 'ZC3']),
#  ('Q8NEV4', 'MYO3A', 'Myosin-IIIa', ['MYO3A']),
#  ('Q8WXR4', 'MYO3B', 'Myosin-IIIb', ['MYO3B']),
#  ('Q7Z2Y5', 'NRK', 'Nik-related protein kinase', ['NRK']),
#  ('O95747',
#   'OXSR1',
#   'Serine/threonine-protein kinase OSR1',
#   ['OXSR1', 'KIAA1101', 'OSR1']),
#  ('Q13153', 'PAK1', 'Serine/threonine-protein kinase PAK 1', ['PAK1']),
#  ('Q13177', 'PAK2', 'Serine/threonine-protein kinase PAK 2', ['PAK2']),
#  ('O75914',
#   'PAK3',
#   'Serine/threonine-protein kinase PAK 3',
#   ['PAK3', 'OPHN3']),
#  ('O96013',
#   'PAK4',
#   'Serine/threonine-protein kinase PAK 4',
#   ['PAK4', 'KIAA1142']),
#  ('Q9P286',
#   'PAK5',
#   'Serine/threonine-protein kinase PAK 5',
#   ['PAK5', 'KIAA1264', 'PAK7']),
#  ('Q9NQU5', 'PAK6', 'Serine/threonine-protein kinase PAK 6', ['PAK6', 'PAK5']),
#  ('Q96KB5',
#   'PBK',
#   'Lymphokine-activated killer T-cell-originated protein kinase',
#   ['PBK', 'TOPK']),
#  ('Q9H2G2',
#   'SLK',
#   'STE20-like serine/threonine-protein kinase',
#   ['SLK', 'KIAA0204', 'STK2']),
#  ('O94804', 'STK10', 'Serine/threonine-protein kinase 10', ['STK10', 'LOK']),
#  ('Q9Y6E0',
#   'STK24',
#   'Serine/threonine-protein kinase 24',
#   ['STK24', 'MST3', 'STK3']),
#  ('O00506',
#   'STK25',
#   'Serine/threonine-protein kinase 25',
#   ['STK25', 'SOK1', 'YSK1']),
#  ('Q9P289',
#   'STK26',
#   'Serine/threonine-protein kinase 26',
#   ['STK26', 'MASK', 'MST4']),
#  ('Q13188',
#   'STK3',
#   'Serine/threonine-protein kinase 3',
#   ['STK3', 'KRS1', 'MST2']),
#  ('Q9UEW8',
#   'STK39',
#   'STE20/SPS1-related proline-alanine-rich protein kinase',
#   ['STK39', 'SPAK']),
#  ('Q13043',
#   'STK4',
#   'Serine/threonine-protein kinase 4',
#   ['STK4', 'KRS2', 'MST1']),
#  ('Q7RTN6',
#   'STRADA',
#   'STE20-related kinase adapter protein alpha',
#   ['STRADA', 'LYK5', 'STRAD']),
#  ('Q9C0K7',
#   'STRADB',
#   'STE20-related kinase adapter protein beta',
#   ['STRADB', 'ALS2CR2', 'ILPIP', 'PRO1038']),
#  ('Q7L7X3',
#   'TAOK1',
#   'Serine/threonine-protein kinase TAO1',
#   ['TAOK1', 'KIAA1361', 'MAP3K16', 'MARKK']),
#  ('Q9UL54',
#   'TAOK2',
#   'Serine/threonine-protein kinase TAO2',
#   ['TAOK2', 'KIAA0881', 'MAP3K17', 'PSK', 'PSK1', 'UNQ2971/PRO7431']),
#  ('Q9H2K8',
#   'TAOK3',
#   'Serine/threonine-protein kinase TAO3',
#   ['TAOK3', 'DPK', 'JIK', 'KDS', 'MAP3K18']),
#  ('Q9UKE5',
#   'TNIK',
#   'TRAF2 and NCK-interacting protein kinase',
#   ['TNIK', 'KIAA0551']),
#  ('Q04771', 'ACVR1', 'Activin receptor type-1', ['ACVR1', 'ACVRLK2']),
#  ('P36896',
#   'ACVR1B',
#   'Activin receptor type-1B',
#   ['ACVR1B', 'ACVRLK4', 'ALK4']),
#  ('Q8NER5', 'ACVR1C', 'Activin receptor type-1C', ['ACVR1C', 'ALK7']),
#  ('P27037', 'ACVR2A', 'Activin receptor type-2A', ['ACVR2A', 'ACVR2']),
#  ('Q13705', 'ACVR2B', 'Activin receptor type-2B', ['ACVR2B']),
#  ('P37023',
#   'ACVRL1',
#   'Serine/threonine-protein kinase receptor R3',
#   ['ACVRL1', 'ACVRLK1', 'ALK1']),
#  ('Q16671',
#   'AMHR2',
#   'Anti-Muellerian hormone type-2 receptor',
#   ['AMHR2', 'AMHR', 'MISR2']),
#  ('Q8NFD2',
#   'ANKK1',
#   'Ankyrin repeat and protein kinase domain-containing protein 1',
#   ['ANKK1', 'PKK2', 'SGK288']),
#  ('P10398',
#   'ARAF',
#   'Serine/threonine-protein kinase A-Raf',
#   ['ARAF', 'ARAF1', 'PKS', 'PKS2']),
#  ('P36894',
#   'BMPR1A',
#   'Bone morphogenetic protein receptor type-1A',
#   ['BMPR1A', 'ACVRLK3', 'ALK3']),
#  ('O00238',
#   'BMPR1B',
#   'Bone morphogenetic protein receptor type-1B',
#   ['BMPR1B']),
#  ('Q13873',
#   'BMPR2',
#   'Bone morphogenetic protein receptor type-2',
#   ['BMPR2', 'PPH1']),
#  ('P15056',
#   'BRAF',
#   'Serine/threonine-protein kinase B-raf',
#   ['BRAF', 'BRAF1', 'RAFB1']),
#  ('Q13418', 'ILK', 'Integrin-linked protein kinase', ['ILK', 'ILK1', 'ILK2']),
#  ('P51617',
#   'IRAK1',
#   'Interleukin-1 receptor-associated kinase 1',
#   ['IRAK1', 'IRAK']),
#  ('O43187',
#   'IRAK2',
#   'Interleukin-1 receptor-associated kinase-like 2',
#   ['IRAK2']),
#  ('Q9Y616', 'IRAK3', 'Interleukin-1 receptor-associated kinase 3', ['IRAK3']),
#  ('Q9NWZ3', 'IRAK4', 'Interleukin-1 receptor-associated kinase 4', ['IRAK4']),
#  ('Q8IVT5', 'KSR1', 'Kinase suppressor of Ras 1', ['KSR1', 'KSR']),
#  ('Q6VAB6', 'KSR2', 'Kinase suppressor of Ras 2', ['KSR2']),
#  ('P53667', 'LIMK1', 'LIM domain kinase 1', ['LIMK1', 'LIMK']),
#  ('P53671', 'LIMK2', 'LIM domain kinase 2', ['LIMK2']),
#  ('Q38SD2',
#   'LRRK1',
#   'Leucine-rich repeat serine/threonine-protein kinase 1',
#   ['LRRK1', 'KIAA1790']),
#  ('Q5S007',
#   'LRRK2',
#   'Leucine-rich repeat serine/threonine-protein kinase 2',
#   ['LRRK2', 'PARK8']),
#  ('P04049',
#   'RAF1',
#   'RAF proto-oncogene serine/threonine-protein kinase',
#   ['RAF1', 'RAF']),
#  ('Q13546',
#   'RIPK1',
#   'Receptor-interacting serine/threonine-protein kinase 1',
#   ['RIPK1', 'RIP', 'RIP1']),
#  ('O43353',
#   'RIPK2',
#   'Receptor-interacting serine/threonine-protein kinase 2',
#   ['RIPK2', 'CARDIAK', 'RICK', 'RIP2', 'UNQ277/PRO314/PRO34092']),
#  ('Q9Y572',
#   'RIPK3',
#   'Receptor-interacting serine/threonine-protein kinase 3',
#   ['RIPK3', 'RIP3']),
#  ('P57078',
#   'RIPK4',
#   'Receptor-interacting serine/threonine-protein kinase 4',
#   ['RIPK4', 'ANKRD3', 'DIK']),
#  ('Q15569',
#   'TESK1',
#   'Dual specificity testis-specific protein kinase 1',
#   ['TESK1']),
#  ('Q96S53',
#   'TESK2',
#   'Dual specificity testis-specific protein kinase 2',
#   ['TESK2']),
#  ('P36897', 'TGFBR1', 'TGF-beta receptor type-1', ['TGFBR1', 'ALK5', 'SKR4']),
#  ('P37173', 'TGFBR2', 'TGF-beta receptor type-2', ['TGFBR2']),
#  ('Q59H18',
#   'TNNI3K',
#   'Serine/threonine-protein kinase TNNI3K',
#   ['TNNI3K', 'CARK']),
#  ('Q6ZMQ8',
#   'AATK',
#   'Serine/threonine-protein kinase LMTK1',
#   ['AATK', 'AATYK', 'KIAA0641', 'LMR1', 'LMTK1']),
#  ('P00519', 'ABL1', 'Tyrosine-protein kinase ABL1', ['ABL1', 'ABL', 'JTK7']),
#  ('P42684', 'ABL2', 'Tyrosine-protein kinase ABL2', ['ABL2', 'ABLL', 'ARG']),
#  ('Q9UM73', 'ALK', 'ALK tyrosine kinase receptor', ['ALK']),
#  ('P30530', 'AXL', 'Tyrosine-protein kinase receptor UFO', ['AXL', 'UFO']),
#  ('P51451', 'BLK', 'Tyrosine-protein kinase Blk', ['BLK']),
#  ('P51813', 'BMX', 'Cytoplasmic tyrosine-protein kinase BMX', ['BMX']),
#  ('Q06187',
#   'BTK',
#   'Tyrosine-protein kinase BTK',
#   ['BTK', 'AGMX1', 'ATK', 'BPK']),
#  ('P07333',
#   'CSF1R',
#   'Macrophage colony-stimulating factor 1 receptor',
#   ['CSF1R', 'FMS']),
#  ('P41240', 'CSK', 'Tyrosine-protein kinase CSK', ['CSK']),
#  ('Q08345',
#   'DDR1',
#   'Epithelial discoidin domain-containing receptor 1',
#   ['DDR1', 'CAK', 'EDDR1', 'NEP', 'NTRK4', 'PTK3A', 'RTK6', 'TRKE']),
#  ('Q16832',
#   'DDR2',
#   'Discoidin domain-containing receptor 2',
#   ['DDR2', 'NTRKR3', 'TKT', 'TYRO10']),
#  ('P00533',
#   'EGFR',
#   'Epidermal growth factor receptor',
#   ['EGFR', 'ERBB', 'ERBB1', 'HER1']),
#  ('P21709',
#   'EPHA1',
#   'Ephrin type-A receptor 1',
#   ['EPHA1', 'EPH', 'EPHT', 'EPHT1']),
#  ('Q5JZY3', 'EPHA10', 'Ephrin type-A receptor 10', ['EPHA10']),
#  ('P29317', 'EPHA2', 'Ephrin type-A receptor 2', ['EPHA2', 'ECK']),
#  ('P29320',
#   'EPHA3',
#   'Ephrin type-A receptor 3',
#   ['EPHA3', 'ETK', 'ETK1', 'HEK', 'TYRO4']),
#  ('P54764',
#   'EPHA4',
#   'Ephrin type-A receptor 4',
#   ['EPHA4', 'HEK8', 'SEK', 'TYRO1']),
#  ('P54756',
#   'EPHA5',
#   'Ephrin type-A receptor 5',
#   ['EPHA5', 'BSK', 'EHK1', 'HEK7', 'TYRO4']),
#  ('Q9UF33', 'EPHA6', 'Ephrin type-A receptor 6', ['EPHA6', 'EHK2', 'HEK12']),
#  ('Q15375', 'EPHA7', 'Ephrin type-A receptor 7', ['EPHA7', 'EHK3', 'HEK11']),
#  ('P29322',
#   'EPHA8',
#   'Ephrin type-A receptor 8',
#   ['EPHA8', 'EEK', 'HEK3', 'KIAA1459']),
#  ('P54762',
#   'EPHB1',
#   'Ephrin type-B receptor 1',
#   ['EPHB1', 'ELK', 'EPHT2', 'HEK6', 'NET']),
#  ('P29323',
#   'EPHB2',
#   'Ephrin type-B receptor 2',
#   ['EPHB2', 'DRT', 'EPHT3', 'EPTH3', 'ERK', 'HEK5', 'TYRO5']),
#  ('P54753',
#   'EPHB3',
#   'Ephrin type-B receptor 3',
#   ['EPHB3', 'ETK2', 'HEK2', 'TYRO6']),
#  ('P54760',
#   'EPHB4',
#   'Ephrin type-B receptor 4',
#   ['EPHB4', 'HTK', 'MYK1', 'TYRO11']),
#  ('O15197', 'EPHB6', 'Ephrin type-B receptor 6', ['EPHB6']),
#  ('P04626',
#   'ERBB2',
#   'Receptor tyrosine-protein kinase erbB-2',
#   ['ERBB2', 'HER2', 'MLN19', 'NEU', 'NGL']),
#  ('P21860',
#   'ERBB3',
#   'Receptor tyrosine-protein kinase erbB-3',
#   ['ERBB3', 'HER3']),
#  ('Q15303',
#   'ERBB4',
#   'Receptor tyrosine-protein kinase erbB-4',
#   ['ERBB4', 'HER4']),
#  ('P16591', 'FER', 'Tyrosine-protein kinase Fer', ['FER', 'TYK3']),
#  ('P07332', 'FES', 'Tyrosine-protein kinase Fes/Fps', ['FES', 'FPS']),
#  ('P11362',
#   'FGFR1',
#   'Fibroblast growth factor receptor 1',
#   ['FGFR1', 'BFGFR', 'CEK', 'FGFBR', 'FLG', 'FLT2', 'HBGFR']),
#  ('P21802',
#   'FGFR2',
#   'Fibroblast growth factor receptor 2',
#   ['FGFR2', 'BEK', 'KGFR', 'KSAM']),
#  ('P22607', 'FGFR3', 'Fibroblast growth factor receptor 3', ['FGFR3', 'JTK4']),
#  ('P22455',
#   'FGFR4',
#   'Fibroblast growth factor receptor 4',
#   ['FGFR4', 'JTK2', 'TKF']),
#  ('P09769', 'FGR', 'Tyrosine-protein kinase Fgr', ['FGR', 'SRC2']),
#  ('P17948',
#   'FLT1',
#   'Vascular endothelial growth factor receptor 1',
#   ['FLT1', 'FLT', 'FRT', 'VEGFR1']),
#  ('P36888',
#   'FLT3',
#   'Receptor-type tyrosine-protein kinase FLT3',
#   ['FLT3', 'CD135', 'FLK2', 'STK1']),
#  ('P35916',
#   'FLT4',
#   'Vascular endothelial growth factor receptor 3',
#   ['FLT4', 'VEGFR3']),
#  ('P42685', 'FRK', 'Tyrosine-protein kinase FRK', ['FRK', 'PTK5', 'RAK']),
#  ('P06241', 'FYN', 'Tyrosine-protein kinase Fyn', ['FYN']),
#  ('P08631', 'HCK', 'Tyrosine-protein kinase HCK', ['HCK']),
#  ('P08069', 'IGF1R', 'Insulin-like growth factor 1 receptor', ['IGF1R']),
#  ('P06213', 'INSR', 'Insulin receptor', ['INSR']),
#  ('P14616', 'INSRR', 'Insulin receptor-related protein', ['INSRR', 'IRR']),
#  ('Q08881', 'ITK', 'Tyrosine-protein kinase ITK/TSK', ['ITK', 'EMT', 'LYK']),
#  ('P23458',
#   'JAK1',
#   'Tyrosine-protein kinase JAK1',
#   ['JAK1', 'JAK1A', 'JAK1B']),
#  ('O60674', 'JAK2', 'Tyrosine-protein kinase JAK2', ['JAK2']),
#  ('P52333', 'JAK3', 'Tyrosine-protein kinase JAK3', ['JAK3']),
#  ('P35968',
#   'KDR',
#   'Vascular endothelial growth factor receptor 2',
#   ['KDR', 'FLK1', 'VEGFR2']),
#  ('P10721',
#   'KIT',
#   'Mast/stem cell growth factor receptor Kit',
#   ['KIT', 'SCFR']),
#  ('P06239', 'LCK', 'Tyrosine-protein kinase Lck', ['LCK']),
#  ('Q8IWU2',
#   'LMTK2',
#   'Serine/threonine-protein kinase LMTK2',
#   ['LMTK2', 'AATYK2', 'BREK', 'KIAA1079', 'KPI2', 'LMR2']),
#  ('Q96Q04',
#   'LMTK3',
#   'Serine/threonine-protein kinase LMTK3',
#   ['LMTK3', 'KIAA1883', 'TYKLM3']),
#  ('P29376', 'LTK', 'Leukocyte tyrosine kinase receptor', ['LTK', 'TYK1']),
#  ('P07948', 'LYN', 'Tyrosine-protein kinase Lyn', ['LYN', 'JTK8']),
#  ('P42679',
#   'MATK',
#   'Megakaryocyte-associated tyrosine-protein kinase',
#   ['MATK', 'CTK', 'HYL']),
#  ('Q12866', 'MERTK', 'Tyrosine-protein kinase Mer', ['MERTK', 'MER']),
#  ('P08581', 'MET', 'Hepatocyte growth factor receptor', ['MET']),
#  ('Q04912',
#   'MST1R',
#   'Macrophage-stimulating protein receptor',
#   ['MST1R', 'PTK8', 'RON']),
#  ('O15146',
#   'MUSK',
#   'Muscle, skeletal receptor tyrosine-protein kinase',
#   ['MUSK']),
#  ('P04629',
#   'NTRK1',
#   'High affinity nerve growth factor receptor',
#   ['NTRK1', 'MTC', 'TRK', 'TRKA']),
#  ('Q16620', 'NTRK2', 'BDNF/NT-3 growth factors receptor', ['NTRK2', 'TRKB']),
#  ('Q16288', 'NTRK3', 'NT-3 growth factor receptor', ['NTRK3', 'TRKC']),
#  ('P16234',
#   'PDGFRA',
#   'Platelet-derived growth factor receptor alpha',
#   ['PDGFRA', 'PDGFR2', 'RHEPDGFRA']),
#  ('P09619',
#   'PDGFRB',
#   'Platelet-derived growth factor receptor beta',
#   ['PDGFRB', 'PDGFR', 'PDGFR1']),
#  ('Q05397', 'PTK2', 'Focal adhesion kinase 1', ['PTK2', 'FAK', 'FAK1']),
#  ('Q14289',
#   'PTK2B',
#   'Protein-tyrosine kinase 2-beta',
#   ['PTK2B', 'FAK2', 'PYK2', 'RAFTK']),
#  ('Q13882', 'PTK6', 'Protein-tyrosine kinase 6', ['PTK6', 'BRK']),
#  ('Q13308', 'PTK7', 'Inactive tyrosine-protein kinase 7', ['PTK7', 'CCK4']),
#  ('P07949',
#   'RET',
#   'Proto-oncogene tyrosine-protein kinase receptor Ret',
#   ['RET', 'CDHF12', 'CDHR16', 'PTC', 'RET51']),
#  ('Q01973',
#   'ROR1',
#   'Inactive tyrosine-protein kinase transmembrane receptor ROR1',
#   ['ROR1', 'NTRKR1']),
#  ('Q01974',
#   'ROR2',
#   'Tyrosine-protein kinase transmembrane receptor ROR2',
#   ['ROR2', 'NTRKR2']),
#  ('P08922',
#   'ROS1',
#   'Proto-oncogene tyrosine-protein kinase ROS',
#   ['ROS1', 'MCF3', 'ROS']),
#  ('P34925', 'RYK', 'Tyrosine-protein kinase RYK', ['RYK', 'JTK5A']),
#  ('P12931',
#   'SRC',
#   'Proto-oncogene tyrosine-protein kinase Src',
#   ['SRC', 'SRC1']),
#  ('Q9H3Y6', 'SRMS', 'Tyrosine-protein kinase Srms', ['SRMS', 'C20orf148']),
#  ('Q6J9G0', 'STYK1', 'Tyrosine-protein kinase STYK1', ['STYK1', 'NOK']),
#  ('P43405', 'SYK', 'Tyrosine-protein kinase SYK', ['SYK']),
#  ('P42680', 'TEC', 'Tyrosine-protein kinase Tec', ['TEC', 'PSCTK4']),
#  ('Q02763',
#   'TEK',
#   'Angiopoietin-1 receptor',
#   ['TEK', 'TIE2', 'VMCM', 'VMCM1']),
#  ('P35590', 'TIE1', 'Tyrosine-protein kinase receptor Tie-1', ['TIE1', 'TIE']),
#  ('Q13470', 'TNK1', 'Non-receptor tyrosine-protein kinase TNK1', ['TNK1']),
#  ('Q07912', 'TNK2', 'Activated CDC42 kinase 1', ['TNK2', 'ACK1']),
#  ('P42681', 'TXK', 'Tyrosine-protein kinase TXK', ['TXK', 'PTK4', 'RLK']),
#  ('P29597', 'TYK2', 'Non-receptor tyrosine-protein kinase TYK2', ['TYK2']),
#  ('Q06418',
#   'TYRO3',
#   'Tyrosine-protein kinase receptor TYRO3',
#   ['TYRO3', 'BYK', 'DTK', 'RSE', 'SKY', 'TIF']),
#  ('P07947', 'YES1', 'Tyrosine-protein kinase Yes', ['YES1', 'YES']),
#  ('P43403', 'ZAP70', 'Tyrosine-protein kinase ZAP-70', ['ZAP70', 'SRK']),
#  ('Q2M2I8', 'AAK1', 'AP2-associated protein kinase 1', ['AAK1', 'KIAA1048']),
#  ('O14965',
#   'AURKA',
#   'Aurora kinase A',
#   ['AURKA',
#    'AIK',
#    'AIRK1',
#    'ARK1',
#    'AURA',
#    'AYK1',
#    'BTAK',
#    'IAK1',
#    'STK15',
#    'STK6']),
#  ('Q96GD4',
#   'AURKB',
#   'Aurora kinase B',
#   ['AURKB', 'AIK2', 'AIM1', 'AIRK2', 'ARK2', 'STK1', 'STK12', 'STK5']),
#  ('Q9UQB9',
#   'AURKC',
#   'Aurora kinase C',
#   ['AURKC', 'AIE2', 'AIK3', 'AIRK3', 'ARK3', 'STK13']),
#  ('Q9NSY1',
#   'BMP2K',
#   'BMP-2-inducible protein kinase',
#   ['BMP2K', 'BIKE', 'HRIHFB2017']),
#  ('O43683',
#   'BUB1',
#   'Mitotic checkpoint serine/threonine-protein kinase BUB1',
#   ['BUB1', 'BUB1L']),
#  ('O60566',
#   'BUB1B',
#   'Mitotic checkpoint serine/threonine-protein kinase BUB1 beta',
#   ['BUB1B', 'BUBR1', 'MAD3L', 'SSK1']),
#  ('Q8N5S9',
#   'CAMKK1',
#   'Calcium/calmodulin-dependent protein kinase kinase 1',
#   ['CAMKK1', 'CAMKKA']),
#  ('Q96RR4',
#   'CAMKK2',
#   'Calcium/calmodulin-dependent protein kinase kinase 2',
#   ['CAMKK2', 'CAMKKB', 'KIAA0787']),
#  ('O00311',
#   'CDC7',
#   'Cell division cycle 7-related protein kinase',
#   ['CDC7', 'CDC7L1']),
#  ('O15111',
#   'CHUK',
#   'Inhibitor of nuclear factor kappa-B kinase subunit alpha',
#   ['CHUK', 'IKKA', 'TCF16']),
#  ('P68400', 'CSNK2A1', 'Casein kinase II subunit alpha', ['CSNK2A1', 'CK2A1']),
#  ('P19784',
#   'CSNK2A2',
#   "Casein kinase II subunit alpha'",
#   ['CSNK2A2', 'CK2A2']),
#  ('Q8NEV1',
#   'CSNK2A3',
#   'Casein kinase II subunit alpha 3',
#   ['CSNK2A3', 'CSNK2A1P']),
#  ('Q6XUX3',
#   'DSTYK',
#   'Dual serine/threonine and tyrosine protein kinase',
#   ['DSTYK', 'KIAA0472', 'RIP5', 'RIPK5', 'SGK496', 'HDCMD38P']),
#  ('Q9BQI3',
#   'EIF2AK1',
#   'Eukaryotic translation initiation factor 2-alpha kinase 1',
#   ['EIF2AK1', 'HRI', 'KIAA1369', 'PRO1362']),
#  ('P19525',
#   'EIF2AK2',
#   'Interferon-induced, double-stranded RNA-activated protein kinase',
#   ['EIF2AK2', 'PKR', 'PRKR']),
#  ('Q9NZJ5',
#   'EIF2AK3',
#   'Eukaryotic translation initiation factor 2-alpha kinase 3',
#   ['EIF2AK3', 'PEK', 'PERK']),
#  ('Q9P2K8',
#   'EIF2AK4',
#   'eIF-2-alpha kinase GCN2',
#   ['EIF2AK4', 'GCN2', 'KIAA1338']),
#  ('O75460',
#   'ERN1',
#   'Serine/threonine-protein kinase/endoribonuclease IRE1',
#   ['ERN1', 'IRE1']),
#  ('Q76MJ5',
#   'ERN2',
#   'Serine/threonine-protein kinase/endoribonuclease IRE2',
#   ['ERN2', 'IRE2']),
#  ('O14976', 'GAK', 'Cyclin-G-associated kinase', ['GAK']),
#  ('Q8TF76',
#   'HASPIN',
#   'Serine/threonine-protein kinase haspin',
#   ['HASPIN', 'GSG2']),
#  ('O14920',
#   'IKBKB',
#   'Inhibitor of nuclear factor kappa-B kinase subunit beta',
#   ['IKBKB', 'IKKB']),
#  ('Q14164',
#   'IKBKE',
#   'Inhibitor of nuclear factor kappa-B kinase subunit epsilon',
#   ['IKBKE', 'IKKE', 'IKKI', 'KIAA0151']),
#  ('Q8NB16', 'MLKL', 'Mixed lineage kinase domain-like protein', ['MLKL']),
#  ('P00540',
#   'MOS',
#   'Proto-oncogene serine/threonine-protein kinase mos',
#   ['MOS']),
#  ('Q9UHY1',
#   'NRBP1',
#   'Nuclear receptor-binding protein',
#   ['NRBP1', 'BCON3', 'NRBP']),
#  ('Q9NSY0',
#   'NRBP2',
#   'Nuclear receptor-binding protein 2',
#   ['NRBP2', 'PP9320', 'TRG16']),
#  ('Q58A45', 'PAN3', 'PAN2-PAN3 deadenylation complex subunit PAN3', ['PAN3']),
#  ('Q8N165',
#   'PDIK1L',
#   'Serine/threonine-protein kinase PDIK1L',
#   ['PDIK1L', 'CLIK1L']),
#  ('Q9H792',
#   'PEAK1',
#   'Inactive tyrosine-protein kinase PEAK1',
#   ['PEAK1', 'KIAA2002']),
#  ('Q99570',
#   'PIK3R4',
#   'Phosphoinositide 3-kinase regulatory subunit 4',
#   ['PIK3R4', 'VPS15']),
#  ('Q9BXM7',
#   'PINK1',
#   'Serine/threonine-protein kinase PINK1, mitochondrial',
#   ['PINK1']),
#  ('Q504Y2',
#   'PKDCC',
#   'Extracellular tyrosine-protein kinase PKDCC',
#   ['PKDCC', 'SGK493', 'VLK']),
#  ('Q99640',
#   'PKMYT1',
#   'Membrane-associated tyrosine- and threonine-specific cdc2-inhibitory kinase',
#   ['PKMYT1', 'MYT1']),
#  ('P53350', 'PLK1', 'Serine/threonine-protein kinase PLK1', ['PLK1', 'PLK']),
#  ('Q9NYY3', 'PLK2', 'Serine/threonine-protein kinase PLK2', ['PLK2', 'SNK']),
#  ('Q9H4B4',
#   'PLK3',
#   'Serine/threonine-protein kinase PLK3',
#   ['PLK3', 'CNK', 'FNK', 'PRK']),
#  ('O00444',
#   'PLK4',
#   'Serine/threonine-protein kinase PLK4',
#   ['PLK4', 'SAK', 'STK18']),
#  ('Q496M5',
#   'PLK5',
#   'Inactive serine/threonine-protein kinase PLK5',
#   ['PLK5', 'PLK5P', 'FG060302']),
#  ('Q9H5K3', 'POMK', 'Protein O-mannose kinase', ['POMK', 'SGK196']),
#  ('Q86YV5',
#   'PRAG1',
#   'Inactive tyrosine-protein kinase PRAG1',
#   ['PRAG1', 'SGK223']),
#  ('Q7Z7A4',
#   'PXK',
#   'PX domain-containing protein kinase-like protein',
#   ['PXK']),
#  ('Q05823', 'RNASEL', '2-5A-dependent ribonuclease', ['RNASEL', 'RNS4']),
#  ('Q96S38',
#   'RPS6KC1',
#   'Ribosomal protein S6 kinase delta-1',
#   ['RPS6KC1', 'RPK118']),
#  ('Q9Y6S9', 'RPS6KL1', 'Ribosomal protein S6 kinase-like 1', ['RPS6KL1']),
#  ('Q96LW2',
#   'RSKR',
#   'Ribosomal protein S6 kinase-related protein',
#   ['RSKR', 'SGK494']),
#  ('Q52WX2', 'SBK1', 'Serine/threonine-protein kinase SBK1', ['SBK1']),
#  ('P0C263',
#   'SBK2',
#   'Serine/threonine-protein kinase SBK2',
#   ['SBK2', 'SGK069']),
#  ('P0C264',
#   'SBK3',
#   'Uncharacterized serine/threonine-protein kinase SBK3',
#   ['SBK3', 'SGK110']),
#  ('Q96KG9',
#   'SCYL1',
#   'N-terminal kinase-like protein',
#   ['SCYL1', 'CVAK90', 'GKLP', 'NTKL', 'TAPK', 'TEIF', 'TRAP', 'HT019']),
#  ('Q6P3W7', 'SCYL2', 'SCY1-like protein 2', ['SCYL2', 'CVAK104', 'KIAA1360']),
#  ('Q8IZE3',
#   'SCYL3',
#   'Protein-associating with the carboxyl-terminal domain of ezrin',
#   ['SCYL3', 'PACE1']),
#  ('O75716',
#   'STK16',
#   'Serine/threonine-protein kinase 16',
#   ['STK16', 'MPSK1', 'PKL12', 'TSF1']),
#  ('Q9BXU1',
#   'STK31',
#   'Serine/threonine-protein kinase 31',
#   ['STK31', 'SGK396']),
#  ('Q8WU08',
#   'STK32A',
#   'Serine/threonine-protein kinase 32A',
#   ['STK32A', 'YANK1']),
#  ('Q9NY57',
#   'STK32B',
#   'Serine/threonine-protein kinase 32B',
#   ['STK32B', 'YANK2', 'UNQ3003/PRO9744']),
#  ('Q86UX6',
#   'STK32C',
#   'Serine/threonine-protein kinase 32C',
#   ['STK32C', 'YANK3']),
#  ('Q8TDR2',
#   'STK35',
#   'Serine/threonine-protein kinase 35',
#   ['STK35', 'CLIK1', 'PDIK1', 'STK35L1']),
#  ('Q9NRP7',
#   'STK36',
#   'Serine/threonine-protein kinase 36',
#   ['STK36', 'KIAA1278']),
#  ('Q8NE28',
#   'STKLD1',
#   'Serine/threonine kinase-like domain-containing protein STKLD1',
#   ['STKLD1', 'C9orf96', 'SGK071']),
#  ('Q8TEA7',
#   'TBCK',
#   'TBC domain-containing protein kinase-like protein',
#   ['TBCK', 'TBCKL', 'HSPC302']),
#  ('Q9UHD2', 'TBK1', 'Serine/threonine-protein kinase TBK1', ['TBK1', 'NAK']),
#  ('Q8IWB6',
#   'TEX14',
#   'Inactive serine/threonine-protein kinase TEX14',
#   ['TEX14', 'SGK307']),
#  ('Q9UKI8',
#   'TLK1',
#   'Serine/threonine-protein kinase tousled-like 1',
#   ['TLK1', 'KIAA0137']),
#  ('Q86UE8',
#   'TLK2',
#   'Serine/threonine-protein kinase tousled-like 2',
#   ['TLK2']),
#  ('Q96S44',
#   'TP53RK',
#   'EKC/KEOPS complex subunit TP53RK',
#   ['TP53RK', 'C20orf64', 'PRPK']),
#  ('P33981',
#   'TTK',
#   'Dual specificity protein kinase TTK',
#   ['TTK', 'MPS1', 'MPS1L1']),
#  ('Q8TAS1',
#   'UHMK1',
#   'Serine/threonine-protein kinase Kist',
#   ['UHMK1', 'KIS', 'KIST']),
#  ('O75385',
#   'ULK1',
#   'Serine/threonine-protein kinase ULK1',
#   ['ULK1', 'KIAA0722']),
#  ('Q8IYT8',
#   'ULK2',
#   'Serine/threonine-protein kinase ULK2',
#   ['ULK2', 'KIAA0623']),
#  ('Q6PHR2', 'ULK3', 'Serine/threonine-protein kinase ULK3', ['ULK3']),
#  ('Q96C45', 'ULK4', 'Serine/threonine-protein kinase ULK4', ['ULK4']),
#  ('P30291', 'WEE1', 'Wee1-like protein kinase', ['WEE1']),
#  ('P0C1S8', 'WEE2', 'Wee1-like protein kinase 2', ['WEE2', 'WEE1B']),
#  ('Q9H4A3',
#   'WNK1',
#   'Serine/threonine-protein kinase WNK1',
#   ['WNK1', 'HSN2', 'KDP', 'KIAA0344', 'PRKWNK1']),
#  ('Q9Y3S1',
#   'WNK2',
#   'Serine/threonine-protein kinase WNK2',
#   ['WNK2', 'KIAA1760', 'PRKWNK2', 'SDCCAG43', 'P/OKcl.13']),
#  ('Q9BYP7',
#   'WNK3',
#   'Serine/threonine-protein kinase WNK3',
#   ['WNK3', 'KIAA1566', 'PRKWNK3']),
#  ('Q96J92',
#   'WNK4',
#   'Serine/threonine-protein kinase WNK4',
#   ['WNK4', 'PRKWNK4']),
#  ('Q86TW2', 'ADCK1', 'AarF domain-containing protein kinase 1', ['ADCK1']),
#  ('Q7Z695',
#   'ADCK2',
#   'Uncharacterized aarF domain-containing protein kinase 2',
#   ['ADCK2', 'AARF']),
#  ('Q3MIX3',
#   'ADCK5',
#   'Uncharacterized aarF domain-containing protein kinase 5',
#   ['ADCK5']),
#  ('Q8NI60',
#   'COQ8A',
#   'Atypical kinase COQ8A, mitochondrial',
#   ['COQ8A', 'ADCK3', 'CABC1', 'PP265']),
#  ('Q96D53',
#   'COQ8B',
#   'Atypical kinase COQ8B, mitochondrial',
#   ['COQ8B', 'ADCK4']),
#  ('Q96QP1', 'ALPK1', 'Alpha-protein kinase 1', ['ALPK1', 'KIAA1527', 'LAK']),
#  ('Q86TB3', 'ALPK2', 'Alpha-protein kinase 2', ['ALPK2', 'HAK']),
#  ('Q96L96', 'ALPK3', 'Alpha-protein kinase 3', ['ALPK3', 'KIAA1330', 'MAK']),
#  ('O00418', 'EEF2K', 'Eukaryotic elongation factor 2 kinase', ['EEF2K']),
#  ('Q9BX84',
#   'TRPM6',
#   'Transient receptor potential cation channel subfamily M member 6',
#   ['TRPM6', 'CHAK2']),
#  ('Q96QT4',
#   'TRPM7',
#   'Transient receptor potential cation channel subfamily M member 7',
#   ['TRPM7', 'CHAK1', 'LTRPC7']),
#  ('Q14296', 'FASTK', 'Fas-activated serine/threonine kinase', ['FASTK']),
#  ('Q14874', '', 'Merged into P13497.', []),
#  ('Q15118', 'PDK1', '[Pyruvate dehydrogenase', ['PDK1', 'PDHK1']),
#  ('Q15119', 'PDK2', '[Pyruvate dehydrogenase', ['PDK2', 'PDHK2']),
#  ('Q15120', 'PDK3', '[Pyruvate dehydrogenase', ['PDK3', 'PDHK3']),
#  ('Q16654', 'PDK4', '[Pyruvate dehydrogenase', ['PDK4', 'PDHK4']),
#  ('Q13315', 'ATM', 'Serine-protein kinase ATM', ['ATM']),
#  ('Q13535', 'ATR', 'Serine/threonine-protein kinase ATR', ['ATR', 'FRP1']),
#  ('P42345',
#   'MTOR',
#   'Serine/threonine-protein kinase mTOR',
#   ['MTOR', 'FRAP', 'FRAP1', 'FRAP2', 'RAFT1', 'RAPT1']),
#  ('P42336',
#   'PIK3CA',
#   'Phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit alpha isoform',
#   ['PIK3CA']),
#  ('P42338',
#   'PIK3CB',
#   'Phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit beta isoform',
#   ['PIK3CB', 'PIK3C1']),
#  ('O00329',
#   'PIK3CD',
#   'Phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit delta isoform',
#   ['PIK3CD']),
#  ('P48736',
#   'PIK3CG',
#   'Phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit gamma isoform',
#   ['PIK3CG']),
#  ('P78527',
#   'PRKDC',
#   'DNA-dependent protein kinase catalytic subunit',
#   ['PRKDC', 'HYRC', 'HYRC1']),
#  ('Q96Q15',
#   'SMG1',
#   'Serine/threonine-protein kinase SMG1',
#   ['SMG1', 'ATX', 'KIAA0421', 'LIP']),
#  ('Q9BRS2',
#   'RIOK1',
#   'Serine/threonine-protein kinase RIO1',
#   ['RIOK1', 'RIO1']),
#  ('Q9BVS4',
#   'RIOK2',
#   'Serine/threonine-protein kinase RIO2',
#   ['RIOK2', 'RIO2']),
#  ('O14730',
#   'RIOK3',
#   'Serine/threonine-protein kinase RIO3',
#   ['RIOK3', 'SUDD'])]

# %%
#convert the list into dataframe
meta_df = pd.DataFrame(total, columns=['Uniprot_number','Gene_name','Protein_name','Gene_aliases'])
meta_df.head()
# Out:
#   Uniprot_number Gene_name                                Protein_name  \
# 0         P31749      AKT1   RAC-alpha serine/threonine-protein kinase
# 1         P31751      AKT2    RAC-beta serine/threonine-protein kinase
# 2         Q9Y243      AKT3   RAC-gamma serine/threonine-protein kinase
# 3         Q5VT25  CDC42BPA  Serine/threonine-protein kinase MRCK alpha
# 4         Q9Y5S2  CDC42BPB   Serine/threonine-protein kinase MRCK beta
#
#            Gene_aliases
# 0      [AKT1, PKB, RAC]
# 1                [AKT2]
# 2          [AKT3, PKBG]
# 3  [CDC42BPA, KIAA0451]
# 4  [CDC42BPB, KIAA1124]

# %%
#turn the meta df into csv file
meta_df.to_csv('meta_names.csv', header=True, index=False)

# %% [markdown]
# The metadata is now available
