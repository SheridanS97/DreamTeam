# %% [markdown]
# # Getting protein name and other synonyms

# %% [markdown]
# ## Source: uniprot

# %%
#import library
import pandas as pd
import re
import csv
import json

# %%
#install the library if you don't have it
# !pip install bioservices
from bioservices import UniProt

# %%
#read csv file into dataframe
kinase_df = pd.read_csv('clean_human_kinase.csv', index_col=0)
kinase_df.tail()
# Out:
#                                          gene_name uniprot_identifier  \
# family
# Atypical: PI3/PI4-kinase family              PRKDC        PRKDC_HUMAN
# Atypical: PI3/PI4-kinase family               SMG1         SMG1_HUMAN
# Atypical: RIO-type Ser/Thr kinase family     RIOK1        RIOK1_HUMAN
# Atypical: RIO-type Ser/Thr kinase family     RIOK2        RIOK2_HUMAN
# Atypical: RIO-type Ser/Thr kinase family     RIOK3        RIOK3_HUMAN
#
#                                          uniprot_number
# family
# Atypical: PI3/PI4-kinase family                  P78527
# Atypical: PI3/PI4-kinase family                  Q96Q15
# Atypical: RIO-type Ser/Thr kinase family         Q9BRS2
# Atypical: RIO-type Ser/Thr kinase family         Q9BVS4
# Atypical: RIO-type Ser/Thr kinase family         O14730

# %%
#unprocessed uniprot_number
unprocessed_list = kinase_df['uniprot_number'].tolist()
unprocessed_list[:10]
# Out:
# ['P31749',
#  'P31751',
#  'Q9Y243',
#  'Q5VT25',
#  'Q9Y5S2',
#  'Q6DT37',
#  'O14578',
#  'Q09013',
#  'Q15835',
#  'P25098']

# %%
#turn gene name into a list
up_num_list = kinase_df['uniprot_number'].str.rstrip().tolist() #rstrip to remove the white spaces
up_num_list
# Out:
# ['P31749',
#  'P31751',
#  'Q9Y243',
#  'Q5VT25',
#  'Q9Y5S2',
#  'Q6DT37',
#  'O14578',
#  'Q09013',
#  'Q15835',
#  'P25098',
#  'P35626',
#  'P32298',
#  'P34947',
#  'P43250',
#  'Q8WTQ7',
#  'O95835',
#  'Q9NRM7',
#  'Q9Y2H9',
#  'Q6P0Q8',
#  'O60307',
#  'O15021',
#  'Q96GX5',
#  'O15530',
#  'Q6A1A2',
#  'Q16512',
#  'Q16513',
#  'Q6P5Z2',
#  'P17612',
#  'P22694',
#  'P22612',
#  'P17252',
#  'P05771',
#  'Q05655',
#  'Q02156',
#  'P05129',
#  'P24723',
#  'P41743',
#  'Q04759',
#  'Q05513',
#  'Q13976',
#  'Q13237',
#  'P51817',
#  'O43930',
#  'Q13464',
#  'O75116',
#  'Q15418',
#  'Q15349',
#  'P51812',
#  'O75676',
#  'O75582',
#  'Q9UK32',
#  'P23443',
#  'Q9UBS0',
#  'O00141',
#  'Q9HBY8',
#  'Q96BR1',
#  'Q15208',
#  'Q9Y2H1',
#  'Q8TDC3',
#  'Q8IWQ3',
#  'Q14012',
#  'Q8IU85',
#  'Q96NX5',
#  'Q9UQM7',
#  'Q13554',
#  'Q13557',
#  'Q13555',
#  'Q16566',
#  'Q8NCB2',
#  'O14936',
#  'O14757',
#  'O96017',
#  'P53355',
#  'Q9UIK4',
#  'O43293',
#  'O15075',
#  'Q8N568',
#  'Q9C098',
#  'P57058',
#  'O60229',
#  'P49137',
#  'Q16644',
#  'Q8IW41',
#  'Q9P0L2',
#  'Q7KZI7',
#  'P27448',
#  'Q96L34',
#  'Q14680',
#  'Q9BUB5',
#  'Q9HBH9',
#  'Q15746',
#  'Q9H1R3',
#  'Q32MK0',
#  'Q86YV6',
#  'Q8IY84',
#  'O60285',
#  'Q9H093',
#  'Q5VST9',
#  'Q96RG2',
#  'Q16816',
#  'P15735',
#  'P11309',
#  'Q9P1W9',
#  'Q86V86',
#  'Q6P2M8',
#  'Q13131',
#  'P54646',
#  'Q15139',
#  'Q9BZL6',
#  'O94806',
#  'P11801',
#  'Q96QS6',
#  'P57059',
#  'A0A0B4J2F2',
#  'Q9H0K1',
#  'Q9Y2K2',
#  'Q9NRH2',
#  'Q15772',
#  'Q15831',
#  'Q9UEE5',
#  'O94768',
#  'Q9BYT3',
#  'Q8N2I9',
#  'Q96RU8',
#  'Q92519',
#  'Q96RU7',
#  'O75962',
#  'Q9BXA7',
#  'Q96PF2',
#  'Q96PN8',
#  'Q6SA08',
#  'Q9BXA6',
#  'Q8WZ42',
#  'P48729',
#  'Q8N752',
#  'P48730',
#  'P49674',
#  'Q9HCP0',
#  'P78368',
#  'Q9Y6M4',
#  'Q5TCY1',
#  'Q6IQ55',
#  'Q99986',
#  'Q86Y07',
#  'Q8IV63',
#  'P06493',
#  'Q15131',
#  'Q9UQ88',
#  'P21127',
#  'Q9NYV4',
#  'Q14004',
#  'O94921',
#  'Q96Q40',
#  'Q00536',
#  'Q00537',
#  'Q07002',
#  'Q9BWU1',
#  'P24941',
#  'Q8IZL9',
#  'Q00526',
#  'P11802',
#  'Q00535',
#  'Q00534',
#  'P50613',
#  'P49336',
#  'P50750',
#  'Q00532',
#  'Q92772',
#  'Q8IVW4',
#  'Q5MAI5',
#  'O76039',
#  'P49759',
#  'P49760',
#  'P49761',
#  'Q9HAZ1',
#  'Q13627',
#  'Q9Y463',
#  'Q92630',
#  'O43781',
#  'Q9NR20',
#  'P49840',
#  'P49841',
#  'Q86Z02',
#  'Q9H2X6',
#  'Q9H422',
#  'Q8NE63',
#  'Q9UPZ9',
#  'P20794',
#  'P28482',
#  'P53779',
#  'Q15759',
#  'P53778',
#  'O15264',
#  'Q16539',
#  'Q8TD08',
#  'P27361',
#  'P31152',
#  'Q16659',
#  'Q13164',
#  'P45983',
#  'P45984',
#  'Q9UQ07',
#  'Q9UBE8',
#  'Q13523',
#  'Q96SB4',
#  'P78362',
#  'Q9UPE1',
#  'Q96PY6',
#  'Q6ZWH5',
#  'Q8NG66',
#  'P51955',
#  'P51956',
#  'P51957',
#  'Q6P3R8',
#  'Q9HC98',
#  'Q8TDX7',
#  'Q86SG6',
#  'Q8TD19',
#  'P25092',
#  'Q02846',
#  'P51841',
#  'P16066',
#  'P20594',
#  'Q02750',
#  'P36507',
#  'P46734',
#  'P45985',
#  'Q13163',
#  'P52564',
#  'O14733',
#  'Q13233',
#  'Q02779',
#  'Q16584',
#  'Q12852',
#  'O43283',
#  'Q99558',
#  'Q6ZN16',
#  'Q56UN5',
#  'Q9Y2U5',
#  'Q9NYL2',
#  'Q5TCX8',
#  'Q99759',
#  'Q9Y6R4',
#  'Q99683',
#  'O95382',
#  'O43318',
#  'P41279',
#  'P80192',
#  'Q92918',
#  'Q12851',
#  'Q8IVH8',
#  'O95819',
#  'Q9Y4K4',
#  'Q8N4C8',
#  'Q8NEV4',
#  'Q8WXR4',
#  'Q7Z2Y5',
#  'O95747',
#  'Q13153',
#  'Q13177',
#  'O75914',
#  'O96013',
#  'Q9P286',
#  'Q9NQU5',
#  'Q96KB5',
#  'Q9H2G2',
#  'O94804',
#  'Q9Y6E0',
#  'O00506',
#  'Q9P289',
#  'Q13188',
#  'Q9UEW8',
#  'Q13043',
#  'Q7RTN6',
#  'Q9C0K7',
#  'Q7L7X3',
#  'Q9UL54',
#  'Q9H2K8',
#  'Q9UKE5',
#  'Q04771',
#  'P36896',
#  'Q8NER5',
#  'P27037',
#  'Q13705',
#  'P37023',
#  'Q16671',
#  'Q8NFD2',
#  'P10398',
#  'P36894',
#  'O00238',
#  'Q13873',
#  'P15056',
#  'Q13418',
#  'P51617',
#  'O43187',
#  'Q9Y616',
#  'Q9NWZ3',
#  'Q8IVT5',
#  'Q6VAB6',
#  'P53667',
#  'P53671',
#  'Q38SD2',
#  'Q5S007',
#  'P04049',
#  'Q13546',
#  'O43353',
#  'Q9Y572',
#  'P57078',
#  'Q15569',
#  'Q96S53',
#  'P36897',
#  'P37173',
#  'Q59H18',
#  'Q6ZMQ8',
#  'P00519',
#  'P42684',
#  'Q9UM73',
#  'P30530',
#  'P51451',
#  'P51813',
#  'Q06187',
#  'P07333',
#  'P41240',
#  'Q08345',
#  'Q16832',
#  'P00533',
#  'P21709',
#  'Q5JZY3',
#  'P29317',
#  'P29320',
#  'P54764',
#  'P54756',
#  'Q9UF33',
#  'Q15375',
#  'P29322',
#  'P54762',
#  'P29323',
#  'P54753',
#  'P54760',
#  'O15197',
#  'P04626',
#  'P21860',
#  'Q15303',
#  'P16591',
#  'P07332',
#  'P11362',
#  'P21802',
#  'P22607',
#  'P22455',
#  'P09769',
#  'P17948',
#  'P36888',
#  'P35916',
#  'P42685',
#  'P06241',
#  'P08631',
#  'P08069',
#  'P06213',
#  'P14616',
#  'Q08881',
#  'P23458',
#  'O60674',
#  'P52333',
#  'P35968',
#  'P10721',
#  'P06239',
#  'Q8IWU2',
#  'Q96Q04',
#  'P29376',
#  'P07948',
#  'P42679',
#  'Q12866',
#  'P08581',
#  'Q04912',
#  'O15146',
#  'P04629',
#  'Q16620',
#  'Q16288',
#  'P16234',
#  'P09619',
#  'Q05397',
#  'Q14289',
#  'Q13882',
#  'Q13308',
#  'P07949',
#  'Q01973',
#  'Q01974',
#  'P08922',
#  'P34925',
#  'P12931',
#  'Q9H3Y6',
#  'Q6J9G0',
#  'P43405',
#  'P42680',
#  'Q02763',
#  'P35590',
#  'Q13470',
#  'Q07912',
#  'P42681',
#  'P29597',
#  'Q06418',
#  'P07947',
#  'P43403',
#  'Q2M2I8',
#  'O14965',
#  'Q96GD4',
#  'Q9UQB9',
#  'Q9NSY1',
#  'O43683',
#  'O60566',
#  'Q8N5S9',
#  'Q96RR4',
#  'O00311',
#  'O15111',
#  'P68400',
#  'P19784',
#  'Q8NEV1',
#  'Q6XUX3',
#  'Q9BQI3',
#  'P19525',
#  'Q9NZJ5',
#  'Q9P2K8',
#  'O75460',
#  'Q76MJ5',
#  'O14976',
#  'Q8TF76',
#  'O14920',
#  'Q14164',
#  'Q8NB16',
#  'P00540',
#  'Q9UHY1',
#  'Q9NSY0',
#  'Q58A45',
#  'Q8N165',
#  'Q9H792',
#  'Q99570',
#  'Q9BXM7',
#  'Q504Y2',
#  'Q99640',
#  'P53350',
#  'Q9NYY3',
#  'Q9H4B4',
#  'O00444',
#  'Q496M5',
#  'Q9H5K3',
#  'Q86YV5',
#  'Q7Z7A4',
#  'Q05823',
#  'Q96S38',
#  'Q9Y6S9',
#  'Q96LW2',
#  'Q52WX2',
#  'P0C263',
#  'P0C264',
#  'Q96KG9',
#  'Q6P3W7',
#  'Q8IZE3',
#  'O75716',
#  'Q9BXU1',
#  'Q8WU08',
#  'Q9NY57',
#  'Q86UX6',
#  'Q8TDR2',
#  'Q9NRP7',
#  'Q8NE28',
#  'Q8TEA7',
#  'Q9UHD2',
#  'Q8IWB6',
#  'Q9UKI8',
#  'Q86UE8',
#  'Q96S44',
#  'P33981',
#  'Q8TAS1',
#  'O75385',
#  'Q8IYT8',
#  'Q6PHR2',
#  'Q96C45',
#  'P30291',
#  'P0C1S8',
#  'Q9H4A3',
#  'Q9Y3S1',
#  'Q9BYP7',
#  'Q96J92',
#  'Q86TW2',
#  'Q7Z695',
#  'Q3MIX3',
#  'Q8NI60',
#  'Q96D53',
#  'Q96QP1',
#  'Q86TB3',
#  'Q96L96',
#  'O00418',
#  'Q9BX84',
#  'Q96QT4',
#  'Q14296',
#  'O14874',
#  'Q15118',
#  'Q15119',
#  'Q15120',
#  'Q16654',
#  'Q13315',
#  'Q13535',
#  'P42345',
#  'P42336',
#  'P42338',
#  'O00329',
#  'P48736',
#  'P78527',
#  'Q96Q15',
#  'Q9BRS2',
#  'Q9BVS4',
#  'O14730']

# %%
#using bioservices
u = UniProt(verbose=False)
u.search("id:P31751", limit=1, columns="id,protein names,entry name")
# Out:
# 'Entry\tProtein names\tEntry name\nP31751\tRAC-beta serine/threonine-protein kinase (EC 2.7.11.1) (Protein kinase Akt-2) (Protein kinase B beta) (PKB beta) (RAC-PK-beta)\tAKT2_HUMAN\n'

# %%
#split the output by multiple seps
example = u.search("id:Q5VT25", limit=1, columns="id,protein names, genes(PREFERRED), genes, entry name")
re.split('\t|\n', example)
# Out:
# ['Entry',
#  'Protein names',
#  'Gene names  (primary )',
#  'Gene names',
#  'Entry name',
#  'Q5VT25',
#  'Serine/threonine-protein kinase MRCK alpha (EC 2.7.11.1) (CDC42-binding protein kinase alpha) (DMPK-like alpha) (Myotonic dystrophy kinase-related CDC42-binding kinase alpha) (MRCK alpha) (Myotonic dystrophy protein kinase-like alpha)',
#  'CDC42BPA',
#  'CDC42BPA KIAA0451',
#  'MRCKA_HUMAN',
#  '']

# %%
#retrieve the protein names
ex_str = re.split('\t|\n', example)
ex_str[6].split('(')[0].rstrip()
# Out:
# 'Serine/threonine-protein kinase MRCK alpha'

# %%
#create a function to get the uniprot_number, gene_name, protein_name, gene_aliases
def get_meta(uniprot_num):
    """
    Takes in a uniprot number.
    Returns the uniprot_number, gene_name, protein_name, gene_aliases as a tuple.
    """
    query = "id:{}".format(uniprot_num)
    output = u.search(query, limit=1, columns="id,protein names, genes(PREFERRED), genes, entry name")
    tmp = re.split('\t|\n', output)
    protein_name = tmp[6].split('(')[0].rstrip()
    gene_name = tmp[7]
    gene_aliases = tmp[8].split()
    uniprot_entry = tmp[9]
    return(uniprot_num, gene_name, protein_name, gene_aliases, uniprot_entry)
get_meta('Q5VT25')
# Out:
# ('Q5VT25',
#  'CDC42BPA',
#  'Serine/threonine-protein kinase MRCK alpha',
#  ['CDC42BPA', 'KIAA0451'],
#  'MRCKA_HUMAN')

# %%
#get all the protein names
total = []
unavailable = []
for num in up_num_list:
    tmp = get_meta(num)
    if len(tmp) < 5:
        unavailable.append(num)
    else:
        total.append(tmp)
print(len(unavailable))
print(total[:5])
# Out:
# 0
# [('P31749', 'AKT1', 'RAC-alpha serine/threonine-protein kinase', ['AKT1', 'PKB', 'RAC'], 'AKT1_HUMAN'), ('P31751', 'AKT2', 'RAC-beta serine/threonine-protein kinase', ['AKT2'], 'AKT2_HUMAN'), ('Q9Y243', 'AKT3', 'RAC-gamma serine/threonine-protein kinase', ['AKT3', 'PKBG'], 'AKT3_HUMAN'), ('Q5VT25', 'CDC42BPA', 'Serine/threonine-protein kinase MRCK alpha', ['CDC42BPA', 'KIAA0451'], 'MRCKA_HUMAN'), ('Q9Y5S2', 'CDC42BPB', 'Serine/threonine-protein kinase MRCK beta', ['CDC42BPB', 'KIAA1124'], 'MRCKB_HUMAN')]

# %%
#convert the list into dataframe
meta_df = pd.DataFrame(total, columns=['Uniprot_number','Gene_name','Protein_name','Gene_aliases', 'Uniprot_entry'])
meta_df.head()
# Out:
#   Uniprot_number Gene_name                                Protein_name  \
# 0         P31749      AKT1   RAC-alpha serine/threonine-protein kinase
# 1         P31751      AKT2    RAC-beta serine/threonine-protein kinase
# 2         Q9Y243      AKT3   RAC-gamma serine/threonine-protein kinase
# 3         Q5VT25  CDC42BPA  Serine/threonine-protein kinase MRCK alpha
# 4         Q9Y5S2  CDC42BPB   Serine/threonine-protein kinase MRCK beta
#
#            Gene_aliases Uniprot_entry
# 0      [AKT1, PKB, RAC]    AKT1_HUMAN
# 1                [AKT2]    AKT2_HUMAN
# 2          [AKT3, PKBG]    AKT3_HUMAN
# 3  [CDC42BPA, KIAA0451]   MRCKA_HUMAN
# 4  [CDC42BPB, KIAA1124]   MRCKB_HUMAN

# %%
#turn the meta df into csv file
meta_df.to_csv('meta_names.csv', header=True, index=False)

# %% [markdown]
# The metadata is now available

# %% [markdown]
# # Checking if Mo's kinase is within my list of human kinases

# %%
#read in mo's csv
kinase_substrate_df = pd.read_csv('clean_human_kinase_substrates.csv')
kinase_substrate_df.head()
# Out:
#    Unnamed: 0     GENE KINASE KIN_ACC_ID   SUBSTRATE  SUB_GENE_ID SUB_ACC_ID  \
# 0           7  EIF2AK1    HRI     Q9BQI3  eIF2-alpha       1965.0     P05198
# 1           8  EIF2AK1    HRI     Q9BQI3  eIF2-alpha       1965.0     P05198
# 2          11    PRKCD   PKCD     Q05655       HDAC5      10014.0     Q9UQL6
# 3          12    PRKCD   PKCD     Q05655  PTPRA iso2       5786.0   P18433-2
# 4          13    PRKCD   PKCD     Q05655     hnRNP K       3190.0     P61978
#
#   SUB_GENE SUB_MOD_RSD  SITE_GRP_ID     SITE_+/-7_AA DOMAIN
# 0   EIF2S1         S52       447635  MILLsELsRRRIRsI     S1
# 1   EIF2S1         S49       450210  IEGMILLsELsRRRI     S1
# 2    HDAC5        S259       447995  FPLRkTAsEPNLKVR    NaN
# 3    PTPRA        S204       447612  PLLARSPsTNRKYPP    NaN
# 4   HNRNPK        S302       457408  GrGGrGGsrArNLPL    NaN

# %%
meta_df.head()
# Out:
#   Uniprot_number Gene_name                                Protein_name  \
# 0         P31749      AKT1   RAC-alpha serine/threonine-protein kinase
# 1         P31751      AKT2    RAC-beta serine/threonine-protein kinase
# 2         Q9Y243      AKT3   RAC-gamma serine/threonine-protein kinase
# 3         Q5VT25  CDC42BPA  Serine/threonine-protein kinase MRCK alpha
# 4         Q9Y5S2  CDC42BPB   Serine/threonine-protein kinase MRCK beta
#
#            Gene_aliases Uniprot_entry
# 0      [AKT1, PKB, RAC]    AKT1_HUMAN
# 1                [AKT2]    AKT2_HUMAN
# 2          [AKT3, PKBG]    AKT3_HUMAN
# 3  [CDC42BPA, KIAA0451]   MRCKA_HUMAN
# 4  [CDC42BPB, KIAA1124]   MRCKB_HUMAN

# %%
#turn meta_df into dictionary with gene_aliases as key and the gene_name as value
kinase_dict = {}
for index, row in meta_df.iterrows():
    kinase_dict[tuple(row['Gene_aliases'])] = row['Gene_name']
#     print(tuple(row['Gene_aliases']))
kinase_dict
# Out:
# {('AKT1', 'PKB', 'RAC'): 'AKT1',
#  ('AKT2',): 'AKT2',
#  ('AKT3', 'PKBG'): 'AKT3',
#  ('CDC42BPA', 'KIAA0451'): 'CDC42BPA',
#  ('CDC42BPB', 'KIAA1124'): 'CDC42BPB',
#  ('CDC42BPG', 'DMPK2'): 'CDC42BPG',
#  ('CIT', 'CRIK', 'KIAA0949', 'STK21'): 'CIT',
#  ('DMPK', 'DM1PK', 'MDPK'): 'DMPK',
#  ('GRK1', 'RHOK'): 'GRK1',
#  ('GRK2', 'ADRBK1', 'BARK', 'BARK1'): 'GRK2',
#  ('GRK3', 'ADRBK2', 'BARK2'): 'GRK3',
#  ('GRK4', 'GPRK2L', 'GPRK4'): 'GRK4',
#  ('GRK5', 'GPRK5'): 'GRK5',
#  ('GRK6', 'GPRK6'): 'GRK6',
#  ('GRK7', 'GPRK7'): 'GRK7',
#  ('LATS1', 'WARTS'): 'LATS1',
#  ('LATS2', 'KPM'): 'LATS2',
#  ('MAST1', 'KIAA0973', 'SAST'): 'MAST1',
#  ('MAST2', 'KIAA0807', 'MAST205'): 'MAST2',
#  ('MAST3', 'KIAA0561'): 'MAST3',
#  ('MAST4', 'KIAA0303'): 'MAST4',
#  ('MASTL', 'GW', 'GWL', 'THC2'): 'MASTL',
#  ('PDPK1', 'PDK1'): 'PDPK1',
#  ('PDPK2P', 'PDPK2'): 'PDPK2P',
#  ('PKN1', 'PAK1', 'PKN', 'PRK1', 'PRKCL1'): 'PKN1',
#  ('PKN2', 'PRK2', 'PRKCL2'): 'PKN2',
#  ('PKN3', 'PKNBETA'): 'PKN3',
#  ('PRKACA', 'PKACA'): 'PRKACA',
#  ('PRKACB',): 'PRKACB',
#  ('PRKACG',): 'PRKACG',
#  ('PRKCA', 'PKCA', 'PRKACA'): 'PRKCA',
#  ('PRKCB', 'PKCB', 'PRKCB1'): 'PRKCB',
#  ('PRKCD',): 'PRKCD',
#  ('PRKCE', 'PKCE'): 'PRKCE',
#  ('PRKCG', 'PKCG'): 'PRKCG',
#  ('PRKCH', 'PKCL', 'PRKCL'): 'PRKCH',
#  ('PRKCI', 'DXS1179E'): 'PRKCI',
#  ('PRKCQ', 'PRKCT'): 'PRKCQ',
#  ('PRKCZ', 'PKC2'): 'PRKCZ',
#  ('PRKG1', 'PRKG1B', 'PRKGR1A', 'PRKGR1B'): 'PRKG1',
#  ('PRKG2', 'PRKGR2'): 'PRKG2',
#  ('PRKX', 'PKX1'): 'PRKX',
#  ('PRKY',): 'PRKY',
#  ('ROCK1',): 'ROCK1',
#  ('ROCK2', 'KIAA0619'): 'ROCK2',
#  ('RPS6KA1', 'MAPKAPK1A', 'RSK1'): 'RPS6KA1',
#  ('RPS6KA2', 'MAPKAPK1C', 'RSK3'): 'RPS6KA2',
#  ('RPS6KA3', 'ISPK1', 'MAPKAPK1B', 'RSK2'): 'RPS6KA3',
#  ('RPS6KA4', 'MSK2'): 'RPS6KA4',
#  ('RPS6KA5', 'MSK1'): 'RPS6KA5',
#  ('RPS6KA6', 'RSK4'): 'RPS6KA6',
#  ('RPS6KB1', 'STK14A'): 'RPS6KB1',
#  ('RPS6KB2', 'STK14B'): 'RPS6KB2',
#  ('SGK1', 'SGK'): 'SGK1',
#  ('SGK2',): 'SGK2',
#  ('SGK3', 'CISK', 'SGKL'): 'SGK3',
#  ('STK38', 'NDR1'): 'STK38',
#  ('STK38L', 'KIAA0965', 'NDR2'): 'STK38L',
#  ('BRSK1', 'KIAA1811', 'SAD1', 'SADB'): 'BRSK1',
#  ('BRSK2', 'C11orf7', 'PEN11B', 'SADA', 'STK29', 'HUSSY-12'): 'BRSK2',
#  ('CAMK1',): 'CAMK1',
#  ('CAMK1D', 'CAMKID'): 'CAMK1D',
#  ('CAMK1G', 'CLICK3', 'VWS1'): 'CAMK1G',
#  ('CAMK2A', 'CAMKA', 'KIAA0968'): 'CAMK2A',
#  ('CAMK2B', 'CAM2', 'CAMK2', 'CAMKB'): 'CAMK2B',
#  ('CAMK2D', 'CAMKD'): 'CAMK2D',
#  ('CAMK2G', 'CAMK', 'CAMK-II', 'CAMKG'): 'CAMK2G',
#  ('CAMK4', 'CAMK', 'CAMK-GR', 'CAMKIV'): 'CAMK4',
#  ('CAMKV',): 'CAMKV',
#  ('CASK', 'LIN2'): 'CASK',
#  ('CHEK1', 'CHK1'): 'CHEK1',
#  ('CHEK2', 'CDS1', 'CHK2', 'RAD53'): 'CHEK2',
#  ('DAPK1', 'DAPK'): 'DAPK1',
#  ('DAPK2',): 'DAPK2',
#  ('DAPK3', 'ZIPK'): 'DAPK3',
#  ('DCLK1', 'DCAMKL1', 'DCDC3A', 'KIAA0369'): 'DCLK1',
#  ('DCLK2', 'DCAMKL2', 'DCDC3B', 'DCK2'): 'DCLK2',
#  ('DCLK3', 'DCAMKL3', 'DCDC3C', 'KIAA1765'): 'DCLK3',
#  ('HUNK', 'MAKV'): 'HUNK',
#  ('KALRN', 'DUET', 'DUO', 'HAPIP', 'TRAD'): 'KALRN',
#  ('MAPKAPK2',): 'MAPKAPK2',
#  ('MAPKAPK3',): 'MAPKAPK3',
#  ('MAPKAPK5', 'PRAK'): 'MAPKAPK5',
#  ('MARK1', 'KIAA1477', 'MARK'): 'MARK1',
#  ('MARK2', 'EMK1'): 'MARK2',
#  ('MARK3', 'CTAK1', 'EMK2'): 'MARK3',
#  ('MARK4', 'KIAA1860', 'MARKL1'): 'MARK4',
#  ('MELK', 'KIAA0175'): 'MELK',
#  ('MKNK1', 'MNK1'): 'MKNK1',
#  ('MKNK2', 'GPRK7', 'MNK2'): 'MKNK2',
#  ('MYLK', 'MLCK', 'MLCK1', 'MYLK1'): 'MYLK',
#  ('MYLK2',): 'MYLK2',
#  ('MYLK3', 'MLCK'): 'MYLK3',
#  ('MYLK4', 'SGK085'): 'MYLK4',
#  ('NIM1K', 'NIM1'): 'NIM1K',
#  ('NUAK1', 'ARK5', 'KIAA0537', 'OMPHK1'): 'NUAK1',
#  ('NUAK2', 'OMPHK2', 'SNARK'): 'NUAK2',
#  ('OBSCN', 'KIAA1556', 'KIAA1639'): 'OBSCN',
#  ('PASK', 'KIAA0135'): 'PASK',
#  ('PHKG1', 'PHKG'): 'PHKG1',
#  ('PHKG2',): 'PHKG2',
#  ('PIM1',): 'PIM1',
#  ('PIM2',): 'PIM2',
#  ('PIM3',): 'PIM3',
#  ('PNCK',): 'PNCK',
#  ('PRKAA1', 'AMPK1'): 'PRKAA1',
#  ('PRKAA2', 'AMPK', 'AMPK2'): 'PRKAA2',
#  ('PRKD1', 'PKD', 'PKD1', 'PRKCM'): 'PRKD1',
#  ('PRKD2', 'PKD2', 'HSPC187'): 'PRKD2',
#  ('PRKD3', 'EPK2', 'PRKCN'): 'PRKD3',
#  ('PSKH1',): 'PSKH1',
#  ('PSKH2',): 'PSKH2',
#  ('SIK1', 'SIK', 'SNF1LK'): 'SIK1',
#  ('SIK1B',): 'SIK1B',
#  ('SIK2', 'KIAA0781', 'QIK', 'SNF1LK2'): 'SIK2',
#  ('SIK3', 'KIAA0999', 'QSK', 'L19'): 'SIK3',
#  ('SNRK', 'KIAA0096', 'SNFRK'): 'SNRK',
#  ('SPEG', 'APEG1', 'KIAA1297'): 'SPEG',
#  ('STK11', 'LKB1', 'PJS'): 'STK11',
#  ('STK17A', 'DRAK1'): 'STK17A',
#  ('STK17B', 'DRAK2'): 'STK17B',
#  ('STK33',): 'STK33',
#  ('STK40', 'SGK495', 'SHIK'): 'STK40',
#  ('TRIB1', 'C8FW', 'GIG2', 'TRB1'): 'TRIB1',
#  ('TRIB2', 'TRB2'): 'TRIB2',
#  ('TRIB3', 'C20orf97', 'NIPK', 'SKIP3', 'TRB3'): 'TRIB3',
#  ('TRIO',): 'TRIO',
#  ('TSSK1B',
#   'SPOGA1',
#   'SPOGA4',
#   'STK22A',
#   'STK22D',
#   'TSSK1',
#   'FKSG81'): 'TSSK1B',
#  ('TSSK2', 'DGSG', 'SPOGA2', 'STK22B'): 'TSSK2',
#  ('TSSK3', 'SPOGA3', 'STK22C'): 'TSSK3',
#  ('TSSK4', 'C14orf20', 'STK22E', 'TSSK5'): 'TSSK4',
#  ('TSSK6', 'SSTK', 'FKSG82'): 'TSSK6',
#  ('TTN',): 'TTN',
#  ('CSNK1A1',): 'CSNK1A1',
#  ('CSNK1A1L',): 'CSNK1A1L',
#  ('CSNK1D', 'HCKID'): 'CSNK1D',
#  ('CSNK1E',): 'CSNK1E',
#  ('CSNK1G1',): 'CSNK1G1',
#  ('CSNK1G2', 'CK1G2'): 'CSNK1G2',
#  ('CSNK1G3',): 'CSNK1G3',
#  ('TTBK1', 'BDTK', 'KIAA1855'): 'TTBK1',
#  ('TTBK2', 'KIAA0847'): 'TTBK2',
#  ('VRK1',): 'VRK1',
#  ('VRK2',): 'VRK2',
#  ('VRK3',): 'VRK3',
#  ('CDK1', 'CDC2', 'CDC28A', 'CDKN1', 'P34CDC2'): 'CDK1',
#  ('CDK10',): 'CDK10',
#  ('CDK11A', 'CDC2L2', 'CDC2L3', 'PITSLREB'): 'CDK11A',
#  ('CDK11B', 'CDC2L1', 'CDK11', 'PITSLREA', 'PK58'): 'CDK11B',
#  ('CDK12', 'CRK7', 'CRKRS', 'KIAA0904'): 'CDK12',
#  ('CDK13', 'CDC2L', 'CDC2L5', 'CHED', 'KIAA1791'): 'CDK13',
#  ('CDK14', 'KIAA0834', 'PFTK1'): 'CDK14',
#  ('CDK15', 'ALS2CR7', 'PFTK2'): 'CDK15',
#  ('CDK16', 'PCTAIRE1', 'PCTK1'): 'CDK16',
#  ('CDK17', 'PCTAIRE2', 'PCTK2'): 'CDK17',
#  ('CDK18', 'PCTAIRE3', 'PCTK3'): 'CDK18',
#  ('CDK19', 'CDC2L6', 'CDK11', 'KIAA1028'): 'CDK19',
#  ('CDK2', 'CDKN2'): 'CDK2',
#  ('CDK20', 'CCRK', 'CDCH'): 'CDK20',
#  ('CDK3', 'CDKN3'): 'CDK3',
#  ('CDK4',): 'CDK4',
#  ('CDK5', 'CDKN5'): 'CDK5',
#  ('CDK6', 'CDKN6'): 'CDK6',
#  ('CDK7', 'CAK', 'CAK1', 'CDKN7', 'MO15', 'STK1'): 'CDK7',
#  ('CDK8',): 'CDK8',
#  ('CDK9', 'CDC2L4', 'TAK'): 'CDK9',
#  ('CDKL1',): 'CDKL1',
#  ('CDKL2',): 'CDKL2',
#  ('CDKL3', 'NKIAMRE'): 'CDKL3',
#  ('CDKL4',): 'CDKL4',
#  ('CDKL5', 'STK9'): 'CDKL5',
#  ('CLK1', 'CLK'): 'CLK1',
#  ('CLK2',): 'CLK2',
#  ('CLK3',): 'CLK3',
#  ('CLK4',): 'CLK4',
#  ('DYRK1A', 'DYRK', 'MNB', 'MNBH'): 'DYRK1A',
#  ('DYRK1B', 'MIRK'): 'DYRK1B',
#  ('DYRK2',): 'DYRK2',
#  ('DYRK3',): 'DYRK3',
#  ('DYRK4',): 'DYRK4',
#  ('GSK3A',): 'GSK3A',
#  ('GSK3B',): 'GSK3B',
#  ('HIPK1', 'KIAA0630', 'MYAK', 'NBAK2'): 'HIPK1',
#  ('HIPK2',): 'HIPK2',
#  ('HIPK3', 'DYRK6', 'FIST3', 'PKY'): 'HIPK3',
#  ('HIPK4',): 'HIPK4',
#  ('ICK', 'KIAA0936'): 'ICK',
#  ('MAK',): 'MAK',
#  ('MAPK1', 'ERK2', 'PRKM1', 'PRKM2'): 'MAPK1',
#  ('MAPK10', 'JNK3', 'JNK3A', 'PRKM10', 'SAPK1B'): 'MAPK10',
#  ('MAPK11', 'PRKM11', 'SAPK2', 'SAPK2B'): 'MAPK11',
#  ('MAPK12', 'ERK6', 'SAPK3'): 'MAPK12',
#  ('MAPK13', 'PRKM13', 'SAPK4'): 'MAPK13',
#  ('MAPK14', 'CSBP', 'CSBP1', 'CSBP2', 'CSPB1', 'MXI2', 'SAPK2A'): 'MAPK14',
#  ('MAPK15', 'ERK7', 'ERK8'): 'MAPK15',
#  ('MAPK3', 'ERK1', 'PRKM3'): 'MAPK3',
#  ('MAPK4', 'ERK4', 'PRKM4'): 'MAPK4',
#  ('MAPK6', 'ERK3', 'PRKM6'): 'MAPK6',
#  ('MAPK7', 'BMK1', 'ERK5', 'PRKM7'): 'MAPK7',
#  ('MAPK8', 'JNK1', 'PRKM8', 'SAPK1', 'SAPK1C'): 'MAPK8',
#  ('MAPK9', 'JNK2', 'PRKM9', 'SAPK1A'): 'MAPK9',
#  ('MOK', 'RAGE', 'RAGE1'): 'MOK',
#  ('NLK', 'LAK1'): 'NLK',
#  ('PRPF4B', 'KIAA0536', 'PRP4', 'PRP4H', 'PRP4K'): 'PRPF4B',
#  ('SRPK1',): 'SRPK1',
#  ('SRPK2',): 'SRPK2',
#  ('SRPK3', 'MSSK1', 'STK23'): 'SRPK3',
#  ('NEK1', 'KIAA1901'): 'NEK1',
#  ('NEK10',): 'NEK10',
#  ('NEK11',): 'NEK11',
#  ('NEK2', 'NEK2A', 'NLK1'): 'NEK2',
#  ('NEK3',): 'NEK3',
#  ('NEK4', 'STK2'): 'NEK4',
#  ('NEK5',): 'NEK5',
#  ('NEK6',): 'NEK6',
#  ('NEK7',): 'NEK7',
#  ('NEK8', 'JCK', 'NEK12A'): 'NEK8',
#  ('NEK9', 'KIAA1995', 'NEK8', 'NERCC'): 'NEK9',
#  ('GUCY2C', 'GUC2C', 'STAR'): 'GUCY2C',
#  ('GUCY2D', 'CORD6', 'GUC1A4', 'GUC2D', 'RETGC', 'RETGC1'): 'GUCY2D',
#  ('GUCY2F', 'GUC2F', 'RETGC2'): 'GUCY2F',
#  ('NPR1', 'ANPRA'): 'NPR1',
#  ('NPR2', 'ANPRB'): 'NPR2',
#  ('MAP2K1', 'MEK1', 'PRKMK1'): 'MAP2K1',
#  ('MAP2K2', 'MEK2', 'MKK2', 'PRKMK2'): 'MAP2K2',
#  ('MAP2K3', 'MEK3', 'MKK3', 'PRKMK3', 'SKK2'): 'MAP2K3',
#  ('MAP2K4',
#   'JNKK1',
#   'MEK4',
#   'MKK4',
#   'PRKMK4',
#   'SEK1',
#   'SERK1',
#   'SKK1'): 'MAP2K4',
#  ('MAP2K5', 'MEK5', 'MKK5', 'PRKMK5'): 'MAP2K5',
#  ('MAP2K6', 'MEK6', 'MKK6', 'PRKMK6', 'SKK3'): 'MAP2K6',
#  ('MAP2K7', 'JNKK2', 'MEK7', 'MKK7', 'PRKMK7', 'SKK4'): 'MAP2K7',
#  ('MAP3K1', 'MAPKKK1', 'MEKK', 'MEKK1'): 'MAP3K1',
#  ('MAP3K10', 'MLK2', 'MST'): 'MAP3K10',
#  ('MAP3K11', 'MLK3', 'PTK1', 'SPRK'): 'MAP3K11',
#  ('MAP3K12', 'ZPK'): 'MAP3K12',
#  ('MAP3K13', 'LZK'): 'MAP3K13',
#  ('MAP3K14', 'NIK'): 'MAP3K14',
#  ('MAP3K15', 'ASK3'): 'MAP3K15',
#  ('MAP3K19', 'RCK', 'YSK4'): 'MAP3K19',
#  ('MAP3K2', 'MAPKKK2', 'MEKK2'): 'MAP3K2',
#  ('MAP3K20', 'MLTK', 'ZAK', 'HCCS4'): 'MAP3K20',
#  ('MAP3K21', 'KIAA1804', 'MLK4'): 'MAP3K21',
#  ('MAP3K3', 'MAPKKK3', 'MEKK3'): 'MAP3K3',
#  ('MAP3K4', 'KIAA0213', 'MAPKKK4', 'MEKK4', 'MTK1'): 'MAP3K4',
#  ('MAP3K5', 'ASK1', 'MAPKKK5', 'MEKK5'): 'MAP3K5',
#  ('MAP3K6', 'ASK2', 'MAPKKK6', 'MEKK6'): 'MAP3K6',
#  ('MAP3K7', 'TAK1'): 'MAP3K7',
#  ('MAP3K8', 'COT', 'ESTF'): 'MAP3K8',
#  ('MAP3K9', 'MLK1', 'PRKE1'): 'MAP3K9',
#  ('MAP4K1', 'HPK1'): 'MAP4K1',
#  ('MAP4K2', 'GCK', 'RAB8IP'): 'MAP4K2',
#  ('MAP4K3', 'RAB8IPL1'): 'MAP4K3',
#  ('MAP4K4', 'HGK', 'KIAA0687', 'NIK'): 'MAP4K4',
#  ('MAP4K5',): 'MAP4K5',
#  ('MINK1', 'B55', 'MAP4K6', 'MINK', 'YSK2', 'ZC3'): 'MINK1',
#  ('MYO3A',): 'MYO3A',
#  ('MYO3B',): 'MYO3B',
#  ('NRK',): 'NRK',
#  ('OXSR1', 'KIAA1101', 'OSR1'): 'OXSR1',
#  ('PAK1',): 'PAK1',
#  ('PAK2',): 'PAK2',
#  ('PAK3', 'OPHN3'): 'PAK3',
#  ('PAK4', 'KIAA1142'): 'PAK4',
#  ('PAK5', 'KIAA1264', 'PAK7'): 'PAK5',
#  ('PAK6', 'PAK5'): 'PAK6',
#  ('PBK', 'TOPK'): 'PBK',
#  ('SLK', 'KIAA0204', 'STK2'): 'SLK',
#  ('STK10', 'LOK'): 'STK10',
#  ('STK24', 'MST3', 'STK3'): 'STK24',
#  ('STK25', 'SOK1', 'YSK1'): 'STK25',
#  ('STK26', 'MASK', 'MST4'): 'STK26',
#  ('STK3', 'KRS1', 'MST2'): 'STK3',
#  ('STK39', 'SPAK'): 'STK39',
#  ('STK4', 'KRS2', 'MST1'): 'STK4',
#  ('STRADA', 'LYK5', 'STRAD'): 'STRADA',
#  ('STRADB', 'ALS2CR2', 'ILPIP', 'PRO1038'): 'STRADB',
#  ('TAOK1', 'KIAA1361', 'MAP3K16', 'MARKK'): 'TAOK1',
#  ('TAOK2', 'KIAA0881', 'MAP3K17', 'PSK', 'PSK1', 'UNQ2971/PRO7431'): 'TAOK2',
#  ('TAOK3', 'DPK', 'JIK', 'KDS', 'MAP3K18'): 'TAOK3',
#  ('TNIK', 'KIAA0551'): 'TNIK',
#  ('ACVR1', 'ACVRLK2'): 'ACVR1',
#  ('ACVR1B', 'ACVRLK4', 'ALK4'): 'ACVR1B',
#  ('ACVR1C', 'ALK7'): 'ACVR1C',
#  ('ACVR2A', 'ACVR2'): 'ACVR2A',
#  ('ACVR2B',): 'ACVR2B',
#  ('ACVRL1', 'ACVRLK1', 'ALK1'): 'ACVRL1',
#  ('AMHR2', 'AMHR', 'MISR2'): 'AMHR2',
#  ('ANKK1', 'PKK2', 'SGK288'): 'ANKK1',
#  ('ARAF', 'ARAF1', 'PKS', 'PKS2'): 'ARAF',
#  ('BMPR1A', 'ACVRLK3', 'ALK3'): 'BMPR1A',
#  ('BMPR1B',): 'BMPR1B',
#  ('BMPR2', 'PPH1'): 'BMPR2',
#  ('BRAF', 'BRAF1', 'RAFB1'): 'BRAF',
#  ('ILK', 'ILK1', 'ILK2'): 'ILK',
#  ('IRAK1', 'IRAK'): 'IRAK1',
#  ('IRAK2',): 'IRAK2',
#  ('IRAK3',): 'IRAK3',
#  ('IRAK4',): 'IRAK4',
#  ('KSR1', 'KSR'): 'KSR1',
#  ('KSR2',): 'KSR2',
#  ('LIMK1', 'LIMK'): 'LIMK1',
#  ('LIMK2',): 'LIMK2',
#  ('LRRK1', 'KIAA1790'): 'LRRK1',
#  ('LRRK2', 'PARK8'): 'LRRK2',
#  ('RAF1', 'RAF'): 'RAF1',
#  ('RIPK1', 'RIP', 'RIP1'): 'RIPK1',
#  ('RIPK2', 'CARDIAK', 'RICK', 'RIP2', 'UNQ277/PRO314/PRO34092'): 'RIPK2',
#  ('RIPK3', 'RIP3'): 'RIPK3',
#  ('RIPK4', 'ANKRD3', 'DIK'): 'RIPK4',
#  ('TESK1',): 'TESK1',
#  ('TESK2',): 'TESK2',
#  ('TGFBR1', 'ALK5', 'SKR4'): 'TGFBR1',
#  ('TGFBR2',): 'TGFBR2',
#  ('TNNI3K', 'CARK'): 'TNNI3K',
#  ('AATK', 'AATYK', 'KIAA0641', 'LMR1', 'LMTK1'): 'AATK',
#  ('ABL1', 'ABL', 'JTK7'): 'ABL1',
#  ('ABL2', 'ABLL', 'ARG'): 'ABL2',
#  ('ALK',): 'ALK',
#  ('AXL', 'UFO'): 'AXL',
#  ('BLK',): 'BLK',
#  ('BMX',): 'BMX',
#  ('BTK', 'AGMX1', 'ATK', 'BPK'): 'BTK',
#  ('CSF1R', 'FMS'): 'CSF1R',
#  ('CSK',): 'CSK',
#  ('DDR1', 'CAK', 'EDDR1', 'NEP', 'NTRK4', 'PTK3A', 'RTK6', 'TRKE'): 'DDR1',
#  ('DDR2', 'NTRKR3', 'TKT', 'TYRO10'): 'DDR2',
#  ('EGFR', 'ERBB', 'ERBB1', 'HER1'): 'EGFR',
#  ('EPHA1', 'EPH', 'EPHT', 'EPHT1'): 'EPHA1',
#  ('EPHA10',): 'EPHA10',
#  ('EPHA2', 'ECK'): 'EPHA2',
#  ('EPHA3', 'ETK', 'ETK1', 'HEK', 'TYRO4'): 'EPHA3',
#  ('EPHA4', 'HEK8', 'SEK', 'TYRO1'): 'EPHA4',
#  ('EPHA5', 'BSK', 'EHK1', 'HEK7', 'TYRO4'): 'EPHA5',
#  ('EPHA6', 'EHK2', 'HEK12'): 'EPHA6',
#  ('EPHA7', 'EHK3', 'HEK11'): 'EPHA7',
#  ('EPHA8', 'EEK', 'HEK3', 'KIAA1459'): 'EPHA8',
#  ('EPHB1', 'ELK', 'EPHT2', 'HEK6', 'NET'): 'EPHB1',
#  ('EPHB2', 'DRT', 'EPHT3', 'EPTH3', 'ERK', 'HEK5', 'TYRO5'): 'EPHB2',
#  ('EPHB3', 'ETK2', 'HEK2', 'TYRO6'): 'EPHB3',
#  ('EPHB4', 'HTK', 'MYK1', 'TYRO11'): 'EPHB4',
#  ('EPHB6',): 'EPHB6',
#  ('ERBB2', 'HER2', 'MLN19', 'NEU', 'NGL'): 'ERBB2',
#  ('ERBB3', 'HER3'): 'ERBB3',
#  ('ERBB4', 'HER4'): 'ERBB4',
#  ('FER', 'TYK3'): 'FER',
#  ('FES', 'FPS'): 'FES',
#  ('FGFR1', 'BFGFR', 'CEK', 'FGFBR', 'FLG', 'FLT2', 'HBGFR'): 'FGFR1',
#  ('FGFR2', 'BEK', 'KGFR', 'KSAM'): 'FGFR2',
#  ('FGFR3', 'JTK4'): 'FGFR3',
#  ('FGFR4', 'JTK2', 'TKF'): 'FGFR4',
#  ('FGR', 'SRC2'): 'FGR',
#  ('FLT1', 'FLT', 'FRT', 'VEGFR1'): 'FLT1',
#  ('FLT3', 'CD135', 'FLK2', 'STK1'): 'FLT3',
#  ('FLT4', 'VEGFR3'): 'FLT4',
#  ('FRK', 'PTK5', 'RAK'): 'FRK',
#  ('FYN',): 'FYN',
#  ('HCK',): 'HCK',
#  ('IGF1R',): 'IGF1R',
#  ('INSR',): 'INSR',
#  ('INSRR', 'IRR'): 'INSRR',
#  ('ITK', 'EMT', 'LYK'): 'ITK',
#  ('JAK1', 'JAK1A', 'JAK1B'): 'JAK1',
#  ('JAK2',): 'JAK2',
#  ('JAK3',): 'JAK3',
#  ('KDR', 'FLK1', 'VEGFR2'): 'KDR',
#  ('KIT', 'SCFR'): 'KIT',
#  ('LCK',): 'LCK',
#  ('LMTK2', 'AATYK2', 'BREK', 'KIAA1079', 'KPI2', 'LMR2'): 'LMTK2',
#  ('LMTK3', 'KIAA1883', 'TYKLM3'): 'LMTK3',
#  ('LTK', 'TYK1'): 'LTK',
#  ('LYN', 'JTK8'): 'LYN',
#  ('MATK', 'CTK', 'HYL'): 'MATK',
#  ('MERTK', 'MER'): 'MERTK',
#  ('MET',): 'MET',
#  ('MST1R', 'PTK8', 'RON'): 'MST1R',
#  ('MUSK',): 'MUSK',
#  ('NTRK1', 'MTC', 'TRK', 'TRKA'): 'NTRK1',
#  ('NTRK2', 'TRKB'): 'NTRK2',
#  ('NTRK3', 'TRKC'): 'NTRK3',
#  ('PDGFRA', 'PDGFR2', 'RHEPDGFRA'): 'PDGFRA',
#  ('PDGFRB', 'PDGFR', 'PDGFR1'): 'PDGFRB',
#  ('PTK2', 'FAK', 'FAK1'): 'PTK2',
#  ('PTK2B', 'FAK2', 'PYK2', 'RAFTK'): 'PTK2B',
#  ('PTK6', 'BRK'): 'PTK6',
#  ('PTK7', 'CCK4'): 'PTK7',
#  ('RET', 'CDHF12', 'CDHR16', 'PTC', 'RET51'): 'RET',
#  ('ROR1', 'NTRKR1'): 'ROR1',
#  ('ROR2', 'NTRKR2'): 'ROR2',
#  ('ROS1', 'MCF3', 'ROS'): 'ROS1',
#  ('RYK', 'JTK5A'): 'RYK',
#  ('SRC', 'SRC1'): 'SRC',
#  ('SRMS', 'C20orf148'): 'SRMS',
#  ('STYK1', 'NOK'): 'STYK1',
#  ('SYK',): 'SYK',
#  ('TEC', 'PSCTK4'): 'TEC',
#  ('TEK', 'TIE2', 'VMCM', 'VMCM1'): 'TEK',
#  ('TIE1', 'TIE'): 'TIE1',
#  ('TNK1',): 'TNK1',
#  ('TNK2', 'ACK1'): 'TNK2',
#  ('TXK', 'PTK4', 'RLK'): 'TXK',
#  ('TYK2',): 'TYK2',
#  ('TYRO3', 'BYK', 'DTK', 'RSE', 'SKY', 'TIF'): 'TYRO3',
#  ('YES1', 'YES'): 'YES1',
#  ('ZAP70', 'SRK'): 'ZAP70',
#  ('AAK1', 'KIAA1048'): 'AAK1',
#  ('AURKA',
#   'AIK',
#   'AIRK1',
#   'ARK1',
#   'AURA',
#   'AYK1',
#   'BTAK',
#   'IAK1',
#   'STK15',
#   'STK6'): 'AURKA',
#  ('AURKB', 'AIK2', 'AIM1', 'AIRK2', 'ARK2', 'STK1', 'STK12', 'STK5'): 'AURKB',
#  ('AURKC', 'AIE2', 'AIK3', 'AIRK3', 'ARK3', 'STK13'): 'AURKC',
#  ('BMP2K', 'BIKE', 'HRIHFB2017'): 'BMP2K',
#  ('BUB1', 'BUB1L'): 'BUB1',
#  ('BUB1B', 'BUBR1', 'MAD3L', 'SSK1'): 'BUB1B',
#  ('CAMKK1', 'CAMKKA'): 'CAMKK1',
#  ('CAMKK2', 'CAMKKB', 'KIAA0787'): 'CAMKK2',
#  ('CDC7', 'CDC7L1'): 'CDC7',
#  ('CHUK', 'IKKA', 'TCF16'): 'CHUK',
#  ('CSNK2A1', 'CK2A1'): 'CSNK2A1',
#  ('CSNK2A2', 'CK2A2'): 'CSNK2A2',
#  ('CSNK2A3', 'CSNK2A1P'): 'CSNK2A3',
#  ('DSTYK', 'KIAA0472', 'RIP5', 'RIPK5', 'SGK496', 'HDCMD38P'): 'DSTYK',
#  ('EIF2AK1', 'HRI', 'KIAA1369', 'PRO1362'): 'EIF2AK1',
#  ('EIF2AK2', 'PKR', 'PRKR'): 'EIF2AK2',
#  ('EIF2AK3', 'PEK', 'PERK'): 'EIF2AK3',
#  ('EIF2AK4', 'GCN2', 'KIAA1338'): 'EIF2AK4',
#  ('ERN1', 'IRE1'): 'ERN1',
#  ('ERN2', 'IRE2'): 'ERN2',
#  ('GAK',): 'GAK',
#  ('HASPIN', 'GSG2'): 'HASPIN',
#  ('IKBKB', 'IKKB'): 'IKBKB',
#  ('IKBKE', 'IKKE', 'IKKI', 'KIAA0151'): 'IKBKE',
#  ('MLKL',): 'MLKL',
#  ('MOS',): 'MOS',
#  ('NRBP1', 'BCON3', 'NRBP'): 'NRBP1',
#  ('NRBP2', 'PP9320', 'TRG16'): 'NRBP2',
#  ('PAN3',): 'PAN3',
#  ('PDIK1L', 'CLIK1L'): 'PDIK1L',
#  ('PEAK1', 'KIAA2002'): 'PEAK1',
#  ('PIK3R4', 'VPS15'): 'PIK3R4',
#  ('PINK1',): 'PINK1',
#  ('PKDCC', 'SGK493', 'VLK'): 'PKDCC',
#  ('PKMYT1', 'MYT1'): 'PKMYT1',
#  ('PLK1', 'PLK'): 'PLK1',
#  ('PLK2', 'SNK'): 'PLK2',
#  ('PLK3', 'CNK', 'FNK', 'PRK'): 'PLK3',
#  ('PLK4', 'SAK', 'STK18'): 'PLK4',
#  ('PLK5', 'PLK5P', 'FG060302'): 'PLK5',
#  ('POMK', 'SGK196'): 'POMK',
#  ('PRAG1', 'SGK223'): 'PRAG1',
#  ('PXK',): 'PXK',
#  ('RNASEL', 'RNS4'): 'RNASEL',
#  ('RPS6KC1', 'RPK118'): 'RPS6KC1',
#  ('RPS6KL1',): 'RPS6KL1',
#  ('RSKR', 'SGK494'): 'RSKR',
#  ('SBK1',): 'SBK1',
#  ('SBK2', 'SGK069'): 'SBK2',
#  ('SBK3', 'SGK110'): 'SBK3',
#  ('SCYL1', 'CVAK90', 'GKLP', 'NTKL', 'TAPK', 'TEIF', 'TRAP', 'HT019'): 'SCYL1',
#  ('SCYL2', 'CVAK104', 'KIAA1360'): 'SCYL2',
#  ('SCYL3', 'PACE1'): 'SCYL3',
#  ('STK16', 'MPSK1', 'PKL12', 'TSF1'): 'STK16',
#  ('STK31', 'SGK396'): 'STK31',
#  ('STK32A', 'YANK1'): 'STK32A',
#  ('STK32B', 'YANK2', 'UNQ3003/PRO9744'): 'STK32B',
#  ('STK32C', 'YANK3'): 'STK32C',
#  ('STK35', 'CLIK1', 'PDIK1', 'STK35L1'): 'STK35',
#  ('STK36', 'KIAA1278'): 'STK36',
#  ('STKLD1', 'C9orf96', 'SGK071'): 'STKLD1',
#  ('TBCK', 'TBCKL', 'HSPC302'): 'TBCK',
#  ('TBK1', 'NAK'): 'TBK1',
#  ('TEX14', 'SGK307'): 'TEX14',
#  ('TLK1', 'KIAA0137'): 'TLK1',
#  ('TLK2',): 'TLK2',
#  ('TP53RK', 'C20orf64', 'PRPK'): 'TP53RK',
#  ('TTK', 'MPS1', 'MPS1L1'): 'TTK',
#  ('UHMK1', 'KIS', 'KIST'): 'UHMK1',
#  ('ULK1', 'KIAA0722'): 'ULK1',
#  ('ULK2', 'KIAA0623'): 'ULK2',
#  ('ULK3',): 'ULK3',
#  ('ULK4',): 'ULK4',
#  ('WEE1',): 'WEE1',
#  ('WEE2', 'WEE1B'): 'WEE2',
#  ('WNK1', 'HSN2', 'KDP', 'KIAA0344', 'PRKWNK1'): 'WNK1',
#  ('WNK2', 'KIAA1760', 'PRKWNK2', 'SDCCAG43', 'P/OKcl.13'): 'WNK2',
#  ('WNK3', 'KIAA1566', 'PRKWNK3'): 'WNK3',
#  ('WNK4', 'PRKWNK4'): 'WNK4',
#  ('ADCK1',): 'ADCK1',
#  ('ADCK2', 'AARF'): 'ADCK2',
#  ('ADCK5',): 'ADCK5',
#  ('COQ8A', 'ADCK3', 'CABC1', 'PP265'): 'COQ8A',
#  ('COQ8B', 'ADCK4'): 'COQ8B',
#  ('ALPK1', 'KIAA1527', 'LAK'): 'ALPK1',
#  ('ALPK2', 'HAK'): 'ALPK2',
#  ('ALPK3', 'KIAA1330', 'MAK'): 'ALPK3',
#  ('EEF2K',): 'EEF2K',
#  ('TRPM6', 'CHAK2'): 'TRPM6',
#  ('TRPM7', 'CHAK1', 'LTRPC7'): 'TRPM7',
#  ('FASTK',): 'FASTK',
#  ('BCKDK',): 'BCKDK',
#  ('PDK1', 'PDHK1'): 'PDK1',
#  ('PDK2', 'PDHK2'): 'PDK2',
#  ('PDK3', 'PDHK3'): 'PDK3',
#  ('PDK4', 'PDHK4'): 'PDK4',
#  ('ATM',): 'ATM',
#  ('ATR', 'FRP1'): 'ATR',
#  ('MTOR', 'FRAP', 'FRAP1', 'FRAP2', 'RAFT1', 'RAPT1'): 'MTOR',
#  ('PIK3CA',): 'PIK3CA',
#  ('PIK3CB', 'PIK3C1'): 'PIK3CB',
#  ('PIK3CD',): 'PIK3CD',
#  ('PIK3CG',): 'PIK3CG',
#  ('PRKDC', 'HYRC', 'HYRC1'): 'PRKDC',
#  ('SMG1', 'ATX', 'KIAA0421', 'LIP'): 'SMG1',
#  ('RIOK1', 'RIO1'): 'RIOK1',
#  ('RIOK2', 'RIO2'): 'RIOK2',
#  ('RIOK3', 'SUDD'): 'RIOK3'}

# %%
#turn mo's kinase_gene into a list
mo_kinase_gene = kinase_substrate_df['GENE'].to_list()
mo_kinase_gene

# %%
#turns the aliases into a list
kinase_list = []
for aliases in kinase_dict:
    for gene in aliases:
        kinase_list.append(gene)
kinase_list
# Out:
# ['AKT1',
#  'PKB',
#  'RAC',
#  'AKT2',
#  'AKT3',
#  'PKBG',
#  'CDC42BPA',
#  'KIAA0451',
#  'CDC42BPB',
#  'KIAA1124',
#  'CDC42BPG',
#  'DMPK2',
#  'CIT',
#  'CRIK',
#  'KIAA0949',
#  'STK21',
#  'DMPK',
#  'DM1PK',
#  'MDPK',
#  'GRK1',
#  'RHOK',
#  'GRK2',
#  'ADRBK1',
#  'BARK',
#  'BARK1',
#  'GRK3',
#  'ADRBK2',
#  'BARK2',
#  'GRK4',
#  'GPRK2L',
#  'GPRK4',
#  'GRK5',
#  'GPRK5',
#  'GRK6',
#  'GPRK6',
#  'GRK7',
#  'GPRK7',
#  'LATS1',
#  'WARTS',
#  'LATS2',
#  'KPM',
#  'MAST1',
#  'KIAA0973',
#  'SAST',
#  'MAST2',
#  'KIAA0807',
#  'MAST205',
#  'MAST3',
#  'KIAA0561',
#  'MAST4',
#  'KIAA0303',
#  'MASTL',
#  'GW',
#  'GWL',
#  'THC2',
#  'PDPK1',
#  'PDK1',
#  'PDPK2P',
#  'PDPK2',
#  'PKN1',
#  'PAK1',
#  'PKN',
#  'PRK1',
#  'PRKCL1',
#  'PKN2',
#  'PRK2',
#  'PRKCL2',
#  'PKN3',
#  'PKNBETA',
#  'PRKACA',
#  'PKACA',
#  'PRKACB',
#  'PRKACG',
#  'PRKCA',
#  'PKCA',
#  'PRKACA',
#  'PRKCB',
#  'PKCB',
#  'PRKCB1',
#  'PRKCD',
#  'PRKCE',
#  'PKCE',
#  'PRKCG',
#  'PKCG',
#  'PRKCH',
#  'PKCL',
#  'PRKCL',
#  'PRKCI',
#  'DXS1179E',
#  'PRKCQ',
#  'PRKCT',
#  'PRKCZ',
#  'PKC2',
#  'PRKG1',
#  'PRKG1B',
#  'PRKGR1A',
#  'PRKGR1B',
#  'PRKG2',
#  'PRKGR2',
#  'PRKX',
#  'PKX1',
#  'PRKY',
#  'ROCK1',
#  'ROCK2',
#  'KIAA0619',
#  'RPS6KA1',
#  'MAPKAPK1A',
#  'RSK1',
#  'RPS6KA2',
#  'MAPKAPK1C',
#  'RSK3',
#  'RPS6KA3',
#  'ISPK1',
#  'MAPKAPK1B',
#  'RSK2',
#  'RPS6KA4',
#  'MSK2',
#  'RPS6KA5',
#  'MSK1',
#  'RPS6KA6',
#  'RSK4',
#  'RPS6KB1',
#  'STK14A',
#  'RPS6KB2',
#  'STK14B',
#  'SGK1',
#  'SGK',
#  'SGK2',
#  'SGK3',
#  'CISK',
#  'SGKL',
#  'STK38',
#  'NDR1',
#  'STK38L',
#  'KIAA0965',
#  'NDR2',
#  'BRSK1',
#  'KIAA1811',
#  'SAD1',
#  'SADB',
#  'BRSK2',
#  'C11orf7',
#  'PEN11B',
#  'SADA',
#  'STK29',
#  'HUSSY-12',
#  'CAMK1',
#  'CAMK1D',
#  'CAMKID',
#  'CAMK1G',
#  'CLICK3',
#  'VWS1',
#  'CAMK2A',
#  'CAMKA',
#  'KIAA0968',
#  'CAMK2B',
#  'CAM2',
#  'CAMK2',
#  'CAMKB',
#  'CAMK2D',
#  'CAMKD',
#  'CAMK2G',
#  'CAMK',
#  'CAMK-II',
#  'CAMKG',
#  'CAMK4',
#  'CAMK',
#  'CAMK-GR',
#  'CAMKIV',
#  'CAMKV',
#  'CASK',
#  'LIN2',
#  'CHEK1',
#  'CHK1',
#  'CHEK2',
#  'CDS1',
#  'CHK2',
#  'RAD53',
#  'DAPK1',
#  'DAPK',
#  'DAPK2',
#  'DAPK3',
#  'ZIPK',
#  'DCLK1',
#  'DCAMKL1',
#  'DCDC3A',
#  'KIAA0369',
#  'DCLK2',
#  'DCAMKL2',
#  'DCDC3B',
#  'DCK2',
#  'DCLK3',
#  'DCAMKL3',
#  'DCDC3C',
#  'KIAA1765',
#  'HUNK',
#  'MAKV',
#  'KALRN',
#  'DUET',
#  'DUO',
#  'HAPIP',
#  'TRAD',
#  'MAPKAPK2',
#  'MAPKAPK3',
#  'MAPKAPK5',
#  'PRAK',
#  'MARK1',
#  'KIAA1477',
#  'MARK',
#  'MARK2',
#  'EMK1',
#  'MARK3',
#  'CTAK1',
#  'EMK2',
#  'MARK4',
#  'KIAA1860',
#  'MARKL1',
#  'MELK',
#  'KIAA0175',
#  'MKNK1',
#  'MNK1',
#  'MKNK2',
#  'GPRK7',
#  'MNK2',
#  'MYLK',
#  'MLCK',
#  'MLCK1',
#  'MYLK1',
#  'MYLK2',
#  'MYLK3',
#  'MLCK',
#  'MYLK4',
#  'SGK085',
#  'NIM1K',
#  'NIM1',
#  'NUAK1',
#  'ARK5',
#  'KIAA0537',
#  'OMPHK1',
#  'NUAK2',
#  'OMPHK2',
#  'SNARK',
#  'OBSCN',
#  'KIAA1556',
#  'KIAA1639',
#  'PASK',
#  'KIAA0135',
#  'PHKG1',
#  'PHKG',
#  'PHKG2',
#  'PIM1',
#  'PIM2',
#  'PIM3',
#  'PNCK',
#  'PRKAA1',
#  'AMPK1',
#  'PRKAA2',
#  'AMPK',
#  'AMPK2',
#  'PRKD1',
#  'PKD',
#  'PKD1',
#  'PRKCM',
#  'PRKD2',
#  'PKD2',
#  'HSPC187',
#  'PRKD3',
#  'EPK2',
#  'PRKCN',
#  'PSKH1',
#  'PSKH2',
#  'SIK1',
#  'SIK',
#  'SNF1LK',
#  'SIK1B',
#  'SIK2',
#  'KIAA0781',
#  'QIK',
#  'SNF1LK2',
#  'SIK3',
#  'KIAA0999',
#  'QSK',
#  'L19',
#  'SNRK',
#  'KIAA0096',
#  'SNFRK',
#  'SPEG',
#  'APEG1',
#  'KIAA1297',
#  'STK11',
#  'LKB1',
#  'PJS',
#  'STK17A',
#  'DRAK1',
#  'STK17B',
#  'DRAK2',
#  'STK33',
#  'STK40',
#  'SGK495',
#  'SHIK',
#  'TRIB1',
#  'C8FW',
#  'GIG2',
#  'TRB1',
#  'TRIB2',
#  'TRB2',
#  'TRIB3',
#  'C20orf97',
#  'NIPK',
#  'SKIP3',
#  'TRB3',
#  'TRIO',
#  'TSSK1B',
#  'SPOGA1',
#  'SPOGA4',
#  'STK22A',
#  'STK22D',
#  'TSSK1',
#  'FKSG81',
#  'TSSK2',
#  'DGSG',
#  'SPOGA2',
#  'STK22B',
#  'TSSK3',
#  'SPOGA3',
#  'STK22C',
#  'TSSK4',
#  'C14orf20',
#  'STK22E',
#  'TSSK5',
#  'TSSK6',
#  'SSTK',
#  'FKSG82',
#  'TTN',
#  'CSNK1A1',
#  'CSNK1A1L',
#  'CSNK1D',
#  'HCKID',
#  'CSNK1E',
#  'CSNK1G1',
#  'CSNK1G2',
#  'CK1G2',
#  'CSNK1G3',
#  'TTBK1',
#  'BDTK',
#  'KIAA1855',
#  'TTBK2',
#  'KIAA0847',
#  'VRK1',
#  'VRK2',
#  'VRK3',
#  'CDK1',
#  'CDC2',
#  'CDC28A',
#  'CDKN1',
#  'P34CDC2',
#  'CDK10',
#  'CDK11A',
#  'CDC2L2',
#  'CDC2L3',
#  'PITSLREB',
#  'CDK11B',
#  'CDC2L1',
#  'CDK11',
#  'PITSLREA',
#  'PK58',
#  'CDK12',
#  'CRK7',
#  'CRKRS',
#  'KIAA0904',
#  'CDK13',
#  'CDC2L',
#  'CDC2L5',
#  'CHED',
#  'KIAA1791',
#  'CDK14',
#  'KIAA0834',
#  'PFTK1',
#  'CDK15',
#  'ALS2CR7',
#  'PFTK2',
#  'CDK16',
#  'PCTAIRE1',
#  'PCTK1',
#  'CDK17',
#  'PCTAIRE2',
#  'PCTK2',
#  'CDK18',
#  'PCTAIRE3',
#  'PCTK3',
#  'CDK19',
#  'CDC2L6',
#  'CDK11',
#  'KIAA1028',
#  'CDK2',
#  'CDKN2',
#  'CDK20',
#  'CCRK',
#  'CDCH',
#  'CDK3',
#  'CDKN3',
#  'CDK4',
#  'CDK5',
#  'CDKN5',
#  'CDK6',
#  'CDKN6',
#  'CDK7',
#  'CAK',
#  'CAK1',
#  'CDKN7',
#  'MO15',
#  'STK1',
#  'CDK8',
#  'CDK9',
#  'CDC2L4',
#  'TAK',
#  'CDKL1',
#  'CDKL2',
#  'CDKL3',
#  'NKIAMRE',
#  'CDKL4',
#  'CDKL5',
#  'STK9',
#  'CLK1',
#  'CLK',
#  'CLK2',
#  'CLK3',
#  'CLK4',
#  'DYRK1A',
#  'DYRK',
#  'MNB',
#  'MNBH',
#  'DYRK1B',
#  'MIRK',
#  'DYRK2',
#  'DYRK3',
#  'DYRK4',
#  'GSK3A',
#  'GSK3B',
#  'HIPK1',
#  'KIAA0630',
#  'MYAK',
#  'NBAK2',
#  'HIPK2',
#  'HIPK3',
#  'DYRK6',
#  'FIST3',
#  'PKY',
#  'HIPK4',
#  'ICK',
#  'KIAA0936',
#  'MAK',
#  'MAPK1',
#  'ERK2',
#  'PRKM1',
#  'PRKM2',
#  'MAPK10',
#  'JNK3',
#  'JNK3A',
#  'PRKM10',
#  'SAPK1B',
#  'MAPK11',
#  'PRKM11',
#  'SAPK2',
#  'SAPK2B',
#  'MAPK12',
#  'ERK6',
#  'SAPK3',
#  'MAPK13',
#  'PRKM13',
#  'SAPK4',
#  'MAPK14',
#  'CSBP',
#  'CSBP1',
#  'CSBP2',
#  'CSPB1',
#  'MXI2',
#  'SAPK2A',
#  'MAPK15',
#  'ERK7',
#  'ERK8',
#  'MAPK3',
#  'ERK1',
#  'PRKM3',
#  'MAPK4',
#  'ERK4',
#  'PRKM4',
#  'MAPK6',
#  'ERK3',
#  'PRKM6',
#  'MAPK7',
#  'BMK1',
#  'ERK5',
#  'PRKM7',
#  'MAPK8',
#  'JNK1',
#  'PRKM8',
#  'SAPK1',
#  'SAPK1C',
#  'MAPK9',
#  'JNK2',
#  'PRKM9',
#  'SAPK1A',
#  'MOK',
#  'RAGE',
#  'RAGE1',
#  'NLK',
#  'LAK1',
#  'PRPF4B',
#  'KIAA0536',
#  'PRP4',
#  'PRP4H',
#  'PRP4K',
#  'SRPK1',
#  'SRPK2',
#  'SRPK3',
#  'MSSK1',
#  'STK23',
#  'NEK1',
#  'KIAA1901',
#  'NEK10',
#  'NEK11',
#  'NEK2',
#  'NEK2A',
#  'NLK1',
#  'NEK3',
#  'NEK4',
#  'STK2',
#  'NEK5',
#  'NEK6',
#  'NEK7',
#  'NEK8',
#  'JCK',
#  'NEK12A',
#  'NEK9',
#  'KIAA1995',
#  'NEK8',
#  'NERCC',
#  'GUCY2C',
#  'GUC2C',
#  'STAR',
#  'GUCY2D',
#  'CORD6',
#  'GUC1A4',
#  'GUC2D',
#  'RETGC',
#  'RETGC1',
#  'GUCY2F',
#  'GUC2F',
#  'RETGC2',
#  'NPR1',
#  'ANPRA',
#  'NPR2',
#  'ANPRB',
#  'MAP2K1',
#  'MEK1',
#  'PRKMK1',
#  'MAP2K2',
#  'MEK2',
#  'MKK2',
#  'PRKMK2',
#  'MAP2K3',
#  'MEK3',
#  'MKK3',
#  'PRKMK3',
#  'SKK2',
#  'MAP2K4',
#  'JNKK1',
#  'MEK4',
#  'MKK4',
#  'PRKMK4',
#  'SEK1',
#  'SERK1',
#  'SKK1',
#  'MAP2K5',
#  'MEK5',
#  'MKK5',
#  'PRKMK5',
#  'MAP2K6',
#  'MEK6',
#  'MKK6',
#  'PRKMK6',
#  'SKK3',
#  'MAP2K7',
#  'JNKK2',
#  'MEK7',
#  'MKK7',
#  'PRKMK7',
#  'SKK4',
#  'MAP3K1',
#  'MAPKKK1',
#  'MEKK',
#  'MEKK1',
#  'MAP3K10',
#  'MLK2',
#  'MST',
#  'MAP3K11',
#  'MLK3',
#  'PTK1',
#  'SPRK',
#  'MAP3K12',
#  'ZPK',
#  'MAP3K13',
#  'LZK',
#  'MAP3K14',
#  'NIK',
#  'MAP3K15',
#  'ASK3',
#  'MAP3K19',
#  'RCK',
#  'YSK4',
#  'MAP3K2',
#  'MAPKKK2',
#  'MEKK2',
#  'MAP3K20',
#  'MLTK',
#  'ZAK',
#  'HCCS4',
#  'MAP3K21',
#  'KIAA1804',
#  'MLK4',
#  'MAP3K3',
#  'MAPKKK3',
#  'MEKK3',
#  'MAP3K4',
#  'KIAA0213',
#  'MAPKKK4',
#  'MEKK4',
#  'MTK1',
#  'MAP3K5',
#  'ASK1',
#  'MAPKKK5',
#  'MEKK5',
#  'MAP3K6',
#  'ASK2',
#  'MAPKKK6',
#  'MEKK6',
#  'MAP3K7',
#  'TAK1',
#  'MAP3K8',
#  'COT',
#  'ESTF',
#  'MAP3K9',
#  'MLK1',
#  'PRKE1',
#  'MAP4K1',
#  'HPK1',
#  'MAP4K2',
#  'GCK',
#  'RAB8IP',
#  'MAP4K3',
#  'RAB8IPL1',
#  'MAP4K4',
#  'HGK',
#  'KIAA0687',
#  'NIK',
#  'MAP4K5',
#  'MINK1',
#  'B55',
#  'MAP4K6',
#  'MINK',
#  'YSK2',
#  'ZC3',
#  'MYO3A',
#  'MYO3B',
#  'NRK',
#  'OXSR1',
#  'KIAA1101',
#  'OSR1',
#  'PAK1',
#  'PAK2',
#  'PAK3',
#  'OPHN3',
#  'PAK4',
#  'KIAA1142',
#  'PAK5',
#  'KIAA1264',
#  'PAK7',
#  'PAK6',
#  'PAK5',
#  'PBK',
#  'TOPK',
#  'SLK',
#  'KIAA0204',
#  'STK2',
#  'STK10',
#  'LOK',
#  'STK24',
#  'MST3',
#  'STK3',
#  'STK25',
#  'SOK1',
#  'YSK1',
#  'STK26',
#  'MASK',
#  'MST4',
#  'STK3',
#  'KRS1',
#  'MST2',
#  'STK39',
#  'SPAK',
#  'STK4',
#  'KRS2',
#  'MST1',
#  'STRADA',
#  'LYK5',
#  'STRAD',
#  'STRADB',
#  'ALS2CR2',
#  'ILPIP',
#  'PRO1038',
#  'TAOK1',
#  'KIAA1361',
#  'MAP3K16',
#  'MARKK',
#  'TAOK2',
#  'KIAA0881',
#  'MAP3K17',
#  'PSK',
#  'PSK1',
#  'UNQ2971/PRO7431',
#  'TAOK3',
#  'DPK',
#  'JIK',
#  'KDS',
#  'MAP3K18',
#  'TNIK',
#  'KIAA0551',
#  'ACVR1',
#  'ACVRLK2',
#  'ACVR1B',
#  'ACVRLK4',
#  'ALK4',
#  'ACVR1C',
#  'ALK7',
#  'ACVR2A',
#  'ACVR2',
#  'ACVR2B',
#  'ACVRL1',
#  'ACVRLK1',
#  'ALK1',
#  'AMHR2',
#  'AMHR',
#  'MISR2',
#  'ANKK1',
#  'PKK2',
#  'SGK288',
#  'ARAF',
#  'ARAF1',
#  'PKS',
#  'PKS2',
#  'BMPR1A',
#  'ACVRLK3',
#  'ALK3',
#  'BMPR1B',
#  'BMPR2',
#  'PPH1',
#  'BRAF',
#  'BRAF1',
#  'RAFB1',
#  'ILK',
#  'ILK1',
#  'ILK2',
#  'IRAK1',
#  'IRAK',
#  'IRAK2',
#  'IRAK3',
#  'IRAK4',
#  'KSR1',
#  'KSR',
#  'KSR2',
#  'LIMK1',
#  'LIMK',
#  'LIMK2',
#  'LRRK1',
#  'KIAA1790',
#  'LRRK2',
#  'PARK8',
#  'RAF1',
#  'RAF',
#  'RIPK1',
#  'RIP',
#  'RIP1',
#  'RIPK2',
#  'CARDIAK',
#  'RICK',
#  'RIP2',
#  'UNQ277/PRO314/PRO34092',
#  'RIPK3',
#  'RIP3',
#  'RIPK4',
#  'ANKRD3',
#  'DIK',
#  'TESK1',
#  'TESK2',
#  'TGFBR1',
#  'ALK5',
#  'SKR4',
#  'TGFBR2',
#  'TNNI3K',
#  'CARK',
#  'AATK',
#  'AATYK',
#  'KIAA0641',
#  'LMR1',
#  'LMTK1',
#  'ABL1',
#  'ABL',
#  'JTK7',
#  'ABL2',
#  'ABLL',
#  'ARG',
#  'ALK',
#  'AXL',
#  'UFO',
#  'BLK',
#  'BMX',
#  'BTK',
#  'AGMX1',
#  'ATK',
#  'BPK',
#  'CSF1R',
#  'FMS',
#  'CSK',
#  'DDR1',
#  'CAK',
#  'EDDR1',
#  'NEP',
#  'NTRK4',
#  'PTK3A',
#  'RTK6',
#  'TRKE',
#  'DDR2',
#  'NTRKR3',
#  'TKT',
#  'TYRO10',
#  'EGFR',
#  'ERBB',
#  'ERBB1',
#  'HER1',
#  'EPHA1',
#  'EPH',
#  'EPHT',
#  'EPHT1',
#  'EPHA10',
#  'EPHA2',
#  'ECK',
#  'EPHA3',
#  'ETK',
#  'ETK1',
#  'HEK',
#  'TYRO4',
#  'EPHA4',
#  'HEK8',
#  'SEK',
#  'TYRO1',
#  'EPHA5',
#  'BSK',
#  'EHK1',
#  'HEK7',
#  'TYRO4',
#  'EPHA6',
#  'EHK2',
#  'HEK12',
#  'EPHA7',
#  'EHK3',
#  'HEK11',
#  'EPHA8',
#  'EEK',
#  'HEK3',
#  'KIAA1459',
#  'EPHB1',
#  'ELK',
#  'EPHT2',
#  'HEK6',
#  'NET',
#  'EPHB2',
#  'DRT',
#  'EPHT3',
#  'EPTH3',
#  'ERK',
#  'HEK5',
#  'TYRO5',
#  'EPHB3',
#  'ETK2',
#  'HEK2',
#  'TYRO6',
#  'EPHB4',
#  'HTK',
#  'MYK1',
#  'TYRO11',
#  'EPHB6',
#  'ERBB2',
#  'HER2',
#  'MLN19',
#  'NEU',
#  'NGL',
#  'ERBB3',
#  'HER3',
#  'ERBB4',
#  'HER4',
#  'FER',
#  'TYK3',
#  'FES',
#  'FPS',
#  'FGFR1',
#  'BFGFR',
#  'CEK',
#  'FGFBR',
#  'FLG',
#  'FLT2',
#  'HBGFR',
#  'FGFR2',
#  'BEK',
#  'KGFR',
#  'KSAM',
#  'FGFR3',
#  'JTK4',
#  'FGFR4',
#  'JTK2',
#  'TKF',
#  'FGR',
#  'SRC2',
#  'FLT1',
#  'FLT',
#  'FRT',
#  'VEGFR1',
#  'FLT3',
#  'CD135',
#  'FLK2',
#  'STK1',
#  'FLT4',
#  'VEGFR3',
#  'FRK',
#  'PTK5',
#  'RAK',
#  'FYN',
#  'HCK',
#  'IGF1R',
#  'INSR',
#  'INSRR',
#  'IRR',
#  'ITK',
#  'EMT',
#  'LYK',
#  'JAK1',
#  'JAK1A',
#  'JAK1B',
#  'JAK2',
#  'JAK3',
#  'KDR',
#  'FLK1',
#  'VEGFR2',
#  'KIT',
#  'SCFR',
#  'LCK',
#  'LMTK2',
#  'AATYK2',
#  'BREK',
#  'KIAA1079',
#  'KPI2',
#  'LMR2',
#  'LMTK3',
#  'KIAA1883',
#  'TYKLM3',
#  'LTK',
#  'TYK1',
#  'LYN',
#  'JTK8',
#  'MATK',
#  'CTK',
#  'HYL',
#  'MERTK',
#  'MER',
#  'MET',
#  'MST1R',
#  'PTK8',
#  'RON',
#  'MUSK',
#  'NTRK1',
#  'MTC',
#  'TRK',
#  'TRKA',
#  'NTRK2',
#  'TRKB',
#  'NTRK3',
#  'TRKC',
#  'PDGFRA',
#  'PDGFR2',
#  'RHEPDGFRA',
#  'PDGFRB',
#  'PDGFR',
#  'PDGFR1',
#  'PTK2',
#  'FAK',
#  'FAK1',
#  'PTK2B',
#  'FAK2',
#  'PYK2',
#  'RAFTK',
#  ...]

# %%
#loop through the list to find any mo's gene that might not be available in mine
not_available=[]
available = []
for gene_query in mo_kinase_gene:
    if gene_query in available:
        continue
    elif gene_query in not_available:
        continue
    else:
        if gene_query in kinase_list:
            available.append(gene_query)
        else:
            not_available.append(gene_query)
print(len(available))
print(not_available)
# Out:
# 340
# ['GTF2F1', 'PRKAG2', 'BCR/ABL', 'NME1', 'HSPA5', 'BCR', 'PIKFYVE', 'PHKA1', 'BAZ1B', 'TAF1', 'TGM2', 'ENPP3', 'PGK1', 'NME2', 'COL4A3BP', 'NPM/ALK', 'PRKAB1', 'PKM', 'BLVRA', 'CSNK2B', 'BRD4', 'FAM20C']

# %%
#output the unavailable into csv
unavailable_df = pd.DataFrame(not_available, columns=['unavailable_kinase'])
unavailable_df.to_csv('unavailable_mo_kinase.csv', index=False)

# %% [markdown]
# We found that there are 22 kinases in Mo's which are not available in the original human kinase list that Han compiled. we took a look at the kinases. We found that a few of them are not real human kinases in Uniprot and others are only kinases in disease state. Therefore we decided to drop them from the phosphosites (clean_human_kinase_substrates.csv).

# %% [markdown]
# # Dropping the unavailable kinases from Mo's phosphosite data

# %%
#Mo's kinase_substrate df
kinase_substrate_df.head()
# Out:
#    Unnamed: 0     GENE KINASE KIN_ACC_ID   SUBSTRATE  SUB_GENE_ID SUB_ACC_ID  \
# 0           7  EIF2AK1    HRI     Q9BQI3  eIF2-alpha       1965.0     P05198
# 1           8  EIF2AK1    HRI     Q9BQI3  eIF2-alpha       1965.0     P05198
# 2          11    PRKCD   PKCD     Q05655       HDAC5      10014.0     Q9UQL6
# 3          12    PRKCD   PKCD     Q05655  PTPRA iso2       5786.0   P18433-2
# 4          13    PRKCD   PKCD     Q05655     hnRNP K       3190.0     P61978
#
#   SUB_GENE SUB_MOD_RSD  SITE_GRP_ID     SITE_+/-7_AA DOMAIN
# 0   EIF2S1         S52       447635  MILLsELsRRRIRsI     S1
# 1   EIF2S1         S49       450210  IEGMILLsELsRRRI     S1
# 2    HDAC5        S259       447995  FPLRkTAsEPNLKVR    NaN
# 3    PTPRA        S204       447612  PLLARSPsTNRKYPP    NaN
# 4   HNRNPK        S302       457408  GrGGrGGsrArNLPL    NaN

# %%
#replace the GENE that are not in Han's kinase list
for i in range(len(kinase_substrate_df['GENE'])):
    gene = kinase_substrate_df.iloc[i]['GENE']
    if gene in not_available:
        kinase_substrate_df.loc[gene, 'GENE'] = 'NULL'
kinase_substrate_df
# Out:
#         Unnamed: 0     GENE KINASE KIN_ACC_ID   SUBSTRATE  SUB_GENE_ID  \
# 0              7.0  EIF2AK1    HRI     Q9BQI3  eIF2-alpha       1965.0
# 1              8.0  EIF2AK1    HRI     Q9BQI3  eIF2-alpha       1965.0
# 2             11.0    PRKCD   PKCD     Q05655       HDAC5      10014.0
# 3             12.0    PRKCD   PKCD     Q05655  PTPRA iso2       5786.0
# 4             13.0    PRKCD   PKCD     Q05655     hnRNP K       3190.0
# ...            ...      ...    ...        ...         ...          ...
# PKM            NaN     NULL    NaN        NaN         NaN          NaN
# BLVRA          NaN     NULL    NaN        NaN         NaN          NaN
# CSNK2B         NaN     NULL    NaN        NaN         NaN          NaN
# BRD4           NaN     NULL    NaN        NaN         NaN          NaN
# FAM20C         NaN     NULL    NaN        NaN         NaN          NaN
#
#        SUB_ACC_ID SUB_GENE SUB_MOD_RSD  SITE_GRP_ID     SITE_+/-7_AA DOMAIN
# 0          P05198   EIF2S1         S52     447635.0  MILLsELsRRRIRsI     S1
# 1          P05198   EIF2S1         S49     450210.0  IEGMILLsELsRRRI     S1
# 2          Q9UQL6    HDAC5        S259     447995.0  FPLRkTAsEPNLKVR    NaN
# 3        P18433-2    PTPRA        S204     447612.0  PLLARSPsTNRKYPP    NaN
# 4          P61978   HNRNPK        S302     457408.0  GrGGrGGsrArNLPL    NaN
# ...           ...      ...         ...          ...              ...    ...
# PKM           NaN      NaN         NaN          NaN              NaN    NaN
# BLVRA         NaN      NaN         NaN          NaN              NaN    NaN
# CSNK2B        NaN      NaN         NaN          NaN              NaN    NaN
# BRD4          NaN      NaN         NaN          NaN              NaN    NaN
# FAM20C        NaN      NaN         NaN          NaN              NaN    NaN
#
# [11003 rows x 12 columns]

# %%
#dropping the rows with NULL in GENE
kinase_substrate_df = kinase_substrate_df[kinase_substrate_df.GENE != 'NULL']
kinase_substrate_df.reset_index(drop=True)
# Out:
#        Unnamed: 0     GENE KINASE KIN_ACC_ID   SUBSTRATE  SUB_GENE_ID  \
# 0             7.0  EIF2AK1    HRI     Q9BQI3  eIF2-alpha       1965.0
# 1             8.0  EIF2AK1    HRI     Q9BQI3  eIF2-alpha       1965.0
# 2            11.0    PRKCD   PKCD     Q05655       HDAC5      10014.0
# 3            12.0    PRKCD   PKCD     Q05655  PTPRA iso2       5786.0
# 4            13.0    PRKCD   PKCD     Q05655     hnRNP K       3190.0
# ...           ...      ...    ...        ...         ...          ...
# 10976     18451.0    NUAK1  NuaK1     O60285       MYPT1       4659.0
# 10977     18452.0    NUAK1  NuaK1     O60285       LATS1       9113.0
# 10978     18453.0     ULK2   ULK2     Q8IYT8      SEC16A       9919.0
# 10979     18454.0     ULK2   ULK2     Q8IYT8      DENND3      22898.0
# 10980     18455.0     ULK2   ULK2     Q8IYT8      DENND3      22898.0
#
#       SUB_ACC_ID  SUB_GENE SUB_MOD_RSD  SITE_GRP_ID     SITE_+/-7_AA DOMAIN
# 0         P05198    EIF2S1         S52     447635.0  MILLsELsRRRIRsI     S1
# 1         P05198    EIF2S1         S49     450210.0  IEGMILLsELsRRRI     S1
# 2         Q9UQL6     HDAC5        S259     447995.0  FPLRkTAsEPNLKVR    NaN
# 3       P18433-2     PTPRA        S204     447612.0  PLLARSPsTNRKYPP    NaN
# 4         P61978    HNRNPK        S302     457408.0  GrGGrGGsrArNLPL    NaN
# ...          ...       ...         ...          ...              ...    ...
# 10976     O14974  PPP1R12A        S910    1983104.0  sLLGRsGsysyLEER    NaN
# 10977     O95835     LATS1        S464     451855.0  NIPVRsNsFNNPLGN    NaN
# 10978     O15027    SEC16A        S846   55578720.0  LAQPINFsVSLSNSH    NaN
# 10979     A2RUS2    DENND3        S472    7997148.0  THRRMVVsMPNLQDI    NaN
# 10980     A2RUS2    DENND3        S490   23050193.0  ELAPRNSsLRLtDTA    NaN
#
# [10981 rows x 12 columns]

# %%
kinase_substrate_df.head()
# Out:
#    Unnamed: 0     GENE KINASE KIN_ACC_ID   SUBSTRATE  SUB_GENE_ID SUB_ACC_ID  \
# 0         7.0  EIF2AK1    HRI     Q9BQI3  eIF2-alpha       1965.0     P05198
# 1         8.0  EIF2AK1    HRI     Q9BQI3  eIF2-alpha       1965.0     P05198
# 2        11.0    PRKCD   PKCD     Q05655       HDAC5      10014.0     Q9UQL6
# 3        12.0    PRKCD   PKCD     Q05655  PTPRA iso2       5786.0   P18433-2
# 4        13.0    PRKCD   PKCD     Q05655     hnRNP K       3190.0     P61978
#
#   SUB_GENE SUB_MOD_RSD  SITE_GRP_ID     SITE_+/-7_AA DOMAIN
# 0   EIF2S1         S52     447635.0  MILLsELsRRRIRsI     S1
# 1   EIF2S1         S49     450210.0  IEGMILLsELsRRRI     S1
# 2    HDAC5        S259     447995.0  FPLRkTAsEPNLKVR    NaN
# 3    PTPRA        S204     447612.0  PLLARSPsTNRKYPP    NaN
# 4   HNRNPK        S302     457408.0  GrGGrGGsrArNLPL    NaN

# %%
kinase_substrate_df=kinase_substrate_df.drop('Unnamed: 0',axis=1)
kinase_substrate_df
# Out:
#           GENE KINASE KIN_ACC_ID   SUBSTRATE  SUB_GENE_ID SUB_ACC_ID  \
# 0      EIF2AK1    HRI     Q9BQI3  eIF2-alpha       1965.0     P05198
# 1      EIF2AK1    HRI     Q9BQI3  eIF2-alpha       1965.0     P05198
# 2        PRKCD   PKCD     Q05655       HDAC5      10014.0     Q9UQL6
# 3        PRKCD   PKCD     Q05655  PTPRA iso2       5786.0   P18433-2
# 4        PRKCD   PKCD     Q05655     hnRNP K       3190.0     P61978
# ...        ...    ...        ...         ...          ...        ...
# 10976    NUAK1  NuaK1     O60285       MYPT1       4659.0     O14974
# 10977    NUAK1  NuaK1     O60285       LATS1       9113.0     O95835
# 10978     ULK2   ULK2     Q8IYT8      SEC16A       9919.0     O15027
# 10979     ULK2   ULK2     Q8IYT8      DENND3      22898.0     A2RUS2
# 10980     ULK2   ULK2     Q8IYT8      DENND3      22898.0     A2RUS2
#
#        SUB_GENE SUB_MOD_RSD  SITE_GRP_ID     SITE_+/-7_AA DOMAIN
# 0        EIF2S1         S52     447635.0  MILLsELsRRRIRsI     S1
# 1        EIF2S1         S49     450210.0  IEGMILLsELsRRRI     S1
# 2         HDAC5        S259     447995.0  FPLRkTAsEPNLKVR    NaN
# 3         PTPRA        S204     447612.0  PLLARSPsTNRKYPP    NaN
# 4        HNRNPK        S302     457408.0  GrGGrGGsrArNLPL    NaN
# ...         ...         ...          ...              ...    ...
# 10976  PPP1R12A        S910    1983104.0  sLLGRsGsysyLEER    NaN
# 10977     LATS1        S464     451855.0  NIPVRsNsFNNPLGN    NaN
# 10978    SEC16A        S846   55578720.0  LAQPINFsVSLSNSH    NaN
# 10979    DENND3        S472    7997148.0  THRRMVVsMPNLQDI    NaN
# 10980    DENND3        S490   23050193.0  ELAPRNSsLRLtDTA    NaN
#
# [10981 rows x 11 columns]

# %%
#output into a csv
kinase_substrate_df.to_csv('mohan_kinase_substrate.csv', index=False)

# %% [markdown]
# # Cleaning up the duplicates in the aliases and looking non-self-referencing aliases

# %% [markdown]
# ## Look for non-self-referencing aliases

# %% [markdown]
# It is found that some entry has duplicates within the list of aliases for each kinase gene name. The following codes is to clean up the duplicates and to make sure that the alias list for each entry has its own kinase gene name for the purpose of query after building the database

# %%
#loading the csv into dataframe
meta_names_df = pd.read_csv("meta_names.csv")
meta_names_df.head()
# Out:
#   Uniprot_number Gene_name                                Protein_name  \
# 0         P31749      AKT1   RAC-alpha serine/threonine-protein kinase
# 1         P31751      AKT2    RAC-beta serine/threonine-protein kinase
# 2         Q9Y243      AKT3   RAC-gamma serine/threonine-protein kinase
# 3         Q5VT25  CDC42BPA  Serine/threonine-protein kinase MRCK alpha
# 4         Q9Y5S2  CDC42BPB   Serine/threonine-protein kinase MRCK beta
#
#                Gene_aliases Uniprot_entry
# 0    ['AKT1', 'PKB', 'RAC']    AKT1_HUMAN
# 1                  ['AKT2']    AKT2_HUMAN
# 2          ['AKT3', 'PKBG']    AKT3_HUMAN
# 3  ['CDC42BPA', 'KIAA0451']   MRCKA_HUMAN
# 4  ['CDC42BPB', 'KIAA1124']   MRCKB_HUMAN

# %%
#to find out if there's any gene_aliases that lack of self-referencing name
#import csv 
#import json
no_self_reference = []
with open('meta_names.csv') as f: #open the file
    reader = csv.DictReader(f) #use DictReader to read into dictionary
    for row in reader:
        gene_name = row["Gene_name"] 
        gene_aliases = json.loads(row["Gene_aliases"].replace("'", '"')) #read the gene_aliases using json because DictReader returns it as a string of list of strings
        print('{}: {}'.format(gene_name, gene_aliases))
        if gene_name in gene_aliases:
            continue
        else:
            no_self_reference.append(gene_name)
print(no_self_reference)
# Out:
# AKT1: ['AKT1', 'PKB', 'RAC']
# AKT2: ['AKT2']
# AKT3: ['AKT3', 'PKBG']
# CDC42BPA: ['CDC42BPA', 'KIAA0451']
# CDC42BPB: ['CDC42BPB', 'KIAA1124']
# CDC42BPG: ['CDC42BPG', 'DMPK2']
# CIT: ['CIT', 'CRIK', 'KIAA0949', 'STK21']
# DMPK: ['DMPK', 'DM1PK', 'MDPK']
# GRK1: ['GRK1', 'RHOK']
# GRK2: ['GRK2', 'ADRBK1', 'BARK', 'BARK1']
# GRK3: ['GRK3', 'ADRBK2', 'BARK2']
# GRK4: ['GRK4', 'GPRK2L', 'GPRK4']
# GRK5: ['GRK5', 'GPRK5']
# GRK6: ['GRK6', 'GPRK6']
# GRK7: ['GRK7', 'GPRK7']
# LATS1: ['LATS1', 'WARTS']
# LATS2: ['LATS2', 'KPM']
# MAST1: ['MAST1', 'KIAA0973', 'SAST']
# MAST2: ['MAST2', 'KIAA0807', 'MAST205']
# MAST3: ['MAST3', 'KIAA0561']
# MAST4: ['MAST4', 'KIAA0303']
# MASTL: ['MASTL', 'GW', 'GWL', 'THC2']
# PDPK1: ['PDPK1', 'PDK1']
# PDPK2P: ['PDPK2P', 'PDPK2']
# PKN1: ['PKN1', 'PAK1', 'PKN', 'PRK1', 'PRKCL1']
# PKN2: ['PKN2', 'PRK2', 'PRKCL2']
# PKN3: ['PKN3', 'PKNBETA']
# PRKACA: ['PRKACA', 'PKACA']
# PRKACB: ['PRKACB']
# PRKACG: ['PRKACG']
# PRKCA: ['PRKCA', 'PKCA', 'PRKACA']
# PRKCB: ['PRKCB', 'PKCB', 'PRKCB1']
# PRKCD: ['PRKCD']
# PRKCE: ['PRKCE', 'PKCE']
# PRKCG: ['PRKCG', 'PKCG']
# PRKCH: ['PRKCH', 'PKCL', 'PRKCL']
# PRKCI: ['PRKCI', 'DXS1179E']
# PRKCQ: ['PRKCQ', 'PRKCT']
# PRKCZ: ['PRKCZ', 'PKC2']
# PRKG1: ['PRKG1', 'PRKG1B', 'PRKGR1A', 'PRKGR1B']
# PRKG2: ['PRKG2', 'PRKGR2']
# PRKX: ['PRKX', 'PKX1']
# PRKY: ['PRKY']
# ROCK1: ['ROCK1']
# ROCK2: ['ROCK2', 'KIAA0619']
# RPS6KA1: ['RPS6KA1', 'MAPKAPK1A', 'RSK1']
# RPS6KA2: ['RPS6KA2', 'MAPKAPK1C', 'RSK3']
# RPS6KA3: ['RPS6KA3', 'ISPK1', 'MAPKAPK1B', 'RSK2']
# RPS6KA4: ['RPS6KA4', 'MSK2']
# RPS6KA5: ['RPS6KA5', 'MSK1']
# RPS6KA6: ['RPS6KA6', 'RSK4']
# RPS6KB1: ['RPS6KB1', 'STK14A']
# RPS6KB2: ['RPS6KB2', 'STK14B']
# SGK1: ['SGK1', 'SGK']
# SGK2: ['SGK2']
# SGK3: ['SGK3', 'CISK', 'SGKL']
# STK38: ['STK38', 'NDR1']
# STK38L: ['STK38L', 'KIAA0965', 'NDR2']
# BRSK1: ['BRSK1', 'KIAA1811', 'SAD1', 'SADB']
# BRSK2: ['BRSK2', 'C11orf7', 'PEN11B', 'SADA', 'STK29', 'HUSSY-12']
# CAMK1: ['CAMK1']
# CAMK1D: ['CAMK1D', 'CAMKID']
# CAMK1G: ['CAMK1G', 'CLICK3', 'VWS1']
# CAMK2A: ['CAMK2A', 'CAMKA', 'KIAA0968']
# CAMK2B: ['CAMK2B', 'CAM2', 'CAMK2', 'CAMKB']
# CAMK2D: ['CAMK2D', 'CAMKD']
# CAMK2G: ['CAMK2G', 'CAMK', 'CAMK-II', 'CAMKG']
# CAMK4: ['CAMK4', 'CAMK', 'CAMK-GR', 'CAMKIV']
# CAMKV: ['CAMKV']
# CASK: ['CASK', 'LIN2']
# CHEK1: ['CHEK1', 'CHK1']
# CHEK2: ['CHEK2', 'CDS1', 'CHK2', 'RAD53']
# DAPK1: ['DAPK1', 'DAPK']
# DAPK2: ['DAPK2']
# DAPK3: ['DAPK3', 'ZIPK']
# DCLK1: ['DCLK1', 'DCAMKL1', 'DCDC3A', 'KIAA0369']
# DCLK2: ['DCLK2', 'DCAMKL2', 'DCDC3B', 'DCK2']
# DCLK3: ['DCLK3', 'DCAMKL3', 'DCDC3C', 'KIAA1765']
# HUNK: ['HUNK', 'MAKV']
# KALRN: ['KALRN', 'DUET', 'DUO', 'HAPIP', 'TRAD']
# MAPKAPK2: ['MAPKAPK2']
# MAPKAPK3: ['MAPKAPK3']
# MAPKAPK5: ['MAPKAPK5', 'PRAK']
# MARK1: ['MARK1', 'KIAA1477', 'MARK']
# MARK2: ['MARK2', 'EMK1']
# MARK3: ['MARK3', 'CTAK1', 'EMK2']
# MARK4: ['MARK4', 'KIAA1860', 'MARKL1']
# MELK: ['MELK', 'KIAA0175']
# MKNK1: ['MKNK1', 'MNK1']
# MKNK2: ['MKNK2', 'GPRK7', 'MNK2']
# MYLK: ['MYLK', 'MLCK', 'MLCK1', 'MYLK1']
# MYLK2: ['MYLK2']
# MYLK3: ['MYLK3', 'MLCK']
# MYLK4: ['MYLK4', 'SGK085']
# NIM1K: ['NIM1K', 'NIM1']
# NUAK1: ['NUAK1', 'ARK5', 'KIAA0537', 'OMPHK1']
# NUAK2: ['NUAK2', 'OMPHK2', 'SNARK']
# OBSCN: ['OBSCN', 'KIAA1556', 'KIAA1639']
# PASK: ['PASK', 'KIAA0135']
# PHKG1: ['PHKG1', 'PHKG']
# PHKG2: ['PHKG2']
# PIM1: ['PIM1']
# PIM2: ['PIM2']
# PIM3: ['PIM3']
# PNCK: ['PNCK']
# PRKAA1: ['PRKAA1', 'AMPK1']
# PRKAA2: ['PRKAA2', 'AMPK', 'AMPK2']
# PRKD1: ['PRKD1', 'PKD', 'PKD1', 'PRKCM']
# PRKD2: ['PRKD2', 'PKD2', 'HSPC187']
# PRKD3: ['PRKD3', 'EPK2', 'PRKCN']
# PSKH1: ['PSKH1']
# PSKH2: ['PSKH2']
# SIK1: ['SIK1', 'SIK', 'SNF1LK']
# SIK1B: ['SIK1B']
# SIK2: ['SIK2', 'KIAA0781', 'QIK', 'SNF1LK2']
# SIK3: ['SIK3', 'KIAA0999', 'QSK', 'L19']
# SNRK: ['SNRK', 'KIAA0096', 'SNFRK']
# SPEG: ['SPEG', 'APEG1', 'KIAA1297']
# STK11: ['STK11', 'LKB1', 'PJS']
# STK17A: ['STK17A', 'DRAK1']
# STK17B: ['STK17B', 'DRAK2']
# STK33: ['STK33']
# STK40: ['STK40', 'SGK495', 'SHIK']
# TRIB1: ['TRIB1', 'C8FW', 'GIG2', 'TRB1']
# TRIB2: ['TRIB2', 'TRB2']
# TRIB3: ['TRIB3', 'C20orf97', 'NIPK', 'SKIP3', 'TRB3']
# TRIO: ['TRIO']
# TSSK1B: ['TSSK1B', 'SPOGA1', 'SPOGA4', 'STK22A', 'STK22D', 'TSSK1', 'FKSG81']
# TSSK2: ['TSSK2', 'DGSG', 'SPOGA2', 'STK22B']
# TSSK3: ['TSSK3', 'SPOGA3', 'STK22C']
# TSSK4: ['TSSK4', 'C14orf20', 'STK22E', 'TSSK5']
# TSSK6: ['TSSK6', 'SSTK', 'FKSG82']
# TTN: ['TTN']
# CSNK1A1: ['CSNK1A1']
# CSNK1A1L: ['CSNK1A1L']
# CSNK1D: ['CSNK1D', 'HCKID']
# CSNK1E: ['CSNK1E']
# CSNK1G1: ['CSNK1G1']
# CSNK1G2: ['CSNK1G2', 'CK1G2']
# CSNK1G3: ['CSNK1G3']
# TTBK1: ['TTBK1', 'BDTK', 'KIAA1855']
# TTBK2: ['TTBK2', 'KIAA0847']
# VRK1: ['VRK1']
# VRK2: ['VRK2']
# VRK3: ['VRK3']
# CDK1: ['CDK1', 'CDC2', 'CDC28A', 'CDKN1', 'P34CDC2']
# CDK10: ['CDK10']
# CDK11A: ['CDK11A', 'CDC2L2', 'CDC2L3', 'PITSLREB']
# CDK11B: ['CDK11B', 'CDC2L1', 'CDK11', 'PITSLREA', 'PK58']
# CDK12: ['CDK12', 'CRK7', 'CRKRS', 'KIAA0904']
# CDK13: ['CDK13', 'CDC2L', 'CDC2L5', 'CHED', 'KIAA1791']
# CDK14: ['CDK14', 'KIAA0834', 'PFTK1']
# CDK15: ['CDK15', 'ALS2CR7', 'PFTK2']
# CDK16: ['CDK16', 'PCTAIRE1', 'PCTK1']
# CDK17: ['CDK17', 'PCTAIRE2', 'PCTK2']
# CDK18: ['CDK18', 'PCTAIRE3', 'PCTK3']
# CDK19: ['CDK19', 'CDC2L6', 'CDK11', 'KIAA1028']
# CDK2: ['CDK2', 'CDKN2']
# CDK20: ['CDK20', 'CCRK', 'CDCH']
# CDK3: ['CDK3', 'CDKN3']
# CDK4: ['CDK4']
# CDK5: ['CDK5', 'CDKN5']
# CDK6: ['CDK6', 'CDKN6']
# CDK7: ['CDK7', 'CAK', 'CAK1', 'CDKN7', 'MO15', 'STK1']
# CDK8: ['CDK8']
# CDK9: ['CDK9', 'CDC2L4', 'TAK']
# CDKL1: ['CDKL1']
# CDKL2: ['CDKL2']
# CDKL3: ['CDKL3', 'NKIAMRE']
# CDKL4: ['CDKL4']
# CDKL5: ['CDKL5', 'STK9']
# CLK1: ['CLK1', 'CLK']
# CLK2: ['CLK2']
# CLK3: ['CLK3']
# CLK4: ['CLK4']
# DYRK1A: ['DYRK1A', 'DYRK', 'MNB', 'MNBH']
# DYRK1B: ['DYRK1B', 'MIRK']
# DYRK2: ['DYRK2']
# DYRK3: ['DYRK3']
# DYRK4: ['DYRK4']
# GSK3A: ['GSK3A']
# GSK3B: ['GSK3B']
# HIPK1: ['HIPK1', 'KIAA0630', 'MYAK', 'NBAK2']
# HIPK2: ['HIPK2']
# HIPK3: ['HIPK3', 'DYRK6', 'FIST3', 'PKY']
# HIPK4: ['HIPK4']
# ICK: ['ICK', 'KIAA0936']
# MAK: ['MAK']
# MAPK1: ['MAPK1', 'ERK2', 'PRKM1', 'PRKM2']
# MAPK10: ['MAPK10', 'JNK3', 'JNK3A', 'PRKM10', 'SAPK1B']
# MAPK11: ['MAPK11', 'PRKM11', 'SAPK2', 'SAPK2B']
# MAPK12: ['MAPK12', 'ERK6', 'SAPK3']
# MAPK13: ['MAPK13', 'PRKM13', 'SAPK4']
# MAPK14: ['MAPK14', 'CSBP', 'CSBP1', 'CSBP2', 'CSPB1', 'MXI2', 'SAPK2A']
# MAPK15: ['MAPK15', 'ERK7', 'ERK8']
# MAPK3: ['MAPK3', 'ERK1', 'PRKM3']
# MAPK4: ['MAPK4', 'ERK4', 'PRKM4']
# MAPK6: ['MAPK6', 'ERK3', 'PRKM6']
# MAPK7: ['MAPK7', 'BMK1', 'ERK5', 'PRKM7']
# MAPK8: ['MAPK8', 'JNK1', 'PRKM8', 'SAPK1', 'SAPK1C']
# MAPK9: ['MAPK9', 'JNK2', 'PRKM9', 'SAPK1A']
# MOK: ['MOK', 'RAGE', 'RAGE1']
# NLK: ['NLK', 'LAK1']
# PRPF4B: ['PRPF4B', 'KIAA0536', 'PRP4', 'PRP4H', 'PRP4K']
# SRPK1: ['SRPK1']
# SRPK2: ['SRPK2']
# SRPK3: ['SRPK3', 'MSSK1', 'STK23']
# NEK1: ['NEK1', 'KIAA1901']
# NEK10: ['NEK10']
# NEK11: ['NEK11']
# NEK2: ['NEK2', 'NEK2A', 'NLK1']
# NEK3: ['NEK3']
# NEK4: ['NEK4', 'STK2']
# NEK5: ['NEK5']
# NEK6: ['NEK6']
# NEK7: ['NEK7']
# NEK8: ['NEK8', 'JCK', 'NEK12A']
# NEK9: ['NEK9', 'KIAA1995', 'NEK8', 'NERCC']
# GUCY2C: ['GUCY2C', 'GUC2C', 'STAR']
# GUCY2D: ['GUCY2D', 'CORD6', 'GUC1A4', 'GUC2D', 'RETGC', 'RETGC1']
# GUCY2F: ['GUCY2F', 'GUC2F', 'RETGC2']
# NPR1: ['NPR1', 'ANPRA']
# NPR2: ['NPR2', 'ANPRB']
# MAP2K1: ['MAP2K1', 'MEK1', 'PRKMK1']
# MAP2K2: ['MAP2K2', 'MEK2', 'MKK2', 'PRKMK2']
# MAP2K3: ['MAP2K3', 'MEK3', 'MKK3', 'PRKMK3', 'SKK2']
# MAP2K4: ['MAP2K4', 'JNKK1', 'MEK4', 'MKK4', 'PRKMK4', 'SEK1', 'SERK1', 'SKK1']
# MAP2K5: ['MAP2K5', 'MEK5', 'MKK5', 'PRKMK5']
# MAP2K6: ['MAP2K6', 'MEK6', 'MKK6', 'PRKMK6', 'SKK3']
# MAP2K7: ['MAP2K7', 'JNKK2', 'MEK7', 'MKK7', 'PRKMK7', 'SKK4']
# MAP3K1: ['MAP3K1', 'MAPKKK1', 'MEKK', 'MEKK1']
# MAP3K10: ['MAP3K10', 'MLK2', 'MST']
# MAP3K11: ['MAP3K11', 'MLK3', 'PTK1', 'SPRK']
# MAP3K12: ['MAP3K12', 'ZPK']
# MAP3K13: ['MAP3K13', 'LZK']
# MAP3K14: ['MAP3K14', 'NIK']
# MAP3K15: ['MAP3K15', 'ASK3']
# MAP3K19: ['MAP3K19', 'RCK', 'YSK4']
# MAP3K2: ['MAP3K2', 'MAPKKK2', 'MEKK2']
# MAP3K20: ['MAP3K20', 'MLTK', 'ZAK', 'HCCS4']
# MAP3K21: ['MAP3K21', 'KIAA1804', 'MLK4']
# MAP3K3: ['MAP3K3', 'MAPKKK3', 'MEKK3']
# MAP3K4: ['MAP3K4', 'KIAA0213', 'MAPKKK4', 'MEKK4', 'MTK1']
# MAP3K5: ['MAP3K5', 'ASK1', 'MAPKKK5', 'MEKK5']
# MAP3K6: ['MAP3K6', 'ASK2', 'MAPKKK6', 'MEKK6']
# MAP3K7: ['MAP3K7', 'TAK1']
# MAP3K8: ['MAP3K8', 'COT', 'ESTF']
# MAP3K9: ['MAP3K9', 'MLK1', 'PRKE1']
# MAP4K1: ['MAP4K1', 'HPK1']
# MAP4K2: ['MAP4K2', 'GCK', 'RAB8IP']
# MAP4K3: ['MAP4K3', 'RAB8IPL1']
# MAP4K4: ['MAP4K4', 'HGK', 'KIAA0687', 'NIK']
# MAP4K5: ['MAP4K5']
# MINK1: ['MINK1', 'B55', 'MAP4K6', 'MINK', 'YSK2', 'ZC3']
# MYO3A: ['MYO3A']
# MYO3B: ['MYO3B']
# NRK: ['NRK']
# OXSR1: ['OXSR1', 'KIAA1101', 'OSR1']
# PAK1: ['PAK1']
# PAK2: ['PAK2']
# PAK3: ['PAK3', 'OPHN3']
# PAK4: ['PAK4', 'KIAA1142']
# PAK5: ['PAK5', 'KIAA1264', 'PAK7']
# PAK6: ['PAK6', 'PAK5']
# PBK: ['PBK', 'TOPK']
# SLK: ['SLK', 'KIAA0204', 'STK2']
# STK10: ['STK10', 'LOK']
# STK24: ['STK24', 'MST3', 'STK3']
# STK25: ['STK25', 'SOK1', 'YSK1']
# STK26: ['STK26', 'MASK', 'MST4']
# STK3: ['STK3', 'KRS1', 'MST2']
# STK39: ['STK39', 'SPAK']
# STK4: ['STK4', 'KRS2', 'MST1']
# STRADA: ['STRADA', 'LYK5', 'STRAD']
# STRADB: ['STRADB', 'ALS2CR2', 'ILPIP', 'PRO1038']
# TAOK1: ['TAOK1', 'KIAA1361', 'MAP3K16', 'MARKK']
# TAOK2: ['TAOK2', 'KIAA0881', 'MAP3K17', 'PSK', 'PSK1', 'UNQ2971/PRO7431']
# TAOK3: ['TAOK3', 'DPK', 'JIK', 'KDS', 'MAP3K18']
# TNIK: ['TNIK', 'KIAA0551']
# ACVR1: ['ACVR1', 'ACVRLK2']
# ACVR1B: ['ACVR1B', 'ACVRLK4', 'ALK4']
# ACVR1C: ['ACVR1C', 'ALK7']
# ACVR2A: ['ACVR2A', 'ACVR2']
# ACVR2B: ['ACVR2B']
# ACVRL1: ['ACVRL1', 'ACVRLK1', 'ALK1']
# AMHR2: ['AMHR2', 'AMHR', 'MISR2']
# ANKK1: ['ANKK1', 'PKK2', 'SGK288']
# ARAF: ['ARAF', 'ARAF1', 'PKS', 'PKS2']
# BMPR1A: ['BMPR1A', 'ACVRLK3', 'ALK3']
# BMPR1B: ['BMPR1B']
# BMPR2: ['BMPR2', 'PPH1']
# BRAF: ['BRAF', 'BRAF1', 'RAFB1']
# ILK: ['ILK', 'ILK1', 'ILK2']
# IRAK1: ['IRAK1', 'IRAK']
# IRAK2: ['IRAK2']
# IRAK3: ['IRAK3']
# IRAK4: ['IRAK4']
# KSR1: ['KSR1', 'KSR']
# KSR2: ['KSR2']
# LIMK1: ['LIMK1', 'LIMK']
# LIMK2: ['LIMK2']
# LRRK1: ['LRRK1', 'KIAA1790']
# LRRK2: ['LRRK2', 'PARK8']
# RAF1: ['RAF1', 'RAF']
# RIPK1: ['RIPK1', 'RIP', 'RIP1']
# RIPK2: ['RIPK2', 'CARDIAK', 'RICK', 'RIP2', 'UNQ277/PRO314/PRO34092']
# RIPK3: ['RIPK3', 'RIP3']
# RIPK4: ['RIPK4', 'ANKRD3', 'DIK']
# TESK1: ['TESK1']
# TESK2: ['TESK2']
# TGFBR1: ['TGFBR1', 'ALK5', 'SKR4']
# TGFBR2: ['TGFBR2']
# TNNI3K: ['TNNI3K', 'CARK']
# AATK: ['AATK', 'AATYK', 'KIAA0641', 'LMR1', 'LMTK1']
# ABL1: ['ABL1', 'ABL', 'JTK7']
# ABL2: ['ABL2', 'ABLL', 'ARG']
# ALK: ['ALK']
# AXL: ['AXL', 'UFO']
# BLK: ['BLK']
# BMX: ['BMX']
# BTK: ['BTK', 'AGMX1', 'ATK', 'BPK']
# CSF1R: ['CSF1R', 'FMS']
# CSK: ['CSK']
# DDR1: ['DDR1', 'CAK', 'EDDR1', 'NEP', 'NTRK4', 'PTK3A', 'RTK6', 'TRKE']
# DDR2: ['DDR2', 'NTRKR3', 'TKT', 'TYRO10']
# EGFR: ['EGFR', 'ERBB', 'ERBB1', 'HER1']
# EPHA1: ['EPHA1', 'EPH', 'EPHT', 'EPHT1']
# EPHA10: ['EPHA10']
# EPHA2: ['EPHA2', 'ECK']
# EPHA3: ['EPHA3', 'ETK', 'ETK1', 'HEK', 'TYRO4']
# EPHA4: ['EPHA4', 'HEK8', 'SEK', 'TYRO1']
# EPHA5: ['EPHA5', 'BSK', 'EHK1', 'HEK7', 'TYRO4']
# EPHA6: ['EPHA6', 'EHK2', 'HEK12']
# EPHA7: ['EPHA7', 'EHK3', 'HEK11']
# EPHA8: ['EPHA8', 'EEK', 'HEK3', 'KIAA1459']
# EPHB1: ['EPHB1', 'ELK', 'EPHT2', 'HEK6', 'NET']
# EPHB2: ['EPHB2', 'DRT', 'EPHT3', 'EPTH3', 'ERK', 'HEK5', 'TYRO5']
# EPHB3: ['EPHB3', 'ETK2', 'HEK2', 'TYRO6']
# EPHB4: ['EPHB4', 'HTK', 'MYK1', 'TYRO11']
# EPHB6: ['EPHB6']
# ERBB2: ['ERBB2', 'HER2', 'MLN19', 'NEU', 'NGL']
# ERBB3: ['ERBB3', 'HER3']
# ERBB4: ['ERBB4', 'HER4']
# FER: ['FER', 'TYK3']
# FES: ['FES', 'FPS']
# FGFR1: ['FGFR1', 'BFGFR', 'CEK', 'FGFBR', 'FLG', 'FLT2', 'HBGFR']
# FGFR2: ['FGFR2', 'BEK', 'KGFR', 'KSAM']
# FGFR3: ['FGFR3', 'JTK4']
# FGFR4: ['FGFR4', 'JTK2', 'TKF']
# FGR: ['FGR', 'SRC2']
# FLT1: ['FLT1', 'FLT', 'FRT', 'VEGFR1']
# FLT3: ['FLT3', 'CD135', 'FLK2', 'STK1']
# FLT4: ['FLT4', 'VEGFR3']
# FRK: ['FRK', 'PTK5', 'RAK']
# FYN: ['FYN']
# HCK: ['HCK']
# IGF1R: ['IGF1R']
# INSR: ['INSR']
# INSRR: ['INSRR', 'IRR']
# ITK: ['ITK', 'EMT', 'LYK']
# JAK1: ['JAK1', 'JAK1A', 'JAK1B']
# JAK2: ['JAK2']
# JAK3: ['JAK3']
# KDR: ['KDR', 'FLK1', 'VEGFR2']
# KIT: ['KIT', 'SCFR']
# LCK: ['LCK']
# LMTK2: ['LMTK2', 'AATYK2', 'BREK', 'KIAA1079', 'KPI2', 'LMR2']
# LMTK3: ['LMTK3', 'KIAA1883', 'TYKLM3']
# LTK: ['LTK', 'TYK1']
# LYN: ['LYN', 'JTK8']
# MATK: ['MATK', 'CTK', 'HYL']
# MERTK: ['MERTK', 'MER']
# MET: ['MET']
# MST1R: ['MST1R', 'PTK8', 'RON']
# MUSK: ['MUSK']
# NTRK1: ['NTRK1', 'MTC', 'TRK', 'TRKA']
# NTRK2: ['NTRK2', 'TRKB']
# NTRK3: ['NTRK3', 'TRKC']
# PDGFRA: ['PDGFRA', 'PDGFR2', 'RHEPDGFRA']
# PDGFRB: ['PDGFRB', 'PDGFR', 'PDGFR1']
# PTK2: ['PTK2', 'FAK', 'FAK1']
# PTK2B: ['PTK2B', 'FAK2', 'PYK2', 'RAFTK']
# PTK6: ['PTK6', 'BRK']
# PTK7: ['PTK7', 'CCK4']
# RET: ['RET', 'CDHF12', 'CDHR16', 'PTC', 'RET51']
# ROR1: ['ROR1', 'NTRKR1']
# ROR2: ['ROR2', 'NTRKR2']
# ROS1: ['ROS1', 'MCF3', 'ROS']
# RYK: ['RYK', 'JTK5A']
# SRC: ['SRC', 'SRC1']
# SRMS: ['SRMS', 'C20orf148']
# STYK1: ['STYK1', 'NOK']
# SYK: ['SYK']
# TEC: ['TEC', 'PSCTK4']
# TEK: ['TEK', 'TIE2', 'VMCM', 'VMCM1']
# TIE1: ['TIE1', 'TIE']
# TNK1: ['TNK1']
# TNK2: ['TNK2', 'ACK1']
# TXK: ['TXK', 'PTK4', 'RLK']
# TYK2: ['TYK2']
# TYRO3: ['TYRO3', 'BYK', 'DTK', 'RSE', 'SKY', 'TIF']
# YES1: ['YES1', 'YES']
# ZAP70: ['ZAP70', 'SRK']
# AAK1: ['AAK1', 'KIAA1048']
# AURKA: ['AURKA', 'AIK', 'AIRK1', 'ARK1', 'AURA', 'AYK1', 'BTAK', 'IAK1', 'STK15', 'STK6']
# AURKB: ['AURKB', 'AIK2', 'AIM1', 'AIRK2', 'ARK2', 'STK1', 'STK12', 'STK5']
# AURKC: ['AURKC', 'AIE2', 'AIK3', 'AIRK3', 'ARK3', 'STK13']
# BMP2K: ['BMP2K', 'BIKE', 'HRIHFB2017']
# BUB1: ['BUB1', 'BUB1L']
# BUB1B: ['BUB1B', 'BUBR1', 'MAD3L', 'SSK1']
# CAMKK1: ['CAMKK1', 'CAMKKA']
# CAMKK2: ['CAMKK2', 'CAMKKB', 'KIAA0787']
# CDC7: ['CDC7', 'CDC7L1']
# CHUK: ['CHUK', 'IKKA', 'TCF16']
# CSNK2A1: ['CSNK2A1', 'CK2A1']
# CSNK2A2: ['CSNK2A2', 'CK2A2']
# CSNK2A3: ['CSNK2A3', 'CSNK2A1P']
# DSTYK: ['DSTYK', 'KIAA0472', 'RIP5', 'RIPK5', 'SGK496', 'HDCMD38P']
# EIF2AK1: ['EIF2AK1', 'HRI', 'KIAA1369', 'PRO1362']
# EIF2AK2: ['EIF2AK2', 'PKR', 'PRKR']
# EIF2AK3: ['EIF2AK3', 'PEK', 'PERK']
# EIF2AK4: ['EIF2AK4', 'GCN2', 'KIAA1338']
# ERN1: ['ERN1', 'IRE1']
# ERN2: ['ERN2', 'IRE2']
# GAK: ['GAK']
# HASPIN: ['HASPIN', 'GSG2']
# IKBKB: ['IKBKB', 'IKKB']
# IKBKE: ['IKBKE', 'IKKE', 'IKKI', 'KIAA0151']
# MLKL: ['MLKL']
# MOS: ['MOS']
# NRBP1: ['NRBP1', 'BCON3', 'NRBP']
# NRBP2: ['NRBP2', 'PP9320', 'TRG16']
# PAN3: ['PAN3']
# PDIK1L: ['PDIK1L', 'CLIK1L']
# PEAK1: ['PEAK1', 'KIAA2002']
# PIK3R4: ['PIK3R4', 'VPS15']
# PINK1: ['PINK1']
# PKDCC: ['PKDCC', 'SGK493', 'VLK']
# PKMYT1: ['PKMYT1', 'MYT1']
# PLK1: ['PLK1', 'PLK']
# PLK2: ['PLK2', 'SNK']
# PLK3: ['PLK3', 'CNK', 'FNK', 'PRK']
# PLK4: ['PLK4', 'SAK', 'STK18']
# PLK5: ['PLK5', 'PLK5P', 'FG060302']
# POMK: ['POMK', 'SGK196']
# PRAG1: ['PRAG1', 'SGK223']
# PXK: ['PXK']
# RNASEL: ['RNASEL', 'RNS4']
# RPS6KC1: ['RPS6KC1', 'RPK118']
# RPS6KL1: ['RPS6KL1']
# RSKR: ['RSKR', 'SGK494']
# SBK1: ['SBK1']
# SBK2: ['SBK2', 'SGK069']
# SBK3: ['SBK3', 'SGK110']
# SCYL1: ['SCYL1', 'CVAK90', 'GKLP', 'NTKL', 'TAPK', 'TEIF', 'TRAP', 'HT019']
# SCYL2: ['SCYL2', 'CVAK104', 'KIAA1360']
# SCYL3: ['SCYL3', 'PACE1']
# STK16: ['STK16', 'MPSK1', 'PKL12', 'TSF1']
# STK31: ['STK31', 'SGK396']
# STK32A: ['STK32A', 'YANK1']
# STK32B: ['STK32B', 'YANK2', 'UNQ3003/PRO9744']
# STK32C: ['STK32C', 'YANK3']
# STK35: ['STK35', 'CLIK1', 'PDIK1', 'STK35L1']
# STK36: ['STK36', 'KIAA1278']
# STKLD1: ['STKLD1', 'C9orf96', 'SGK071']
# TBCK: ['TBCK', 'TBCKL', 'HSPC302']
# TBK1: ['TBK1', 'NAK']
# TEX14: ['TEX14', 'SGK307']
# TLK1: ['TLK1', 'KIAA0137']
# TLK2: ['TLK2']
# TP53RK: ['TP53RK', 'C20orf64', 'PRPK']
# TTK: ['TTK', 'MPS1', 'MPS1L1']
# UHMK1: ['UHMK1', 'KIS', 'KIST']
# ULK1: ['ULK1', 'KIAA0722']
# ULK2: ['ULK2', 'KIAA0623']
# ULK3: ['ULK3']
# ULK4: ['ULK4']
# WEE1: ['WEE1']
# WEE2: ['WEE2', 'WEE1B']
# WNK1: ['WNK1', 'HSN2', 'KDP', 'KIAA0344', 'PRKWNK1']
# WNK2: ['WNK2', 'KIAA1760', 'PRKWNK2', 'SDCCAG43', 'P/OKcl.13']
# WNK3: ['WNK3', 'KIAA1566', 'PRKWNK3']
# WNK4: ['WNK4', 'PRKWNK4']
# ADCK1: ['ADCK1']
# ADCK2: ['ADCK2', 'AARF']
# ADCK5: ['ADCK5']
# COQ8A: ['COQ8A', 'ADCK3', 'CABC1', 'PP265']
# COQ8B: ['COQ8B', 'ADCK4']
# ALPK1: ['ALPK1', 'KIAA1527', 'LAK']
# ALPK2: ['ALPK2', 'HAK']
# ALPK3: ['ALPK3', 'KIAA1330', 'MAK']
# EEF2K: ['EEF2K']
# TRPM6: ['TRPM6', 'CHAK2']
# TRPM7: ['TRPM7', 'CHAK1', 'LTRPC7']
# FASTK: ['FASTK']
# BCKDK: ['BCKDK']
# PDK1: ['PDK1', 'PDHK1']
# PDK2: ['PDK2', 'PDHK2']
# PDK3: ['PDK3', 'PDHK3']
# PDK4: ['PDK4', 'PDHK4']
# ATM: ['ATM']
# ATR: ['ATR', 'FRP1']
# MTOR: ['MTOR', 'FRAP', 'FRAP1', 'FRAP2', 'RAFT1', 'RAPT1']
# PIK3CA: ['PIK3CA']
# PIK3CB: ['PIK3CB', 'PIK3C1']
# PIK3CD: ['PIK3CD']
# PIK3CG: ['PIK3CG']
# PRKDC: ['PRKDC', 'HYRC', 'HYRC1']
# SMG1: ['SMG1', 'ATX', 'KIAA0421', 'LIP']
# RIOK1: ['RIOK1', 'RIO1']
# RIOK2: ['RIOK2', 'RIO2']
# RIOK3: ['RIOK3', 'SUDD']
# []

# %% [markdown]
# The codes above showed that each gene has a self-referencing gene name in the list of aliases.

# %% [markdown]
# ## Look for duplicates

# %%
gene_alias_list = []
duplicates = []
with open('meta_names.csv') as f: #open the file
    reader = csv.DictReader(f) #use DictReader to read into dictionary
    for row in reader:
        gene_aliases = json.loads(row["Gene_aliases"].replace("'", '"'))
        for alias in gene_aliases:
            if alias in gene_alias_list:
                duplicates.append(alias)
            else:
                gene_alias_list.append(alias)
duplicates
# Out:
# ['PRKACA',
#  'CAMK',
#  'GPRK7',
#  'MLCK',
#  'CDK11',
#  'NEK8',
#  'NIK',
#  'PAK1',
#  'PAK5',
#  'STK2',
#  'STK3',
#  'CAK',
#  'TYRO4',
#  'STK1',
#  'STK1',
#  'MAK',
#  'PDK1']

# %% [markdown]
# The list above shows that there are a number of gene aliases duplicated. The duplicates will be removed from the latter entries.
