# %%
import numpy as np
import pandas as pd
import re

# %%
#opening file with inhibitor information
df = pd.read_csv('kinase_inhibitor_list.csv',index_col=0)
                 
#Assigning an index column to dataframe
df = df.set_index("Inhibitor", drop = False)

#removing data with no Action
df = df.dropna(subset=['Action'])

df.head()
# Out:
#                                          Inhibitor          Brutto        MW  \
# Inhibitor
# (5Z)-7-Oxozeaenol                (5Z)-7-Oxozeaenol        C19H22O7  362.3700
# 1 NA-PP1 (PP1 Analog)        1 NA-PP1 (PP1 Analog)        C19H19N5  317.4000
# 1 NM-PP1 (PP1 Analog II)  1 NM-PP1 (PP1 Analog II)        C20H21N5  331.4000
# 2-Aminopurine                        2-Aminopurine          C5H5N5  135.1267
# A-443654                                  A-443654  C24H23ON5x2HCl  470.3900
#
#                          Action  \
# Inhibitor
# (5Z)-7-Oxozeaenol          TAK1
# 1 NA-PP1 (PP1 Analog)       Src
# 1 NM-PP1 (PP1 Analog II)    Src
# 2-Aminopurine               PKR
# A-443654                   Akt1
#
#                                                               Reference  \
# Inhibitor
# (5Z)-7-Oxozeaenol         Ninomiya-Tsuji (2003)  J.Biol.Chem. 278 18485
# 1 NA-PP1 (PP1 Analog)                Bishop A. C. (2000) Nature 407 395
# 1 NM-PP1 (PP1 Analog II)                Ira G.  (2004) Nature 431 1011
# 2-Aminopurine                                                       NaN
# A-443654                            Shi Y. (2005) Neoplasia 7 992-1000.
#
#                                                            Reference_2  \
# Inhibitor
# (5Z)-7-Oxozeaenol             Windheim et al (2007) Biochem.J. 404 179
# 1 NA-PP1 (PP1 Analog)     Bishop A.C. (1999) J. Am. Chem. Soc. 121 627
# 1 NM-PP1 (PP1 Analog II)             Papa F.R. (2003) Science 302 1533
# 2-Aminopurine                                                      NaN
# A-443654                                                           NaN
#
#                                PMID2        Patent   Commercial Vendor  \
# Inhibitor
# (5Z)-7-Oxozeaenol         17348859.0           NaN              Tocris
# 1 NA-PP1 (PP1 Analog)            NaN  WO2003082341  Merck (Calbiochem)
# 1 NM-PP1 (PP1 Analog II)  14564015.0  WO2000042042  Merck (Calbiochem)
# 2-Aminopurine                    NaN           NaN               Sigma
# A-443654                         NaN  WO2007106884    AdooQ Bioscience
#
#                                   CAS  \
# Inhibitor
# (5Z)-7-Oxozeaenol          66018-38-0
# 1 NA-PP1 (PP1 Analog)     221243-82-9
# 1 NM-PP1 (PP1 Analog II)  221244-14-0
# 2-Aminopurine                452-06-2
# A-443654                  552325-16-3
#
#                                                                       InChI  \
# Inhibitor
# (5Z)-7-Oxozeaenol         InChI=1S/C19H22O7/c1-11-5-3-7-14(20)18(23)15(2...
# 1 NA-PP1 (PP1 Analog)     InChI=1S/C19H19N5/c1-19(2,3)24-18-15(17(20)21-...
# 1 NM-PP1 (PP1 Analog II)  InChI=1S/C20H21N5/c1-20(2,3)25-19-17(18(21)22-...
# 2-Aminopurine             InChI=1S/C5H5N5/c6-5-7-1-3-4(10-5)9-2-8-3/h1-2...
# A-443654                  InChI=1S/C24H23N5O/c1-15-22-10-16(6-7-24(22)29...
#
#                                             InChI Key  PubChem CID  \
# Inhibitor
# (5Z)-7-Oxozeaenol         NEQZWEXWOFPKOT-UHFFFAOYSA-N   53442201.0
# 1 NA-PP1 (PP1 Analog)     XSHQBIXMLULFEV-UHFFFAOYSA-N       4877.0
# 1 NM-PP1 (PP1 Analog II)  GDQXJQSQYMMKRA-UHFFFAOYSA-N    5154691.0
# 2-Aminopurine             MWBWWFOAEOYUST-UHFFFAOYSA-N       9955.0
# A-443654                  YWTBGJGMTBHQTM-IBGZPJMESA-N   10172943.0
#
#                                                                      SMILES  \
# Inhibitor
# (5Z)-7-Oxozeaenol         CC1CC=CC(=O)C(C(CC=CC2=CC(=CC(=C2C(=O)O1)O)OC)O)O
# 1 NA-PP1 (PP1 Analog)     CC(C)(C)N1C2=C(C(=N1)C3=CC=CC4=CC=CC=C43)C(=NC...
# 1 NM-PP1 (PP1 Analog II)  CC(C)(C)N1C2=C(C(=N1)CC3=CC=CC4=CC=CC=C43)C(=N...
# 2-Aminopurine                                        C1=C2C(=NC(=N1)N)N=CN2
# A-443654                  CC1=C2C=C(C=CC2=NN1)C3=CC(=CN=C3)OCC(CC4=CNC5=...
#
#                                                                    Alt Name
# Inhibitor
# (5Z)-7-Oxozeaenol                                               LL-Z-1640-2
# 1 NA-PP1 (PP1 Analog)                       1-NA-PP1, CHEBI:52310, 1-Na PP1
# 1 NM-PP1 (PP1 Analog II)  PP1 Analog II, 1NM-PP1, Mutant Kinases Inhibit...
# 2-Aminopurine                                                          2-AP
# A-443654                  SHN-414, A443654, DNC006711, CHEMBL379300, MLS...

# %%
df[df.columns[14]] = df[df.columns[14]].str.replace(",", "|")
df.head()
# Out:
#                                          Inhibitor          Brutto        MW  \
# Inhibitor
# (5Z)-7-Oxozeaenol                (5Z)-7-Oxozeaenol        C19H22O7  362.3700
# 1 NA-PP1 (PP1 Analog)        1 NA-PP1 (PP1 Analog)        C19H19N5  317.4000
# 1 NM-PP1 (PP1 Analog II)  1 NM-PP1 (PP1 Analog II)        C20H21N5  331.4000
# 2-Aminopurine                        2-Aminopurine          C5H5N5  135.1267
# A-443654                                  A-443654  C24H23ON5x2HCl  470.3900
#
#                          Action  \
# Inhibitor
# (5Z)-7-Oxozeaenol          TAK1
# 1 NA-PP1 (PP1 Analog)       Src
# 1 NM-PP1 (PP1 Analog II)    Src
# 2-Aminopurine               PKR
# A-443654                   Akt1
#
#                                                               Reference  \
# Inhibitor
# (5Z)-7-Oxozeaenol         Ninomiya-Tsuji (2003)  J.Biol.Chem. 278 18485
# 1 NA-PP1 (PP1 Analog)                Bishop A. C. (2000) Nature 407 395
# 1 NM-PP1 (PP1 Analog II)                Ira G.  (2004) Nature 431 1011
# 2-Aminopurine                                                       NaN
# A-443654                            Shi Y. (2005) Neoplasia 7 992-1000.
#
#                                                            Reference_2  \
# Inhibitor
# (5Z)-7-Oxozeaenol             Windheim et al (2007) Biochem.J. 404 179
# 1 NA-PP1 (PP1 Analog)     Bishop A.C. (1999) J. Am. Chem. Soc. 121 627
# 1 NM-PP1 (PP1 Analog II)             Papa F.R. (2003) Science 302 1533
# 2-Aminopurine                                                      NaN
# A-443654                                                           NaN
#
#                                PMID2        Patent   Commercial Vendor  \
# Inhibitor
# (5Z)-7-Oxozeaenol         17348859.0           NaN              Tocris
# 1 NA-PP1 (PP1 Analog)            NaN  WO2003082341  Merck (Calbiochem)
# 1 NM-PP1 (PP1 Analog II)  14564015.0  WO2000042042  Merck (Calbiochem)
# 2-Aminopurine                    NaN           NaN               Sigma
# A-443654                         NaN  WO2007106884    AdooQ Bioscience
#
#                                   CAS  \
# Inhibitor
# (5Z)-7-Oxozeaenol          66018-38-0
# 1 NA-PP1 (PP1 Analog)     221243-82-9
# 1 NM-PP1 (PP1 Analog II)  221244-14-0
# 2-Aminopurine                452-06-2
# A-443654                  552325-16-3
#
#                                                                       InChI  \
# Inhibitor
# (5Z)-7-Oxozeaenol         InChI=1S/C19H22O7/c1-11-5-3-7-14(20)18(23)15(2...
# 1 NA-PP1 (PP1 Analog)     InChI=1S/C19H19N5/c1-19(2,3)24-18-15(17(20)21-...
# 1 NM-PP1 (PP1 Analog II)  InChI=1S/C20H21N5/c1-20(2,3)25-19-17(18(21)22-...
# 2-Aminopurine             InChI=1S/C5H5N5/c6-5-7-1-3-4(10-5)9-2-8-3/h1-2...
# A-443654                  InChI=1S/C24H23N5O/c1-15-22-10-16(6-7-24(22)29...
#
#                                             InChI Key  PubChem CID  \
# Inhibitor
# (5Z)-7-Oxozeaenol         NEQZWEXWOFPKOT-UHFFFAOYSA-N   53442201.0
# 1 NA-PP1 (PP1 Analog)     XSHQBIXMLULFEV-UHFFFAOYSA-N       4877.0
# 1 NM-PP1 (PP1 Analog II)  GDQXJQSQYMMKRA-UHFFFAOYSA-N    5154691.0
# 2-Aminopurine             MWBWWFOAEOYUST-UHFFFAOYSA-N       9955.0
# A-443654                  YWTBGJGMTBHQTM-IBGZPJMESA-N   10172943.0
#
#                                                                      SMILES  \
# Inhibitor
# (5Z)-7-Oxozeaenol         CC1CC=CC(=O)C(C(CC=CC2=CC(=CC(=C2C(=O)O1)O)OC)O)O
# 1 NA-PP1 (PP1 Analog)     CC(C)(C)N1C2=C(C(=N1)C3=CC=CC4=CC=CC=C43)C(=NC...
# 1 NM-PP1 (PP1 Analog II)  CC(C)(C)N1C2=C(C(=N1)CC3=CC=CC4=CC=CC=C43)C(=N...
# 2-Aminopurine                                        C1=C2C(=NC(=N1)N)N=CN2
# A-443654                  CC1=C2C=C(C=CC2=NN1)C3=CC(=CN=C3)OCC(CC4=CNC5=...
#
#                                                                    Alt Name
# Inhibitor
# (5Z)-7-Oxozeaenol                                               LL-Z-1640-2
# 1 NA-PP1 (PP1 Analog)                       1-NA-PP1| CHEBI:52310| 1-Na PP1
# 1 NM-PP1 (PP1 Analog II)  PP1 Analog II| 1NM-PP1| Mutant Kinases Inhibit...
# 2-Aminopurine                                                          2-AP
# A-443654                  SHN-414| A443654| DNC006711| CHEMBL379300| MLS...

# %%
#extracting just the pubchem CID to upload into pubchem to get information
pubchem = pd.DataFrame(data={'PubChem CID':list(df[df.columns[12]])})
pubchem.head()
# Out:
#    PubChem CID
# 0   53442201.0
# 1       4877.0
# 2    5154691.0
# 3       9955.0
# 4   10172943.0

# %%
#df into a csv file to be used in pubchem
#pubchem.to_csv('Pubchem.csv', header=None, index=False)

# %%
#opening PubChem file with information from the CID above
pubchem_CID = pd.read_csv('PubChem_ncbi.csv')
pubchem_CID.head()
# Out:
#     cid                                           cmpdname  \
# 0  1400  1-(Tert-Butyl)-3-(p-tolyl)-1H-pyrazolo[3,4-d]p...
# 1  2049                  6,7-Dimethoxy-2-phenylquinoxaline
# 2  2051  N-(3-Chlorophenyl)-6,7-dimethoxyquinazolin-4-a...
# 3  2161                                          Amlexanox
# 4  2396                              Bisindolylmaleimide i
#
#                                          cmpdsynonym      mw            mf  \
# 0  172889-26-8|PP1|PP 1|1-(tert-Butyl)-3-(p-tolyl...  281.36      C16H19N5
# 1  146535-11-7|Tyrphostin AG 1296|6,7-dimethoxy-2...  266.29    C16H14N2O2
# 2  AG-1478|153436-53-4|Tyrphostin AG 1478|N-(3-ch...  315.75  C16H14ClN3O2
# 3  amlexanox|68302-57-8|Amoxanox|Aphthasol|2-Amin...  298.29    C16H14N2O4
# 4  bisindolylmaleimide i|133052-90-1|GF 109203X|G...  412.50    C25H24N4O2
#
#    polararea  complexity  xlogp  heavycnt  hbonddonor  hbondacc  rotbonds  \
# 0       69.6       358.0    NaN        21           1         4         2
# 1       44.2       307.0    NaN        20           0         4         3
# 2       56.3       360.0    NaN        22           1         5         4
# 3      103.0       467.0    NaN        22           2         6         2
# 4       70.1       748.0    NaN        31           2         3         6
#
#                       inchikey  \
# 0  ZVPDNRVYHLRXLX-UHFFFAOYSA-N
# 1  QNOXYUNHIGOWNY-UHFFFAOYSA-N
# 2  GFNNBHLJANVSQV-UHFFFAOYSA-N
# 3  SGRYPYWGNKJSDL-UHFFFAOYSA-N
# 4  QMGUOJYZJKLOLH-UHFFFAOYSA-N
#
#                                            iupacname meshheadings  annothits  \
# 0  1-tert-butyl-3-(4-methylphenyl)pyrazolo[3,4-d]...          NaN   104214.0
# 1                  6,7-dimethoxy-2-phenylquinoxaline          NaN   100118.0
# 2  N-(3-chlorophenyl)-6,7-dimethoxyquinazolin-4-a...          NaN   237342.0
# 3  2-amino-5-oxo-7-propan-2-ylchromeno[2,3-b]pyri...          NaN   261950.0
# 4  3-[1-[3-(dimethylamino)propyl]indol-3-yl]-4-(1...          NaN   106262.0
#
#    annothitcnt                                               aids  cidcdate  \
# 0          9.0  619,631,640,689,690,693,696,697,704,707,710,71...  20050325
# 1          8.0  880,1030,1457,1458,1460,1463,1468,1469,1471,14...  20050325
# 2         12.0  1,3,5,7,9,13,15,19,21,23,25,29,31,33,35,37,39,...  20050325
# 3         15.0  485,631,731,781,782,880,950,951,952,1001,1006,...  20050325
# 4         10.0  410,411,445,447,448,450,451,526,530,584,585,59...  20050325
#
#                                                 dois
# 0  10.1002/0471142956.cy1312s54|10.1002/cyto.a.20...
# 1  10.1002/hep.21606|10.1002/jcp.21600|10.1002/mr...
# 2  10.1002/(sici)1097-0215(19971210)73:6&lt;917::...
# 3  10.1002/bio.2828|10.1006/bbrc.1997.7476|10.100...
# 4  10.1002/(sici)1097-4547(19971201)50:5&lt;743::...

# %%
#replacing the synonyms column with synonyms column from pubchem

for x in df[df.columns[12]]:  #for pubchem CID in original df 
    for y in pubchem_CID.cid : #for pubchem CID in the file with CID and its other information from pubchem
        
    #if the value of both the CIDs are the same
        if x == y:
            
            #find the correct synonym associated with that CID from the pubchem df
            synonym = df.loc[df[df.columns[12]] == x, "Alt Name"].iloc[0]
                             
            synonym2 = pubchem_CID.loc[pubchem_CID.cid == x, "cmpdsynonym"].iloc[0]
            
            
            #replace the synonym column with the correct and updated synonym
            df[df.columns[14]] = df[df.columns[14]].replace(synonym, synonym2)     
        else:
            pass
df.head()
# Out:
#                                          Inhibitor          Brutto        MW  \
# Inhibitor
# (5Z)-7-Oxozeaenol                (5Z)-7-Oxozeaenol        C19H22O7  362.3700
# 1 NA-PP1 (PP1 Analog)        1 NA-PP1 (PP1 Analog)        C19H19N5  317.4000
# 1 NM-PP1 (PP1 Analog II)  1 NM-PP1 (PP1 Analog II)        C20H21N5  331.4000
# 2-Aminopurine                        2-Aminopurine          C5H5N5  135.1267
# A-443654                                  A-443654  C24H23ON5x2HCl  470.3900
#
#                          Action  \
# Inhibitor
# (5Z)-7-Oxozeaenol          TAK1
# 1 NA-PP1 (PP1 Analog)       Src
# 1 NM-PP1 (PP1 Analog II)    Src
# 2-Aminopurine               PKR
# A-443654                   Akt1
#
#                                                               Reference  \
# Inhibitor
# (5Z)-7-Oxozeaenol         Ninomiya-Tsuji (2003)  J.Biol.Chem. 278 18485
# 1 NA-PP1 (PP1 Analog)                Bishop A. C. (2000) Nature 407 395
# 1 NM-PP1 (PP1 Analog II)                Ira G.  (2004) Nature 431 1011
# 2-Aminopurine                                                       NaN
# A-443654                            Shi Y. (2005) Neoplasia 7 992-1000.
#
#                                                            Reference_2  \
# Inhibitor
# (5Z)-7-Oxozeaenol             Windheim et al (2007) Biochem.J. 404 179
# 1 NA-PP1 (PP1 Analog)     Bishop A.C. (1999) J. Am. Chem. Soc. 121 627
# 1 NM-PP1 (PP1 Analog II)             Papa F.R. (2003) Science 302 1533
# 2-Aminopurine                                                      NaN
# A-443654                                                           NaN
#
#                                PMID2        Patent   Commercial Vendor  \
# Inhibitor
# (5Z)-7-Oxozeaenol         17348859.0           NaN              Tocris
# 1 NA-PP1 (PP1 Analog)            NaN  WO2003082341  Merck (Calbiochem)
# 1 NM-PP1 (PP1 Analog II)  14564015.0  WO2000042042  Merck (Calbiochem)
# 2-Aminopurine                    NaN           NaN               Sigma
# A-443654                         NaN  WO2007106884    AdooQ Bioscience
#
#                                   CAS  \
# Inhibitor
# (5Z)-7-Oxozeaenol          66018-38-0
# 1 NA-PP1 (PP1 Analog)     221243-82-9
# 1 NM-PP1 (PP1 Analog II)  221244-14-0
# 2-Aminopurine                452-06-2
# A-443654                  552325-16-3
#
#                                                                       InChI  \
# Inhibitor
# (5Z)-7-Oxozeaenol         InChI=1S/C19H22O7/c1-11-5-3-7-14(20)18(23)15(2...
# 1 NA-PP1 (PP1 Analog)     InChI=1S/C19H19N5/c1-19(2,3)24-18-15(17(20)21-...
# 1 NM-PP1 (PP1 Analog II)  InChI=1S/C20H21N5/c1-20(2,3)25-19-17(18(21)22-...
# 2-Aminopurine             InChI=1S/C5H5N5/c6-5-7-1-3-4(10-5)9-2-8-3/h1-2...
# A-443654                  InChI=1S/C24H23N5O/c1-15-22-10-16(6-7-24(22)29...
#
#                                             InChI Key  PubChem CID  \
# Inhibitor
# (5Z)-7-Oxozeaenol         NEQZWEXWOFPKOT-UHFFFAOYSA-N   53442201.0
# 1 NA-PP1 (PP1 Analog)     XSHQBIXMLULFEV-UHFFFAOYSA-N       4877.0
# 1 NM-PP1 (PP1 Analog II)  GDQXJQSQYMMKRA-UHFFFAOYSA-N    5154691.0
# 2-Aminopurine             MWBWWFOAEOYUST-UHFFFAOYSA-N       9955.0
# A-443654                  YWTBGJGMTBHQTM-IBGZPJMESA-N   10172943.0
#
#                                                                      SMILES  \
# Inhibitor
# (5Z)-7-Oxozeaenol         CC1CC=CC(=O)C(C(CC=CC2=CC(=CC(=C2C(=O)O1)O)OC)O)O
# 1 NA-PP1 (PP1 Analog)     CC(C)(C)N1C2=C(C(=N1)C3=CC=CC4=CC=CC=C43)C(=NC...
# 1 NM-PP1 (PP1 Analog II)  CC(C)(C)N1C2=C(C(=N1)CC3=CC=CC4=CC=CC=C43)C(=N...
# 2-Aminopurine                                        C1=C2C(=NC(=N1)N)N=CN2
# A-443654                  CC1=C2C=C(C=CC2=NN1)C3=CC(=CN=C3)OCC(CC4=CNC5=...
#
#                                                                    Alt Name
# Inhibitor
# (5Z)-7-Oxozeaenol                                    253863-19-3|66018-38-0
# 1 NA-PP1 (PP1 Analog)     1-NAPHTHYL PP1|221243-82-9|1-NA-PP1|pp1 analog...
# 1 NM-PP1 (PP1 Analog II)  1-NM-PP1|221244-14-0|PP1 Analog II, 1NM-PP1|1-...
# 2-Aminopurine             2-aminopurine|7H-purin-2-amine|452-06-2|1H-PUR...
# A-443654                  A-443654|552325-16-3|A 443654|(2s)-1-(1h-Indol...

# %%
#replacing the Molecular weight and molecular formula comlumn with ones from pubchem

for x in df[df.columns[12]]:  #for pubchem CID in original df 
    for y in pubchem_CID.cid : #for pubchem CID in the file with CID and its other information from pubchem
        
    #if the value of both the CIDs are the same
        if x == y:
            
            Old_MW = df.loc[df[df.columns[12]] == x, "MW"].iloc[0]                
            New_MW = pubchem_CID.loc[pubchem_CID.cid == x, "mw"].iloc[0]
            
            Old_MF = df.loc[df[df.columns[12]] == x, "Brutto"].iloc[0]                
            New_MF = pubchem_CID.loc[pubchem_CID.cid == x, "mf"].iloc[0]
            
            
            df[df.columns[2]] = df[df.columns[2]].replace(Old_MW, New_MW)
            df[df.columns[1]] = df[df.columns[1]].replace(Old_MF, New_MF)  
        else:
            pass
df.head()
# Out:
#                                          Inhibitor     Brutto      MW Action  \
# Inhibitor
# (5Z)-7-Oxozeaenol                (5Z)-7-Oxozeaenol   C19H22O7  362.40   TAK1
# 1 NA-PP1 (PP1 Analog)        1 NA-PP1 (PP1 Analog)   C19H19N5  317.40    Src
# 1 NM-PP1 (PP1 Analog II)  1 NM-PP1 (PP1 Analog II)   C20H21N5  331.40    Src
# 2-Aminopurine                        2-Aminopurine     C5H5N5  135.13    PKR
# A-443654                                  A-443654  C24H23N5O  397.50   Akt1
#
#                                                               Reference  \
# Inhibitor
# (5Z)-7-Oxozeaenol         Ninomiya-Tsuji (2003)  J.Biol.Chem. 278 18485
# 1 NA-PP1 (PP1 Analog)                Bishop A. C. (2000) Nature 407 395
# 1 NM-PP1 (PP1 Analog II)                Ira G.  (2004) Nature 431 1011
# 2-Aminopurine                                                       NaN
# A-443654                            Shi Y. (2005) Neoplasia 7 992-1000.
#
#                                                            Reference_2  \
# Inhibitor
# (5Z)-7-Oxozeaenol             Windheim et al (2007) Biochem.J. 404 179
# 1 NA-PP1 (PP1 Analog)     Bishop A.C. (1999) J. Am. Chem. Soc. 121 627
# 1 NM-PP1 (PP1 Analog II)             Papa F.R. (2003) Science 302 1533
# 2-Aminopurine                                                      NaN
# A-443654                                                           NaN
#
#                                PMID2        Patent   Commercial Vendor  \
# Inhibitor
# (5Z)-7-Oxozeaenol         17348859.0           NaN              Tocris
# 1 NA-PP1 (PP1 Analog)            NaN  WO2003082341  Merck (Calbiochem)
# 1 NM-PP1 (PP1 Analog II)  14564015.0  WO2000042042  Merck (Calbiochem)
# 2-Aminopurine                    NaN           NaN               Sigma
# A-443654                         NaN  WO2007106884    AdooQ Bioscience
#
#                                   CAS  \
# Inhibitor
# (5Z)-7-Oxozeaenol          66018-38-0
# 1 NA-PP1 (PP1 Analog)     221243-82-9
# 1 NM-PP1 (PP1 Analog II)  221244-14-0
# 2-Aminopurine                452-06-2
# A-443654                  552325-16-3
#
#                                                                       InChI  \
# Inhibitor
# (5Z)-7-Oxozeaenol         InChI=1S/C19H22O7/c1-11-5-3-7-14(20)18(23)15(2...
# 1 NA-PP1 (PP1 Analog)     InChI=1S/C19H19N5/c1-19(2,3)24-18-15(17(20)21-...
# 1 NM-PP1 (PP1 Analog II)  InChI=1S/C20H21N5/c1-20(2,3)25-19-17(18(21)22-...
# 2-Aminopurine             InChI=1S/C5H5N5/c6-5-7-1-3-4(10-5)9-2-8-3/h1-2...
# A-443654                  InChI=1S/C24H23N5O/c1-15-22-10-16(6-7-24(22)29...
#
#                                             InChI Key  PubChem CID  \
# Inhibitor
# (5Z)-7-Oxozeaenol         NEQZWEXWOFPKOT-UHFFFAOYSA-N   53442201.0
# 1 NA-PP1 (PP1 Analog)     XSHQBIXMLULFEV-UHFFFAOYSA-N       4877.0
# 1 NM-PP1 (PP1 Analog II)  GDQXJQSQYMMKRA-UHFFFAOYSA-N    5154691.0
# 2-Aminopurine             MWBWWFOAEOYUST-UHFFFAOYSA-N       9955.0
# A-443654                  YWTBGJGMTBHQTM-IBGZPJMESA-N   10172943.0
#
#                                                                      SMILES  \
# Inhibitor
# (5Z)-7-Oxozeaenol         CC1CC=CC(=O)C(C(CC=CC2=CC(=CC(=C2C(=O)O1)O)OC)O)O
# 1 NA-PP1 (PP1 Analog)     CC(C)(C)N1C2=C(C(=N1)C3=CC=CC4=CC=CC=C43)C(=NC...
# 1 NM-PP1 (PP1 Analog II)  CC(C)(C)N1C2=C(C(=N1)CC3=CC=CC4=CC=CC=C43)C(=N...
# 2-Aminopurine                                        C1=C2C(=NC(=N1)N)N=CN2
# A-443654                  CC1=C2C=C(C=CC2=NN1)C3=CC(=CN=C3)OCC(CC4=CNC5=...
#
#                                                                    Alt Name
# Inhibitor
# (5Z)-7-Oxozeaenol                                    253863-19-3|66018-38-0
# 1 NA-PP1 (PP1 Analog)     1-NAPHTHYL PP1|221243-82-9|1-NA-PP1|pp1 analog...
# 1 NM-PP1 (PP1 Analog II)  1-NM-PP1|221244-14-0|PP1 Analog II, 1NM-PP1|1-...
# 2-Aminopurine             2-aminopurine|7H-purin-2-amine|452-06-2|1H-PUR...
# A-443654                  A-443654|552325-16-3|A 443654|(2s)-1-(1h-Indol...

# %%
#dataframe of only inhibitor and action
My_df = pd.DataFrame(data={
  'Inhibitor':list(df.Inhibitor),
  'Action': list(df.Action)})

#one inhibitor can have many actions
#making repeats
#allocating each action to its inhibitor
 

Action_Inhibitor= (My_df.set_index(['Inhibitor'])
   .stack()
   .str.split(',', expand=True)
   .stack()
   .unstack(-2)
   .reset_index(-1, drop=True)
   .reset_index())

#274 rows
Action_Inhibitor.head()
# Out:
#                   Inhibitor Action
# 0         (5Z)-7-Oxozeaenol   TAK1
# 1     1 NA-PP1 (PP1 Analog)    Src
# 2  1 NM-PP1 (PP1 Analog II)    Src
# 3             2-Aminopurine    PKR
# 4                  A-443654   Akt1

# %%
#upper case the action column 

def mod_upper(q):
    if isinstance(q,str):
        return q.upper()
    else:
        return q
    
upper_Action = [mod_upper(f) for f in Action_Inhibitor.Action]
upper_Action[:5]
# Out:
# ['TAK1', 'SRC', 'SRC', 'PKR', 'AKT1']

# %%
#some Action contains spaces before the word
#need to remove this
new_Action= []

for i in upper_Action:
    j = i.replace(' ','')
    new_Action.append(j)
    
new_Action[:10]
# Out:
# ['TAK1',
#  'SRC',
#  'SRC',
#  'PKR',
#  'AKT1',
#  'AMPKACTIVATOR',
#  'ALK5',
#  'ACTIVATORALPK1',
#  'ACTIVATORALPK1',
#  'PDGF']

# %%
Action_Inhibitor.head()
# Out:
#                   Inhibitor Action
# 0         (5Z)-7-Oxozeaenol   TAK1
# 1     1 NA-PP1 (PP1 Analog)    Src
# 2  1 NM-PP1 (PP1 Analog II)    Src
# 3             2-Aminopurine    PKR
# 4                  A-443654   Akt1

# %%
#replace old action column with modidied action column 

#name of the column by index
n = Action_Inhibitor.columns[1]

# Drop old action column
Action_Inhibitor.drop(n, axis = 1, inplace = True)

# Put new column
Action_Inhibitor[n] = new_Action

Action_Inhibitor.head()
# Out:
#                   Inhibitor Action
# 0         (5Z)-7-Oxozeaenol   TAK1
# 1     1 NA-PP1 (PP1 Analog)    SRC
# 2  1 NM-PP1 (PP1 Analog II)    SRC
# 3             2-Aminopurine    PKR
# 4                  A-443654   AKT1

# %%
#opening human kinase file 
human_kinase_db = pd.read_csv("gene_names.csv", index_col = 0)

#dropping Protein_name column
human_kinase_db.drop(human_kinase_db.columns[1], axis = 1, inplace = True)
human_kinase_db.head()
# Out:
#                Gene_name              Gene_aliases
# Uniprot_number
# P31749              AKT1    ['AKT1', 'PKB', 'RAC']
# P31751              AKT2                  ['AKT2']
# Q9Y243              AKT3          ['AKT3', 'PKBG']
# Q5VT25          CDC42BPA  ['CDC42BPA', 'KIAA0451']
# Q9Y5S2          CDC42BPB  ['CDC42BPB', 'KIAA1124']

# %%
#removing the [] from gene-aliases column
g = [i.replace('[', '') for i in human_kinase_db.Gene_aliases]
y = [i.replace(']', '') for i in g]

#removing '' quotation marks from each gene
import ast
q = str(y).replace("'", "")
q = ast.literal_eval(q)


#replacing the gene-aliales column with new column without []
#name of the column by index
n = human_kinase_db.columns[1]

# Drop that column
human_kinase_db.drop(n, axis = 1, inplace = True)

# Put new column
human_kinase_db[n] = q


#separating each gene_aliases into its respective gene_name
wanted_kinase = human_kinase_db.apply(lambda x :x.str.split(',',expand=True).stack()).reset_index(level=1,drop=True).ffill()

#1326 rows
wanted_kinase.head()
# Out:
#                Gene_name Gene_aliases
# Uniprot_number
# A0A0B4J2F2         SIK1B        SIK1B
# O00141              SGK1         SGK1
# O00141              SGK1          SGK
# O00238            BMPR1B       BMPR1B
# O00311              CDC7         CDC7

# %%
#some gene aliases contain space before the word
#need to remove the spaces first
new_gene_aliases = []

for i in wanted_kinase.Gene_aliases:
    j = i.replace(' ','')
    new_gene_aliases.append(j)

    
##replacing gene aliases column

#name of the column by index
n = wanted_kinase.columns[1]

# Drop that column
wanted_kinase.drop(n, axis = 1, inplace = True)

# Put new column
wanted_kinase[n] = new_gene_aliases

#the new column
wanted_kinase.Gene_aliases[:10]
# Out:
# Uniprot_number
# A0A0B4J2F2     SIK1B
# O00141          SGK1
# O00141           SGK
# O00238        BMPR1B
# O00311          CDC7
# O00311        CDC7L1
# O00329        PIK3CD
# O00418         EEF2K
# O00444          PLK4
# O00444           SAK
# Name: Gene_aliases, dtype: object

# %%
for x in wanted_kinase.Gene_aliases:  #gene aliases
    for y in Action_Inhibitor.Action: #action
        
    #if the value of gene aliase and action are the same:
        if x == y:
            
            #find the correct gene name associated with that gene aliase
            gene = wanted_kinase.loc[wanted_kinase.Gene_aliases == x, "Gene_name"].iloc[0]
            
            #replace the action column with the correct name
            Action_Inhibitor['Action'] = Action_Inhibitor['Action'].str.replace(y, gene)     
        else:
            pass


#274 rows
Action_Inhibitor.head()
# Out:
#                   Inhibitor   Action
# 0         (5Z)-7-Oxozeaenol   MAP3K7
# 1     1 NA-PP1 (PP1 Analog)      SRC
# 2  1 NM-PP1 (PP1 Analog II)      SRC
# 3             2-Aminopurine  EIF2AK2
# 4                  A-443654     AKT1

# %%
#comparing Action column with gene_name column and finding its inhibitor
#if gene_name and gene_aliases match, extract its inhibitor

test=wanted_kinase.join(Action_Inhibitor.set_index('Action'), on='Gene_name')
new_db = test[test['Inhibitor'].notnull()]                    

new_db.head()
# Out:
#                Gene_name Gene_aliases        Inhibitor
# Uniprot_number
# O00141              SGK1         SGK1       GSK650394A
# O00141              SGK1         SGK1   SGK-Sanofi-14i
# O00141              SGK1         SGK1  SGK1-Sanofi-14g
# O00141              SGK1         SGK1  SGK1-Sanofi-14h
# O00141              SGK1         SGK1  SGK1-Sanofi-14n

# %%
#removing Gene_aliases column for next step
new_db.drop(new_db.columns[1], axis = 1, inplace = True)

new_db.head() ##280 rows
# Out:
#                Gene_name        Inhibitor
# Uniprot_number
# O00141              SGK1       GSK650394A
# O00141              SGK1   SGK-Sanofi-14i
# O00141              SGK1  SGK1-Sanofi-14g
# O00141              SGK1  SGK1-Sanofi-14h
# O00141              SGK1  SGK1-Sanofi-14n

# %%
#remove duplicate rows
new_db = new_db.drop_duplicates()  

#115 rows
new_db.head()
# Out:
#                Gene_name        Inhibitor
# Uniprot_number
# O00141              SGK1       GSK650394A
# O00141              SGK1   SGK-Sanofi-14i
# O00141              SGK1  SGK1-Sanofi-14g
# O00141              SGK1  SGK1-Sanofi-14h
# O00141              SGK1  SGK1-Sanofi-14n

# %%
#incase of duplicates in inhibitor: group by Inhibitors
new_db.groupby('Inhibitor')['Gene_name'].apply(lambda x: x.unique()).reset_index()

#115 rows
new_db.head()
# Out:
#                Gene_name        Inhibitor
# Uniprot_number
# O00141              SGK1       GSK650394A
# O00141              SGK1   SGK-Sanofi-14i
# O00141              SGK1  SGK1-Sanofi-14g
# O00141              SGK1  SGK1-Sanofi-14h
# O00141              SGK1  SGK1-Sanofi-14n

# %%
#join two files together.
#match inhibitors from new_db and original df to extract other information

test=new_db.join(df.set_index('Inhibitor'), on='Inhibitor')
match_info = test[test['Action'].notnull()]   #testing on Action since it is guranteed to be there for every inhibitor in this df. 

#115 rows
match_info.head()
# Out:
#                Gene_name        Inhibitor          Brutto      MW Action  \
# Uniprot_number
# O00141              SGK1       GSK650394A      C25H22N2O2  382.50    SGK
# O00141              SGK1   SGK-Sanofi-14i   C18H15ClN6O3S  430.87    SGK
# O00141              SGK1  SGK1-Sanofi-14g  C17H12Cl2N6O2S  435.29    SGK
# O00141              SGK1  SGK1-Sanofi-14h  C17H12Cl2N6O2S  435.29    SGK
# O00141              SGK1  SGK1-Sanofi-14n  C17H12CIFN6O2S  418.83    SGK
#
#                                                         Reference Reference_2  \
# Uniprot_number
# O00141                 Sherk A. B. (2008) Cancer Res 68 7475–7483         NaN
# O00141          Halland, N (2015) ACS Medicinal Chemistry Lett...         NaN
# O00141          Halland, N (2015) ACS Medicinal Chemistry Lett...         NaN
# O00141           Halland, N (2015) ACS Medicinal Chemistry Let...         NaN
# O00141          Halland, N (2015) ACS Medicinal Chemistry Lett...         NaN
#
#                 PMID2 Patent Commercial Vendor          CAS  \
# Uniprot_number
# O00141            NaN    NaN            Tocris  890842-28-1
# O00141            NaN    NaN               NaN          NaN
# O00141            NaN    NaN               NaN          NaN
# O00141            NaN    NaN               NaN          NaN
# O00141            NaN    NaN               NaN          NaN
#
#                                                             InChI  \
# Uniprot_number
# O00141          InChI=1S/C25H22N2O2/c28-25(29)20-11-10-18(12-2...
# O00141                                                        NaN
# O00141                                                        NaN
# O00141                                                        NaN
# O00141                                                        NaN
#
#                                   InChI Key  PubChem CID  \
# Uniprot_number
# O00141          WVSBGSNVCDAMCF-UHFFFAOYSA-N   25022668.0
# O00141                                  NaN          NaN
# O00141                                  NaN          NaN
# O00141                                  NaN          NaN
# O00141                                  NaN          NaN
#
#                                                            SMILES  \
# Uniprot_number
# O00141          C1CCC(C1)C2=C(C=CC(=C2)C3=CNC4=NC=C(C=C34)C5=C...
# O00141                                                        NaN
# O00141                                                        NaN
# O00141                                                        NaN
# O00141                                                        NaN
#
#                                                          Alt Name
# Uniprot_number
# O00141          GSK 650394|890842-28-1|GSK650394|GSK-650394|UN...
# O00141                                                   SHN-2122
# O00141                                                   SHN-2121
# O00141                                                   SHN-2217
# O00141                                                   SHN-2108

# %%
#making final dataframe

My_df = pd.DataFrame({
  'Inhibitor': list(match_info.Inhibitor),'Target': list(match_info.Gene_name),
    'MW':list(match_info.MW), "Formula": list(match_info.Brutto), 
    'InChI': list(match_info.InChI), 'PubChem_CID': list(match_info[match_info.columns[13]]),
    'SMILES': list(match_info.SMILES), "Synonymns": list(match_info[match_info.columns[-1]])})


#rearranging the columns
df_final = My_df[['Inhibitor', 'Target', 'MW', 'Formula', 'InChI', 'PubChem_CID', 'SMILES', 'Synonymns']]

#115 rows
df_final.head()
# Out:
#          Inhibitor Target      MW         Formula  \
# 0       GSK650394A   SGK1  382.50      C25H22N2O2
# 1   SGK-Sanofi-14i   SGK1  430.87   C18H15ClN6O3S
# 2  SGK1-Sanofi-14g   SGK1  435.29  C17H12Cl2N6O2S
# 3  SGK1-Sanofi-14h   SGK1  435.29  C17H12Cl2N6O2S
# 4  SGK1-Sanofi-14n   SGK1  418.83  C17H12CIFN6O2S
#
#                                                InChI  PubChem_CID  \
# 0  InChI=1S/C25H22N2O2/c28-25(29)20-11-10-18(12-2...   25022668.0
# 1                                                NaN          NaN
# 2                                                NaN          NaN
# 3                                                NaN          NaN
# 4                                                NaN          NaN
#
#                                               SMILES  \
# 0  C1CCC(C1)C2=C(C=CC(=C2)C3=CNC4=NC=C(C=C34)C5=C...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            Synonymns
# 0  GSK 650394|890842-28-1|GSK650394|GSK-650394|UN...
# 1                                           SHN-2122
# 2                                           SHN-2121
# 3                                           SHN-2217
# 4                                           SHN-2108

# %%
#df into a csv file

df_final.to_csv('Incomplete_inhibitor.csv', header=True, index=False)
